# %%
# AUTO-GENERATED FROM MATLAB FitResult.m -- DO NOT EDIT
from pathlib import Path
import sys

REPO_ROOT = Path.cwd().resolve().parent
SRC_PATH = (REPO_ROOT / "src").resolve()
if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat

from nstat.data_manager import ensure_example_data
from nstat.notebook_figures import FigureTracker

np.random.seed(0)
DATA_DIR = ensure_example_data(download=True)
OUTPUT_ROOT = REPO_ROOT / "output" / "notebook_images"
__tracker = FigureTracker(topic='FitResult', output_root=OUTPUT_ROOT, expected_count=0)

def _matlab(line: str) -> None:
    """Placeholder for untranslated MATLAB syntax."""
    _ = line
    return

def _load_matlab_globals(name: str) -> dict[str, object]:
    candidates = [
        Path(name),
        DATA_DIR / name,
        DATA_DIR / "mEPSCs" / name,
        DATA_DIR / "Place Cells" / name,
        DATA_DIR / "Explicit Stimulus" / name,
    ]
    for path in candidates:
        if path.exists():
            data = loadmat(path)
            return {k: v for k, v in data.items() if not k.startswith("__")}
    return {}

def _has_vars(*names: str) -> bool:
    return all(name in globals() for name in names)

# SECTION 0: Section 0
# MATLAB L1: classdef FitResult < handle
_matlab('classdef FitResult < handle')
# MATLAB L2: % FITRESULT 
# FITRESULT
# MATLAB L3: % stores results of a fit using the Analysis object
# stores results of a fit using the Analysis object
# MATLAB L4: % The results are for a single neuron over a range of configurations
# The results are for a single neuron over a range of configurations
# MATLAB L5: %
#
# MATLAB L6: % <a href="FitResultExamples.html">FitResult Examples</a> 
# <a href="FitResultExamples.html">FitResult Examples</a>
# MATLAB L7: %
#
# MATLAB L8: % see also <a href="Analysis.html">Analysis</a>
# see also <a href="Analysis.html">Analysis</a>
# MATLAB L9: %
#
# MATLAB L10: % Reference page in Help browser
# Reference page in Help browser
# MATLAB L11: % <a href="FitResult.html">FitResult Reference</a>
# <a href="FitResult.html">FitResult Reference</a>
# MATLAB L12: 
#
# MATLAB L13: 
#
# MATLAB L14: %
#
# MATLAB L15: % nSTAT v1 Copyright (C) 2012 Masschusetts Institute of Technology
# nSTAT v1 Copyright (C) 2012 Masschusetts Institute of Technology
# MATLAB L16: % Cajigas, I, Malik, WQ, Brown, EN
# Cajigas, I, Malik, WQ, Brown, EN
# MATLAB L17: % This program is free software; you can redistribute it and/or 
# This program is free software; you can redistribute it and/or
# MATLAB L18: % modify it under the terms of the GNU General Public License as published 
# modify it under the terms of the GNU General Public License as published
# MATLAB L19: % by the Free Software Foundation; either version 2 of the License, or 
# by the Free Software Foundation; either version 2 of the License, or
# MATLAB L20: % (at your option) any later version.
# (at your option) any later version.
# MATLAB L21: % 
#
# MATLAB L22: % This program is distributed in the hope that it will be useful, 
# This program is distributed in the hope that it will be useful,
# MATLAB L23: % but WITHOUT ANY WARRANTY; without even the implied warranty of 
# but WITHOUT ANY WARRANTY; without even the implied warranty of
# MATLAB L24: % MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. 
# MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
# MATLAB L25: % See the GNU General Public License for more details.
# See the GNU General Public License for more details.
# MATLAB L26: %  
#
# MATLAB L27: % You should have received a copy of the GNU General Public License 
# You should have received a copy of the GNU General Public License
# MATLAB L28: % along with this program; if not, write to the Free Software Foundation, 
# along with this program; if not, write to the Free Software Foundation,
# MATLAB L29: % Inc., 59 Temple Place, Suite 330, Boston, MA 02111-1307 USA
# Inc., 59 Temple Place, Suite 330, Boston, MA 02111-1307 USA
# MATLAB L30: 
#
# MATLAB L31:     properties
_matlab('properties')
# MATLAB L32:        numResults   %Number of results in this FitResult object
_matlab('numResults   %Number of results in this FitResult object')
# MATLAB L33:        lambda       %Lambda signal
_matlab('lambda       %Lambda signal')
# MATLAB L34:        numCoeffs    %Number of coefficients for each fitResult
_matlab('numCoeffs    %Number of coefficients for each fitResult')
# MATLAB L35:        fitType      %Poisson or Binomial
_matlab('fitType      %Poisson or Binomial')
# MATLAB L36:        
#
# MATLAB L37:        b            %coefficients for each fit
_matlab('b            %coefficients for each fit')
# MATLAB L38:        
#
# MATLAB L39:        dev          %deviance for each fit
_matlab('dev          %deviance for each fit')
# MATLAB L40:        AIC          %Akaike's Information Criterion for each fit
_matlab("AIC          %Akaike's Information Criterion for each fit")
# MATLAB L41:        BIC          %Baysian Information Criterion for each fit
_matlab('BIC          %Baysian Information Criterion for each fit')
# MATLAB L42:        logLL        %Log Likelihood
_matlab('logLL        %Log Likelihood')
# MATLAB L43:        stats        %Relevant statistics for each fit
_matlab('stats        %Relevant statistics for each fit')
# MATLAB L44:        configs      % the config collection for the different fits
_matlab('configs      % the config collection for the different fits')
# MATLAB L45:        configNames  % names of the the differen fits
_matlab('configNames  % names of the the differen fits')
# MATLAB L46:        neuronNumber % the number of the neuron the data comes from
_matlab('neuronNumber % the number of the neuron the data comes from')
# MATLAB L47:        neuralSpikeTrain % the spike data
_matlab('neuralSpikeTrain % the spike data')
# MATLAB L48:        covLabels    
_matlab('covLabels')
# MATLAB L49:        uniqueCovLabels
_matlab('uniqueCovLabels')
# MATLAB L50:        indicesToUniqueLabels
_matlab('indicesToUniqueLabels')
# MATLAB L51:        numHist        % Number of history terms (used for indexing into the regression coefficients) for each fit
_matlab('numHist        % Number of history terms (used for indexing into the regression coefficients) for each fit')
# MATLAB L52:        histObjects    % History object for self firing 
_matlab('histObjects    % History object for self firing')
# MATLAB L53:        ensHistObjects % History object to be applied to the neuron's neigbors to compute ensemble effect
_matlab("ensHistObjects % History object to be applied to the neuron's neigbors to compute ensemble effect")
# MATLAB L54:        flatMask
_matlab('flatMask')
# MATLAB L55:        Z    % Rescaled spike times from the Time-Rescaling theorem, exponential rate 1
_matlab('Z    % Rescaled spike times from the Time-Rescaling theorem, exponential rate 1')
# MATLAB L56:        U    % Transformed z's -> uniform in [0,1]
_matlab("U    % Transformed z's -> uniform in [0,1]")
# MATLAB L57:        X    % Transformed u's -> gaussian in [-inf, inf]
_matlab("X    % Transformed u's -> gaussian in [-inf, inf]")
# MATLAB L58:        Residual %fit residual
_matlab('Residual %fit residual')
# MATLAB L59: %        xAxis
# xAxis
# MATLAB L60: %        KSSorted
# KSSorted
# MATLAB L61: %        ks_stat
# ks_stat
# MATLAB L62:        invGausStats 
_matlab('invGausStats')
# MATLAB L63:        KSStats  %Kolmogorov Smirnov Statistics
_matlab('KSStats  %Kolmogorov Smirnov Statistics')
# MATLAB L64:        plotParams
_matlab('plotParams')
# MATLAB L65:        XvalData % cell array of raw data used for validation
_matlab('XvalData % cell array of raw data used for validation')
# MATLAB L66:        XvalTime % cell array of time vectors for each element of XvalData
_matlab('XvalTime % cell array of time vectors for each element of XvalData')
# MATLAB L67:        validation % a FitResult object with the validation data
_matlab('validation % a FitResult object with the validation data')
# MATLAB L68:        minTime  % The minTime from the spikeTrain (not necessarily the analysis)
_matlab('minTime  % The minTime from the spikeTrain (not necessarily the analysis)')
# MATLAB L69:        maxTime  % The maxTime for the spikeTrain (not necessarily the analysis)
_matlab('maxTime  % The maxTime for the spikeTrain (not necessarily the analysis)')
# MATLAB L70:     end
_matlab('end')
# MATLAB L71:     properties (Constant,Hidden)
_matlab('properties (Constant,Hidden)')
# MATLAB L72:         colors={'b','g','r','c','m','y','k'};    
_matlab("colors={'b','g','r','c','m','y','k'};")
# MATLAB L73:     end
_matlab('end')
# MATLAB L74: 
#
# MATLAB L75: 
#
# MATLAB L76:     methods 
_matlab('methods')
# MATLAB L77:      
#
# MATLAB L78:         function fitObj=FitResult(spikeObj,covLabels,numHist,histObjects,ensHistObj,lambda,b, dev, stats,AIC,BIC,logLL, configColl,XvalData,XvalTime,distribution)
_matlab('function fitObj=FitResult(spikeObj,covLabels,numHist,histObjects,ensHistObj,lambda,b, dev, stats,AIC,BIC,logLL, configColl,XvalData,XvalTime,distribution)')
# MATLAB L79:             % fitObj=FitResult(spikeObj,covLabels,numHist,histObjects,ensHistObj,lambda,b, dev, stats,AIC,BIC,configColl,XvalData,XvalTime)
# fitObj=FitResult(spikeObj,covLabels,numHist,histObjects,ensHistObj,lambda,b, dev, stats,AIC,BIC,configColl,XvalData,XvalTime)
# MATLAB L80:             % Stores the results of multiple regressions for a single  neuron into a accessible structure.
# Stores the results of multiple regressions for a single  neuron into a accessible structure.
# MATLAB L81:             %
#
# MATLAB L82:             % spikeObj: The spike train for the neuron whose results are
# spikeObj: The spike train for the neuron whose results are
# MATLAB L83:             %           being stored.
# being stored.
# MATLAB L84:             % covLabels: A 2-d cell array, the jth row has all the labels for the covariates used in the jth fit
# covLabels: A 2-d cell array, the jth row has all the labels for the covariates used in the jth fit
# MATLAB L85:             % numHist: The number of history terms in each of the N fits.
# numHist: The number of history terms in each of the N fits.
# MATLAB L86:             % histObjects: The History object for each of the N fits
# histObjects: The History object for each of the N fits
# MATLAB L87:             % ensHistObj: The History object for used to compute the ensemble history effect.
# ensHistObj: The History object for used to compute the ensemble history effect.
# MATLAB L88:             % lambda: The conditional intensity function evaluated usin the
# lambda: The conditional intensity function evaluated usin the
# MATLAB L89:             % data. Each dimension of lambda corresponds to the a different
# data. Each dimension of lambda corresponds to the a different
# MATLAB L90:             %       GLM Fit.
# GLM Fit.
# MATLAB L91:             % b: N-component cell array containing the GLM regression
# b: N-component cell array containing the GLM regression
# MATLAB L92:             %    coefficient of each of the fits. The jth component has all
# coefficient of each of the fits. The jth component has all
# MATLAB L93:             %    the regression coefficients for the jth trial.
# the regression coefficients for the jth trial.
# MATLAB L94:             % dev: vector of Deviances for each the GLM fits.
# dev: vector of Deviances for each the GLM fits.
# MATLAB L95:             % stats: Cell array of the stats parameters for each GLM fit;
# stats: Cell array of the stats parameters for each GLM fit;
# MATLAB L96:             % AIC: vector of Akaike's information criteria for each the GLM fits.
# AIC: vector of Akaike's information criteria for each the GLM fits.
# MATLAB L97:             % BIC: vector of Bayes Information criteria for each the GLM fits.
# BIC: vector of Bayes Information criteria for each the GLM fits.
# MATLAB L98:             % configColl: configCollection object used to generate this
# configColl: configCollection object used to generate this
# MATLAB L99:             %             results
# results
# MATLAB L100:             % XvalData: Data to be used for validation.
# XvalData: Data to be used for validation.
# MATLAB L101:             % XvalTime: Time vector for the data.
# XvalTime: Time vector for the data.
# MATLAB L102:             
#
# MATLAB L103:             if(nargin< 14)
_matlab('if(nargin< 14)')
# MATLAB L104:                 XvalTime =[];
_matlab('XvalTime =[];')
# MATLAB L105:             end
_matlab('end')
# MATLAB L106:             if(nargin<13)
_matlab('if(nargin<13)')
# MATLAB L107:                 XvalData =[];
_matlab('XvalData =[];')
# MATLAB L108:             end
_matlab('end')
# MATLAB L109:             
#
# MATLAB L110:             if(isa(spikeObj,'cell'))
_matlab("if(isa(spikeObj,'cell'))")
# MATLAB L111:                 for i=1:length(spikeObj)
_matlab('for i=1:length(spikeObj)')
# MATLAB L112:                     if(isnumeric(spikeObj{i}.name))
_matlab('if(isnumeric(spikeObj{i}.name))')
# MATLAB L113:                         nNumber(i) =spikeObj{i}.name;
_matlab('nNumber(i) =spikeObj{i}.name;')
# MATLAB L114:                     else
_matlab('else')
# MATLAB L115:                         nNumber(i) = str2double(spikeObj{i}.name(~isletter(spikeObj{i}.name)));
_matlab('nNumber(i) = str2double(spikeObj{i}.name(~isletter(spikeObj{i}.name)));')
# MATLAB L116:                     end
_matlab('end')
# MATLAB L117:                     minTime(i)=spikeObj{i}.minTime;
_matlab('minTime(i)=spikeObj{i}.minTime;')
# MATLAB L118:                     maxTime(i)=spikeObj{i}.maxTime;
_matlab('maxTime(i)=spikeObj{i}.maxTime;')
# MATLAB L119:                 end
_matlab('end')
# MATLAB L120:                 nNumber = unique(nNumber);
_matlab('nNumber = unique(nNumber);')
# MATLAB L121:                 minTime = unique(minTime);
_matlab('minTime = unique(minTime);')
# MATLAB L122:                 maxTime = unique(maxTime);
_matlab('maxTime = unique(maxTime);')
# MATLAB L123:                 if(length(nNumber)>1)
_matlab('if(length(nNumber)>1)')
# MATLAB L124:                     error('Can only have a FitResults with spike trains from a single neuron');
_matlab("error('Can only have a FitResults with spike trains from a single neuron');")
# MATLAB L125:                 end
_matlab('end')
# MATLAB L126:                 if(length(minTime)>1 || length(maxTime)>1)
_matlab('if(length(minTime)>1 || length(maxTime)>1)')
# MATLAB L127:                     error('Spike Trains are of different lengths');
_matlab("error('Spike Trains are of different lengths');")
# MATLAB L128:                 end
_matlab('end')
# MATLAB L129:                 
#
# MATLAB L130:             elseif(isa(spikeObj,'nspikeTrain'))
_matlab("elseif(isa(spikeObj,'nspikeTrain'))")
# MATLAB L131:                 if(isnumeric(spikeObj.name))
_matlab('if(isnumeric(spikeObj.name))')
# MATLAB L132:                     nNumber =spikeObj.name;
_matlab('nNumber =spikeObj.name;')
# MATLAB L133:                 else
_matlab('else')
# MATLAB L134:                     nNumber = str2double(spikeObj.name(~isletter(spikeObj.name)));
_matlab('nNumber = str2double(spikeObj.name(~isletter(spikeObj.name)));')
# MATLAB L135:                 end
_matlab('end')
# MATLAB L136:                 minTime=spikeObj.minTime;
_matlab('minTime=spikeObj.minTime;')
# MATLAB L137:                 maxTime=spikeObj.maxTime;
_matlab('maxTime=spikeObj.maxTime;')
# MATLAB L138:                     
#
# MATLAB L139:             end
_matlab('end')
# MATLAB L140:                 
#
# MATLAB L141:             fitObj.neuronNumber = nNumber; %str2num(spikeObj.name);
_matlab('fitObj.neuronNumber = nNumber; %str2num(spikeObj.name);')
# MATLAB L142:             fitObj.neuralSpikeTrain = spikeObj;
_matlab('fitObj.neuralSpikeTrain = spikeObj;')
# MATLAB L143:             fitObj.minTime = minTime;
_matlab('fitObj.minTime = minTime;')
# MATLAB L144:             fitObj.maxTime = maxTime;
_matlab('fitObj.maxTime = maxTime;')
# MATLAB L145: 
#
# MATLAB L146:             fitObj.numResults = 0;
_matlab('fitObj.numResults = 0;')
# MATLAB L147:             fitObj.configs = configColl;
_matlab('fitObj.configs = configColl;')
# MATLAB L148:             fitObj.configNames = configColl.getConfigNames;
_matlab('fitObj.configNames = configColl.getConfigNames;')
# MATLAB L149:             fitObj.covLabels=covLabels;
_matlab('fitObj.covLabels=covLabels;')
# MATLAB L150:             fitObj.uniqueCovLabels= getUniqueLabels(covLabels);
_matlab('fitObj.uniqueCovLabels= getUniqueLabels(covLabels);')
# MATLAB L151:            
#
# MATLAB L152:             fitObj.mapCovLabelsToUniqueLabels;
_matlab('fitObj.mapCovLabelsToUniqueLabels;')
# MATLAB L153:             fitObj.numHist=numHist;
_matlab('fitObj.numHist=numHist;')
# MATLAB L154:             fitObj.histObjects = histObjects;
_matlab('fitObj.histObjects = histObjects;')
# MATLAB L155:             fitObj.ensHistObjects = ensHistObj;
_matlab('fitObj.ensHistObjects = ensHistObj;')
# MATLAB L156:             fitObj.addParamsToFit(fitObj.neuronNumber,lambda,b, dev, stats,AIC,BIC,logLL,configColl);
_matlab('fitObj.addParamsToFit(fitObj.neuronNumber,lambda,b, dev, stats,AIC,BIC,logLL,configColl);')
# MATLAB L157:             fitObj.Z        =[]; %rescaled spikes times - exponentially dist.
_matlab('fitObj.Z        =[]; %rescaled spikes times - exponentially dist.')
# MATLAB L158:             fitObj.U        =[]; %rescaled spike times - uniformly dist.
_matlab('fitObj.U        =[]; %rescaled spike times - uniformly dist.')
# MATLAB L159:             fitObj.X        =[]; %rescaled spike times - gaussian dist.
_matlab('fitObj.X        =[]; %rescaled spike times - gaussian dist.')
# MATLAB L160:             fitObj.Residual =[]; %fit residual for PP
_matlab('fitObj.Residual =[]; %fit residual for PP')
# MATLAB L161:             fitObj.KSStats.xAxis    =[];
_matlab('fitObj.KSStats.xAxis    =[];')
# MATLAB L162:             fitObj.KSStats.KSSorted =[];
_matlab('fitObj.KSStats.KSSorted =[];')
# MATLAB L163:             fitObj.KSStats.ks_stat  =[];
_matlab('fitObj.KSStats.ks_stat  =[];')
# MATLAB L164:             fitObj.invGausStats.rhoSig=[];
_matlab('fitObj.invGausStats.rhoSig=[];')
# MATLAB L165:             fitObj.invGausStats.confBoundSig=[];
_matlab('fitObj.invGausStats.confBoundSig=[];')
# MATLAB L166:             fitObj.plotParams = [];
_matlab('fitObj.plotParams = [];')
# MATLAB L167:             fitObj.XvalData = XvalData;
_matlab('fitObj.XvalData = XvalData;')
# MATLAB L168:             fitObj.XvalTime = XvalTime;     
_matlab('fitObj.XvalTime = XvalTime;')
# MATLAB L169:             
#
# MATLAB L170:             fitObj.fitType = distribution;     
_matlab('fitObj.fitType = distribution;')
# MATLAB L171:              
#
# MATLAB L172:         end       
_matlab('end')
# MATLAB L173:         function fitObj = setNeuronName(fitObj,name)
_matlab('function fitObj = setNeuronName(fitObj,name)')
# MATLAB L174:            fitObj.neuronNumber = name; 
_matlab('fitObj.neuronNumber = name;')
# MATLAB L175:         end
_matlab('end')
# MATLAB L176:         function mFitRes = mergeResults(fitObj,newFitObj)
_matlab('function mFitRes = mergeResults(fitObj,newFitObj)')
# MATLAB L177:             % mFitRes = mergeResults(fitObj,newFitObj)
# mFitRes = mergeResults(fitObj,newFitObj)
# MATLAB L178:             % mFitRes contains the results from fitObj followed by the
# mFitRes contains the results from fitObj followed by the
# MATLAB L179:             % results of newFitObj in a single new FitResult object
# results of newFitObj in a single new FitResult object
# MATLAB L180:             %
#
# MATLAB L181:             % newFitObj can be of class 'FitResult' or a cell array of
# newFitObj can be of class 'FitResult' or a cell array of
# MATLAB L182:             % 'FitResult' objects. In the latter case, the results are
# 'FitResult' objects. In the latter case, the results are
# MATLAB L183:             % apppended in the order that they appear in each cell array.
# apppended in the order that they appear in each cell array.
# MATLAB L184:             if(isa(newFitObj,'FitResult'))
_matlab("if(isa(newFitObj,'FitResult'))")
# MATLAB L185: %                 newFitObj.neuronNumber
# newFitObj.neuronNumber
# MATLAB L186:                 if(fitObj.neuronNumber ==newFitObj.neuronNumber)
_matlab('if(fitObj.neuronNumber ==newFitObj.neuronNumber)')
# MATLAB L187:                     spikeObj = fitObj.neuralSpikeTrain;
_matlab('spikeObj = fitObj.neuralSpikeTrain;')
# MATLAB L188:                     covLabels = fitObj.covLabels(1:fitObj.numResults);
_matlab('covLabels = fitObj.covLabels(1:fitObj.numResults);')
# MATLAB L189:                     covLabels((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.covLabels(1:newFitObj.numResults);
_matlab('covLabels((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.covLabels(1:newFitObj.numResults);')
# MATLAB L190:                     numHist = fitObj.numHist(1:fitObj.numResults);
_matlab('numHist = fitObj.numHist(1:fitObj.numResults);')
# MATLAB L191:                     numHist((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.numHist(1:newFitObj.numResults);
_matlab('numHist((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.numHist(1:newFitObj.numResults);')
# MATLAB L192:                     histObjects=fitObj.histObjects(1:fitObj.numResults);
_matlab('histObjects=fitObj.histObjects(1:fitObj.numResults);')
# MATLAB L193:                     histObjects((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.histObjects(1:newFitObj.numResults);
_matlab('histObjects((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.histObjects(1:newFitObj.numResults);')
# MATLAB L194:                     ensHistObjects=fitObj.ensHistObjects(1:fitObj.numResults);
_matlab('ensHistObjects=fitObj.ensHistObjects(1:fitObj.numResults);')
# MATLAB L195:                     ensHistObjects((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.ensHistObjects(1:newFitObj.numResults);
_matlab('ensHistObjects((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.ensHistObjects(1:newFitObj.numResults);')
# MATLAB L196:                     b=fitObj.b(1:fitObj.numResults);
_matlab('b=fitObj.b(1:fitObj.numResults);')
# MATLAB L197:                     b((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.b(1:newFitObj.numResults);
_matlab('b((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.b(1:newFitObj.numResults);')
# MATLAB L198:                     dev = [fitObj.dev newFitObj.dev];
_matlab('dev = [fitObj.dev newFitObj.dev];')
# MATLAB L199:                     AIC = [fitObj.AIC newFitObj.AIC];
_matlab('AIC = [fitObj.AIC newFitObj.AIC];')
# MATLAB L200:                     BIC = [fitObj.BIC newFitObj.BIC];
_matlab('BIC = [fitObj.BIC newFitObj.BIC];')
# MATLAB L201:                     logLL = [fitObj.logLL newFit.logLL];
_matlab('logLL = [fitObj.logLL newFit.logLL];')
# MATLAB L202:                     stats=fitObj.stats(1:fitObj.numResults);
_matlab('stats=fitObj.stats(1:fitObj.numResults);')
# MATLAB L203:                     stats((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.stats(1:newFitObj.numResults);
_matlab('stats((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.stats(1:newFitObj.numResults);')
# MATLAB L204:                     lambda = fitObj.lambda.merge(newFitObj.lambda);
_matlab('lambda = fitObj.lambda.merge(newFitObj.lambda);')
# MATLAB L205:                     
#
# MATLAB L206:                     for i=1:fitObj.numResults
_matlab('for i=1:fitObj.numResults')
# MATLAB L207:                         config{i}=fitObj.configs.getConfig(i);
_matlab('config{i}=fitObj.configs.getConfig(i);')
# MATLAB L208:                     end
_matlab('end')
# MATLAB L209:                     offset=fitObj.numResults;
_matlab('offset=fitObj.numResults;')
# MATLAB L210:                     for i=1:newFitObj.numResults
_matlab('for i=1:newFitObj.numResults')
# MATLAB L211:                         config{i+offset}=newFitObj.configs.getConfig(i);
_matlab('config{i+offset}=newFitObj.configs.getConfig(i);')
# MATLAB L212:                     end
_matlab('end')
# MATLAB L213:                     configColl= ConfigColl(config);
_matlab('configColl= ConfigColl(config);')
# MATLAB L214:                     
#
# MATLAB L215:                     XvalData = [fitObj.XvalData newFitObj.XvalData];
_matlab('XvalData = [fitObj.XvalData newFitObj.XvalData];')
# MATLAB L216:                     XvalTime = [fitObj.XvalTime newFitObj.XvalTime];
_matlab('XvalTime = [fitObj.XvalTime newFitObj.XvalTime];')
# MATLAB L217:                     distribution=fitObj.fitType(1:fitObj.numResults);
_matlab('distribution=fitObj.fitType(1:fitObj.numResults);')
# MATLAB L218:                     distribution((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.fitType(1:newFitObj.numResults);
_matlab('distribution((fitObj.numResults+1):(fitObj.numResults+newFitObj.numResults)) = newFitObj.fitType(1:newFitObj.numResults);')
# MATLAB L219:                     tempZ = zeros(length(fitObj.Z),size(newFitObj.Z,2));
_matlab('tempZ = zeros(length(fitObj.Z),size(newFitObj.Z,2));')
# MATLAB L220:                     tempU = zeros(length(fitObj.U),size(newFitObj.U,2));
_matlab('tempU = zeros(length(fitObj.U),size(newFitObj.U,2));')
# MATLAB L221:                     tempZ(1:length(newFitObj.Z),:) = newFitObj.Z;
_matlab('tempZ(1:length(newFitObj.Z),:) = newFitObj.Z;')
# MATLAB L222:                     tempU(1:length(newFitObj.U),:) = newFitObj.U;
_matlab('tempU(1:length(newFitObj.U),:) = newFitObj.U;')
# MATLAB L223:                     Z=[fitObj.Z tempZ];
_matlab('Z=[fitObj.Z tempZ];')
# MATLAB L224:                     U=[fitObj.U tempU];
_matlab('U=[fitObj.U tempU];')
# MATLAB L225:                     [X,rhoSig,confBoundSig] = Analysis.computeInvGausTrans(Z);
_matlab('[X,rhoSig,confBoundSig] = Analysis.computeInvGausTrans(Z);')
# MATLAB L226: 
#
# MATLAB L227:                     M=fitObj.Residual.merge(newFitObj.Residual);
_matlab('M=fitObj.Residual.merge(newFitObj.Residual);')
# MATLAB L228:                    
#
# MATLAB L229:                     origLength = size(fitObj.KSStats.xAxis,1);
_matlab('origLength = size(fitObj.KSStats.xAxis,1);')
# MATLAB L230:                     currLength = size(newFitObj.KSStats.xAxis,1);
_matlab('currLength = size(newFitObj.KSStats.xAxis,1);')
# MATLAB L231:                     
#
# MATLAB L232:                     if(currLength~=origLength)
_matlab('if(currLength~=origLength)')
# MATLAB L233:                         %we use this because some times the time scales
# we use this because some times the time scales
# MATLAB L234:                         %dont match up.  In particular when spikeTrain is
# dont match up.  In particular when spikeTrain is
# MATLAB L235:                         %segmented by steps or windows and the window sizes
# segmented by steps or windows and the window sizes
# MATLAB L236:                         %are normalized to 1.
# are normalized to 1.
# MATLAB L237:                       newX = fitObj.KSStats.xAxis;
_matlab('newX = fitObj.KSStats.xAxis;')
# MATLAB L238:                       oldX = newFitObj.KSStats.xAxis;
_matlab('oldX = newFitObj.KSStats.xAxis;')
# MATLAB L239:                       oldY = newFitObj.KSStats.KSSorted;
_matlab('oldY = newFitObj.KSStats.KSSorted;')
# MATLAB L240:                       y = interp1(oldX,oldY,newX(:,1),'spline','extrap');
_matlab("y = interp1(oldX,oldY,newX(:,1),'spline','extrap');")
# MATLAB L241:                       xAxis    = [fitObj.KSStats.xAxis newX(:,1)];
_matlab('xAxis    = [fitObj.KSStats.xAxis newX(:,1)];')
# MATLAB L242:                       KSSorted = [fitObj.KSStats.KSSorted y];
_matlab('KSSorted = [fitObj.KSStats.KSSorted y];')
# MATLAB L243:                     else
_matlab('else')
# MATLAB L244:                        
#
# MATLAB L245:                         xAxis    = [fitObj.KSStats.xAxis newFitObj.KSStats.xAxis];
_matlab('xAxis    = [fitObj.KSStats.xAxis newFitObj.KSStats.xAxis];')
# MATLAB L246:                         KSSorted = [fitObj.KSStats.KSSorted newFitObj.KSStats.KSSorted];
_matlab('KSSorted = [fitObj.KSStats.KSSorted newFitObj.KSStats.KSSorted];')
# MATLAB L247:                         
#
# MATLAB L248:                     end
_matlab('end')
# MATLAB L249:                     ks_stat  = [fitObj.KSStats.ks_stat newFitObj.KSStats.ks_stat];
_matlab('ks_stat  = [fitObj.KSStats.ks_stat newFitObj.KSStats.ks_stat];')
# MATLAB L250:                     mFitRes=FitResult(spikeObj,covLabels,numHist,histObjects,ensHistObjects,lambda,b, dev, stats,AIC,BIC,logLL,configColl,XvalData,XvalTime,distribution);
_matlab('mFitRes=FitResult(spikeObj,covLabels,numHist,histObjects,ensHistObjects,lambda,b, dev, stats,AIC,BIC,logLL,configColl,XvalData,XvalTime,distribution);')
# MATLAB L251:                     mFitRes.setKSStats(Z,U, xAxis, KSSorted, ks_stat);
_matlab('mFitRes.setKSStats(Z,U, xAxis, KSSorted, ks_stat);')
# MATLAB L252:                     mFitRes.setInvGausStats(X,rhoSig,confBoundSig);
_matlab('mFitRes.setInvGausStats(X,rhoSig,confBoundSig);')
# MATLAB L253:                     mFitRes.setFitResidual(M);
_matlab('mFitRes.setFitResidual(M);')
# MATLAB L254:                     
#
# MATLAB L255:                     
#
# MATLAB L256:                 elseif(isa(newFitObj,'cell'))
_matlab("elseif(isa(newFitObj,'cell'))")
# MATLAB L257:                     if(isa(newFitObj{1},'FitResult'))
_matlab("if(isa(newFitObj{1},'FitResult'))")
# MATLAB L258:                         for i=1:length(newFitObj)
_matlab('for i=1:length(newFitObj)')
# MATLAB L259:                             if(i==1)
_matlab('if(i==1)')
# MATLAB L260:                                 mFitRes = fitObj.mergeResults(newFitObj{i});
_matlab('mFitRes = fitObj.mergeResults(newFitObj{i});')
# MATLAB L261:                             else
_matlab('else')
# MATLAB L262:                                 mFitRes = mFitRes.mergeResults(newFitObj{i});
_matlab('mFitRes = mFitRes.mergeResults(newFitObj{i});')
# MATLAB L263:                             end
_matlab('end')
# MATLAB L264:                         end
_matlab('end')
# MATLAB L265:                     end
_matlab('end')
# MATLAB L266:                 end
_matlab('end')
# MATLAB L267:             end
_matlab('end')
# MATLAB L268:             
#
# MATLAB L269:         end
_matlab('end')
# MATLAB L270:         function subsetFit = getSubsetFitResult(fitObj,subfits)
_matlab('function subsetFit = getSubsetFitResult(fitObj,subfits)')
# MATLAB L271:             %subfits is a row vector with numbers corresponding to the
# subfits is a row vector with numbers corresponding to the
# MATLAB L272:             %subfits
# subfits
# MATLAB L273:             if(and(min(subfits)>0,max(subfits)<=fitObj.numResults))
_matlab('if(and(min(subfits)>0,max(subfits)<=fitObj.numResults))')
# MATLAB L274:                 spikeObj = fitObj.neuralSpikeTrain;
_matlab('spikeObj = fitObj.neuralSpikeTrain;')
# MATLAB L275:                 covLabels = fitObj.covLabels(subfits);
_matlab('covLabels = fitObj.covLabels(subfits);')
# MATLAB L276:                 numHist = fitObj.numHist(subfits);
_matlab('numHist = fitObj.numHist(subfits);')
# MATLAB L277:                 histObjects = fitObj.histObjects(subfits);
_matlab('histObjects = fitObj.histObjects(subfits);')
# MATLAB L278:                 ensHistObj = fitObj.ensHistObjects(subfits);
_matlab('ensHistObj = fitObj.ensHistObjects(subfits);')
# MATLAB L279:                 lambda = fitObj.lambda.getSubSignal(subfits);
_matlab('lambda = fitObj.lambda.getSubSignal(subfits);')
# MATLAB L280:                 b = fitObj.b(subfits);
_matlab('b = fitObj.b(subfits);')
# MATLAB L281:                 dev = fitObj.dev(subfits);
_matlab('dev = fitObj.dev(subfits);')
# MATLAB L282:                 stats = fitObj.stats(subfits);
_matlab('stats = fitObj.stats(subfits);')
# MATLAB L283:                 AIC = fitObj.AIC(subfits);
_matlab('AIC = fitObj.AIC(subfits);')
# MATLAB L284:                 BIC = fitObj.BIC(subfits);
_matlab('BIC = fitObj.BIC(subfits);')
# MATLAB L285:                 logLL = fitObj.logLL(subfits);
_matlab('logLL = fitObj.logLL(subfits);')
# MATLAB L286:                 configColl = fitObj.configs.getSubsetConfigs(subfits);
_matlab('configColl = fitObj.configs.getSubsetConfigs(subfits);')
# MATLAB L287:                 XvalData  = fitObj.XvalData;
_matlab('XvalData  = fitObj.XvalData;')
# MATLAB L288:                 XvalTime  = fitObj.XvalTime;
_matlab('XvalTime  = fitObj.XvalTime;')
# MATLAB L289:                 distribution = fitObj.fitType;
_matlab('distribution = fitObj.fitType;')
# MATLAB L290: 
#
# MATLAB L291:                 subsetFit=FitResult(spikeObj,covLabels,numHist,histObjects,ensHistObj,lambda,b, dev, stats,AIC,BIC,logLL,configColl,XvalData,XvalTime,distribution);
_matlab('subsetFit=FitResult(spikeObj,covLabels,numHist,histObjects,ensHistObj,lambda,b, dev, stats,AIC,BIC,logLL,configColl,XvalData,XvalTime,distribution);')
# MATLAB L292:                 Z = fitObj.Z(:,subfits);
_matlab('Z = fitObj.Z(:,subfits);')
# MATLAB L293:                 U = fitObj.U(:,subfits);
_matlab('U = fitObj.U(:,subfits);')
# MATLAB L294:                 X = fitObj.X(:,subfits);
_matlab('X = fitObj.X(:,subfits);')
# MATLAB L295:                 xAxis= fitObj.KSStats.xAxis(:,subfits);
_matlab('xAxis= fitObj.KSStats.xAxis(:,subfits);')
# MATLAB L296:                 KSSorted=fitObj.KSStats.KSSorted(:,subfits);
_matlab('KSSorted=fitObj.KSStats.KSSorted(:,subfits);')
# MATLAB L297:                 ks_stat=fitObj.KSStats.ks_stat(subfits);
_matlab('ks_stat=fitObj.KSStats.ks_stat(subfits);')
# MATLAB L298:                 rhoSig=fitObj.invGausStats.rhoSig.getSubSignal(subfits);
_matlab('rhoSig=fitObj.invGausStats.rhoSig.getSubSignal(subfits);')
# MATLAB L299:                 confBoundSig=fitObj.invGausStats.confBoundSig;
_matlab('confBoundSig=fitObj.invGausStats.confBoundSig;')
# MATLAB L300:                 M = fitObj.Residual.getSubSignal(subfits);
_matlab('M = fitObj.Residual.getSubSignal(subfits);')
# MATLAB L301: 
#
# MATLAB L302:                 subsetFit.setKSStats(Z,U, xAxis, KSSorted, ks_stat);
_matlab('subsetFit.setKSStats(Z,U, xAxis, KSSorted, ks_stat);')
# MATLAB L303:                 subsetFit.setInvGausStats(X,rhoSig,confBoundSig);
_matlab('subsetFit.setInvGausStats(X,rhoSig,confBoundSig);')
# MATLAB L304:                 subsetFit.setFitResidual(M);
_matlab('subsetFit.setFitResidual(M);')
# MATLAB L305:             end
_matlab('end')
# MATLAB L306:         end
_matlab('end')
# MATLAB L307:         function addParamsToFit(fitObj,neuronNum,lambda,b, dev, stats,AIC,BIC,logLL,configColl)
_matlab('function addParamsToFit(fitObj,neuronNum,lambda,b, dev, stats,AIC,BIC,logLL,configColl)')
# MATLAB L308:             % addParamsToFit(fitObj,neuronNum,lambda,b, dev, stats,AIC,BIC,configColl)
# addParamsToFit(fitObj,neuronNum,lambda,b, dev, stats,AIC,BIC,configColl)
# MATLAB L309:             % Add the specified parameters to the current FitResult object
# Add the specified parameters to the current FitResult object
# MATLAB L310:             % only if the neuronNum matches the neuronNum of this object
# only if the neuronNum matches the neuronNum of this object
# MATLAB L311:             if(fitObj.neuronNumber==neuronNum)
_matlab('if(fitObj.neuronNumber==neuronNum)')
# MATLAB L312:               if(isa(lambda,'cell'))
_matlab("if(isa(lambda,'cell'))")
# MATLAB L313:                   newLambda=lambda{1};
_matlab('newLambda=lambda{1};')
# MATLAB L314:                   for i=2:length(lambda)
_matlab('for i=2:length(lambda)')
# MATLAB L315:                       newLambda = newLambda.merge(lambda{i});
_matlab('newLambda = newLambda.merge(lambda{i});')
# MATLAB L316:                   end
_matlab('end')
# MATLAB L317:               elseif(isa(lambda,'Covariate')||isa(lambda,'SignalObj'))
_matlab("elseif(isa(lambda,'Covariate')||isa(lambda,'SignalObj'))")
# MATLAB L318:                   newLambda = lambda;
_matlab('newLambda = lambda;')
# MATLAB L319:               end
_matlab('end')
# MATLAB L320: 
#
# MATLAB L321:               numNewResults = newLambda.dimension;%number of new elements
_matlab('numNewResults = newLambda.dimension;%number of new elements')
# MATLAB L322:               if(nargin<8)
_matlab('if(nargin<8)')
# MATLAB L323:                   configColl = cell(1,numNewResults);
_matlab('configColl = cell(1,numNewResults);')
# MATLAB L324:               end
_matlab('end')
# MATLAB L325: 
#
# MATLAB L326:               if(numNewResults==1)
_matlab('if(numNewResults==1)')
# MATLAB L327:                       fitObj.b{fitObj.numResults+1}    = b{1};
_matlab('fitObj.b{fitObj.numResults+1}    = b{1};')
# MATLAB L328:                       
#
# MATLAB L329:                       fitObj.dev(fitObj.numResults+1)  = dev;
_matlab('fitObj.dev(fitObj.numResults+1)  = dev;')
# MATLAB L330:                       fitObj.stats{fitObj.numResults+1}= stats{1};
_matlab('fitObj.stats{fitObj.numResults+1}= stats{1};')
# MATLAB L331:                       if(nargin<7)
_matlab('if(nargin<7)')
# MATLAB L332:                           fitObj.AIC(fitObj.numResults+1)  = 2*length(b)+dev;
_matlab('fitObj.AIC(fitObj.numResults+1)  = 2*length(b)+dev;')
# MATLAB L333:                           fitObj.BIC(fitObj.numResults+1)  = length(b)*log(length(newLambda.time))+dev;
_matlab('fitObj.BIC(fitObj.numResults+1)  = length(b)*log(length(newLambda.time))+dev;')
# MATLAB L334:                           delta = 1/newLambda.sampleRate;
_matlab('delta = 1/newLambda.sampleRate;')
# MATLAB L335:                           fitObj.logLL(fitObj.numResults+1) = sum(y.*log(data*delta)+(1-y).*(1-newLambda.data*delta));
_matlab('fitObj.logLL(fitObj.numResults+1) = sum(y.*log(data*delta)+(1-y).*(1-newLambda.data*delta));')
# MATLAB L336:                       else
_matlab('else')
# MATLAB L337:                           fitObj.AIC(fitObj.numResults+1)  = AIC;
_matlab('fitObj.AIC(fitObj.numResults+1)  = AIC;')
# MATLAB L338:                           fitObj.BIC(fitObj.numResults+1)  = BIC;
_matlab('fitObj.BIC(fitObj.numResults+1)  = BIC;')
# MATLAB L339:                           fitObj.logLL(fitObj.numResults+1) = logLL;
_matlab('fitObj.logLL(fitObj.numResults+1) = logLL;')
# MATLAB L340:                       end
_matlab('end')
# MATLAB L341:                           
#
# MATLAB L342:                       fitObj.numCoeffs(fitObj.numResults+1) = length(b);
_matlab('fitObj.numCoeffs(fitObj.numResults+1) = length(b);')
# MATLAB L343:               else
_matlab('else')
# MATLAB L344:                   for i=1:numNewResults
_matlab('for i=1:numNewResults')
# MATLAB L345:                       fitObj.b{fitObj.numResults+i}    = b{i};
_matlab('fitObj.b{fitObj.numResults+i}    = b{i};')
# MATLAB L346:                       
#
# MATLAB L347:                       fitObj.dev(fitObj.numResults+i)  = dev(i);
_matlab('fitObj.dev(fitObj.numResults+i)  = dev(i);')
# MATLAB L348:                       fitObj.stats{fitObj.numResults+i}= stats{i};
_matlab('fitObj.stats{fitObj.numResults+i}= stats{i};')
# MATLAB L349:                       if(nargin<7)
_matlab('if(nargin<7)')
# MATLAB L350:                           fitObj.AIC(fitObj.numResults+i)  = 2*length(b{i})+dev(i);
_matlab('fitObj.AIC(fitObj.numResults+i)  = 2*length(b{i})+dev(i);')
# MATLAB L351:                           fitObj.BIC(fitObj.numResults+i)  = length(b{i})*log(length(newLambda.time))+dev(i);
_matlab('fitObj.BIC(fitObj.numResults+i)  = length(b{i})*log(length(newLambda.time))+dev(i);')
# MATLAB L352:                           delta=fitObj.neuralSpikeTrain.sampleRate;
_matlab('delta=fitObj.neuralSpikeTrain.sampleRate;')
# MATLAB L353:                           y=fitObj.neuralSpikeTrain.getSigRep.dataToMatrix;
_matlab('y=fitObj.neuralSpikeTrain.getSigRep.dataToMatrix;')
# MATLAB L354:                           
#
# MATLAB L355:                           fitObj.logLL(fitObj.numResults+i)= sum(y.*log(newLambda.data*delta)+(1-y).*(1-newLambda.data*delta));
_matlab('fitObj.logLL(fitObj.numResults+i)= sum(y.*log(newLambda.data*delta)+(1-y).*(1-newLambda.data*delta));')
# MATLAB L356:                       else
_matlab('else')
# MATLAB L357:                           fitObj.AIC(fitObj.numResults+i)  = AIC(i);
_matlab('fitObj.AIC(fitObj.numResults+i)  = AIC(i);')
# MATLAB L358:                           fitObj.BIC(fitObj.numResults+i)  = BIC(i);
_matlab('fitObj.BIC(fitObj.numResults+i)  = BIC(i);')
# MATLAB L359:                           fitObj.logLL(fitObj.numResults+i)= logLL(i);
_matlab('fitObj.logLL(fitObj.numResults+i)= logLL(i);')
# MATLAB L360:                       end
_matlab('end')
# MATLAB L361:                       fitObj.numCoeffs(fitObj.numResults+i) = length(b{i});
_matlab('fitObj.numCoeffs(fitObj.numResults+i) = length(b{i});')
# MATLAB L362:                   end
_matlab('end')
# MATLAB L363:               end
_matlab('end')
# MATLAB L364:               if(fitObj.numResults ==0)
_matlab('if(fitObj.numResults ==0)')
# MATLAB L365:                   fitObj.lambda = newLambda;
_matlab('fitObj.lambda = newLambda;')
# MATLAB L366:               else
_matlab('else')
# MATLAB L367:                 fitObj.lambda = fitObj.lambda.merge(newLambda); %new lambda
_matlab('fitObj.lambda = fitObj.lambda.merge(newLambda); %new lambda')
# MATLAB L368:               end
_matlab('end')
# MATLAB L369:               
#
# MATLAB L370:               fitObj.numResults = fitObj.numResults+numNewResults;
_matlab('fitObj.numResults = fitObj.numResults+numNewResults;')
# MATLAB L371:               dataLabels = cell(1,fitObj.numResults);
_matlab('dataLabels = cell(1,fitObj.numResults);')
# MATLAB L372:               for i=1:fitObj.numResults
_matlab('for i=1:fitObj.numResults')
# MATLAB L373:                  dataLabels{i} = strcat('\lambda_{',num2str(i),'}');
_matlab("dataLabels{i} = strcat('\\lambda_{',num2str(i),'}');")
# MATLAB L374:               end
_matlab('end')
# MATLAB L375:               fitObj.lambda.setDataLabels(dataLabels);
_matlab('fitObj.lambda.setDataLabels(dataLabels);')
# MATLAB L376:               
#
# MATLAB L377:               fitObj.configs.addConfig(configColl);
_matlab('fitObj.configs.addConfig(configColl);')
# MATLAB L378:               fitObj.configNames = fitObj.configs.getConfigNames;
_matlab('fitObj.configNames = fitObj.configs.getConfigNames;')
# MATLAB L379:           else
_matlab('else')
# MATLAB L380:               error('Neuron number does not match');
_matlab("error('Neuron number does not match');")
# MATLAB L381:           end
_matlab('end')
# MATLAB L382:         end
_matlab('end')
# MATLAB L383:         function [lambda, logLL] = computeValLambda(fitObj)
_matlab('function [lambda, logLL] = computeValLambda(fitObj)')
# MATLAB L384:             % lambda = computeValLambda(fitObj)
# lambda = computeValLambda(fitObj)
# MATLAB L385:             % Returns a Covariate object lambda. This is the Conditional
# Returns a Covariate object lambda. This is the Conditional
# MATLAB L386:             % intensity function evaluated using the validation data
# intensity function evaluated using the validation data
# MATLAB L387:             lambdaData = zeros(length(fitObj.XvalTime{1}),fitObj.numResults);
_matlab('lambdaData = zeros(length(fitObj.XvalTime{1}),fitObj.numResults);')
# MATLAB L388:             for i=1:fitObj.numResults
_matlab('for i=1:fitObj.numResults')
# MATLAB L389:                 lambdaData(:,i) = fitObj.evalLambda(i,fitObj.XvalData{i});
_matlab('lambdaData(:,i) = fitObj.evalLambda(i,fitObj.XvalData{i});')
# MATLAB L390:             end
_matlab('end')
# MATLAB L391:             lambda=Covariate(fitObj.XvalTime{1},lambdaData,...
_matlab('lambda=Covariate(fitObj.XvalTime{1},lambdaData,...')
# MATLAB L392:                   '\lambda(t)',fitObj.lambda.xlabelval,...
_matlab("'\\lambda(t)',fitObj.lambda.xlabelval,...")
# MATLAB L393:                   fitObj.lambda.xunits,'Hz',fitObj.lambda.dataLabels);
_matlab("fitObj.lambda.xunits,'Hz',fitObj.lambda.dataLabels);")
# MATLAB L394:             delta = 1/lambda.sampleRate;
_matlab('delta = 1/lambda.sampleRate;')
# MATLAB L395:             y=fitObj.neuralSpikeTrain.getSigRep.dataToMatrix;
_matlab('y=fitObj.neuralSpikeTrain.getSigRep.dataToMatrix;')
# MATLAB L396:             logLL =sum(y.*log(lambda.data*delta)+(1-y).*(1-lambda.data*delta));
_matlab('logLL =sum(y.*log(lambda.data*delta)+(1-y).*(1-lambda.data*delta));')
# MATLAB L397:         end
_matlab('end')
# MATLAB L398:         
#
# MATLAB L399:         function mapCovLabelsToUniqueLabels(fitObj)
_matlab('function mapCovLabelsToUniqueLabels(fitObj)')
# MATLAB L400:             % mapCovLabelsToUniqueLabels(fitObj)
# mapCovLabelsToUniqueLabels(fitObj)
# MATLAB L401:             % Used internally by the FitResult class generate a matrix that
# Used internally by the FitResult class generate a matrix that
# MATLAB L402:             % maps how covariate labels of the fit object map to unique
# maps how covariate labels of the fit object map to unique
# MATLAB L403:             % covariate labels. For example, multiple fits that have a
# covariate labels. For example, multiple fits that have a
# MATLAB L404:             % constant baseline term will be assumed to refer to the same
# constant baseline term will be assumed to refer to the same
# MATLAB L405:             % "baseline" term and not two separate ones
# "baseline" term and not two separate ones
# MATLAB L406:             flatMask = zeros(length(fitObj.uniqueCovLabels),length(fitObj.covLabels));
_matlab('flatMask = zeros(length(fitObj.uniqueCovLabels),length(fitObj.covLabels));')
# MATLAB L407:             for j=1:length(fitObj.covLabels)
_matlab('for j=1:length(fitObj.covLabels)')
# MATLAB L408:                 currLabels = fitObj.covLabels{j};
_matlab('currLabels = fitObj.covLabels{j};')
# MATLAB L409:                 index=zeros(1,length(currLabels));
_matlab('index=zeros(1,length(currLabels));')
# MATLAB L410:                 for i=1:length(currLabels)
_matlab('for i=1:length(currLabels)')
# MATLAB L411:                     index(i)=strmatch(currLabels{i}, fitObj.uniqueCovLabels, 'exact');
_matlab("index(i)=strmatch(currLabels{i}, fitObj.uniqueCovLabels, 'exact');")
# MATLAB L412:                 end
_matlab('end')
# MATLAB L413:                 
#
# MATLAB L414:                 fitObj.indicesToUniqueLabels{j} = index;
_matlab('fitObj.indicesToUniqueLabels{j} = index;')
# MATLAB L415:                 flatMask(index,j) = 1;
_matlab('flatMask(index,j) = 1;')
# MATLAB L416:             end
_matlab('end')
# MATLAB L417:             fitObj.flatMask = flatMask;
_matlab('fitObj.flatMask = flatMask;')
# MATLAB L418:         end        
_matlab('end')
# MATLAB L419:         function p=getPlotParams(fitObj)
_matlab('function p=getPlotParams(fitObj)')
# MATLAB L420:             % p=getPlotParams(fitObj)
# p=getPlotParams(fitObj)
# MATLAB L421:             if(isempty(fitObj.plotParams))
_matlab('if(isempty(fitObj.plotParams))')
# MATLAB L422:                 fitObj.computePlotParams;
_matlab('fitObj.computePlotParams;')
# MATLAB L423:             end
_matlab('end')
# MATLAB L424:                 p=fitObj.plotParams;
_matlab('p=fitObj.plotParams;')
# MATLAB L425:         end        
_matlab('end')
# MATLAB L426:         function plotValidation(fitObj) 
_matlab('function plotValidation(fitObj)')
# MATLAB L427:             % plotValidation(fitObj) 
# plotValidation(fitObj)
# MATLAB L428:             % calls plotResults on the validation FitResult object if
# calls plotResults on the validation FitResult object if
# MATLAB L429:             % validation data is present. Note that the GLM coefficients
# validation data is present. Note that the GLM coefficients
# MATLAB L430:             % are not recomputed and therefore the same as those obtained
# are not recomputed and therefore the same as those obtained
# MATLAB L431:             % from the training data.
# from the training data.
# MATLAB L432:             if(~isempty(fitObj.validation))
_matlab('if(~isempty(fitObj.validation))')
# MATLAB L433:                 fitObj.validation.plotResults;
_matlab('fitObj.validation.plotResults;')
# MATLAB L434:             else
_matlab('else')
# MATLAB L435:                 display('Validation Data not available to plot');
_matlab("display('Validation Data not available to plot');")
# MATLAB L436:             end
_matlab('end')
# MATLAB L437:         end
_matlab('end')
# MATLAB L438:         function answer = isValDataPresent(fitObj)
_matlab('function answer = isValDataPresent(fitObj)')
# MATLAB L439:             % answer = isValDataPresent(fitObj)
# answer = isValDataPresent(fitObj)
# MATLAB L440:             % returns 1 if validation data is present. This method is used
# returns 1 if validation data is present. This method is used
# MATLAB L441:             % to determine if validation data is available to compute the
# to determine if validation data is available to compute the
# MATLAB L442:             % validation results.
# validation results.
# MATLAB L443:             answer = 0;
answer = 0
# MATLAB L444:             if(~isempty(fitObj.XvalTime) && ~isempty(fitObj.XvalData))
_matlab('if(~isempty(fitObj.XvalTime) && ~isempty(fitObj.XvalData))')
# MATLAB L445:                 for i=1:length(fitObj.XvalTime)
_matlab('for i=1:length(fitObj.XvalTime)')
# MATLAB L446:                     currTime = fitObj.XvalTime{i};
_matlab('currTime = fitObj.XvalTime{i};')
# MATLAB L447:                     if(~isempty(currTime))
_matlab('if(~isempty(currTime))')
# MATLAB L448:                         if(currTime(end)-currTime(1)>0)
_matlab('if(currTime(end)-currTime(1)>0)')
# MATLAB L449:                             answer =1;
answer = 1
# MATLAB L450:                             break;
_matlab('break;')
# MATLAB L451:                         end
_matlab('end')
# MATLAB L452:                     end
_matlab('end')
# MATLAB L453:                 end
_matlab('end')
# MATLAB L454:                 
#
# MATLAB L455:             end
_matlab('end')
# MATLAB L456:             
#
# MATLAB L457:         end        
_matlab('end')
# MATLAB L458:         function lambdaData = evalLambda(fitObj,lambdaIndex,newData)
_matlab('function lambdaData = evalLambda(fitObj,lambdaIndex,newData)')
# MATLAB L459:             % lambdaData = evalLambda(fitObj,lambdaIndex,newData)
# lambdaData = evalLambda(fitObj,lambdaIndex,newData)
# MATLAB L460:             % lambdaIndex: the index of the corresponding lambda to be
# lambdaIndex: the index of the corresponding lambda to be
# MATLAB L461:             %              evaluated with the new data.
# evaluated with the new data.
# MATLAB L462:             % newData:     matrix of covariates in same order as fits without
# newData:     matrix of covariates in same order as fits without
# MATLAB L463:             %              constant term in first column
# constant term in first column
# MATLAB L464: %             if(isa(newData,'double'))
# if(isa(newData,'double'))
# MATLAB L465: %                 [~,columns] = size(newData);
# [~,columns] = size(newData);
# MATLAB L466: %                 tempData = cell(1,columns);
# tempData = cell(1,columns);
# MATLAB L467: %                 for i=1:columns
# for i=1:columns
# MATLAB L468: %                    tempData{i} = newData(:,i); 
# tempData{i} = newData(:,i);
# MATLAB L469: %                 end
# end
# MATLAB L470: %                 newData = tempData;
# newData = tempData;
# MATLAB L471: %             end
# end
# MATLAB L472:             
#
# MATLAB L473:             if(lambdaIndex>0 && lambdaIndex <= fitObj.numResults)
_matlab('if(lambdaIndex>0 && lambdaIndex <= fitObj.numResults)')
# MATLAB L474:                 b=fitObj.b{lambdaIndex}; %coefficient matrix
_matlab('b=fitObj.b{lambdaIndex}; %coefficient matrix')
# MATLAB L475:                 if(isempty(newData))
_matlab('if(isempty(newData))')
# MATLAB L476:                     [rows,~] = size(newData);
_matlab('[rows,~] = size(newData);')
# MATLAB L477:                     baseline=ones(rows,1);
_matlab('baseline=ones(rows,1);')
# MATLAB L478:                     lambdaData =  exp(b(1)*baseline);
_matlab('lambdaData =  exp(b(1)*baseline);')
# MATLAB L479:                 else
_matlab('else')
# MATLAB L480:                     if(isa(newData,'double')) %matrix, 1 column per coefficient
_matlab("if(isa(newData,'double')) %matrix, 1 column per coefficient")
# MATLAB L481:                         baseline=ones(length(newData),1);
_matlab('baseline=ones(length(newData),1);')
# MATLAB L482:                         [~,columns] = size(newData);
_matlab('[~,columns] = size(newData);')
# MATLAB L483:                         
#
# MATLAB L484:                         if(length(b)>=1)
_matlab('if(length(b)>=1)')
# MATLAB L485:                             lambdaData = exp(newData*b(1:end));
_matlab('lambdaData = exp(newData*b(1:end));')
# MATLAB L486:                             if(strcmp(fitObj.fitType{lambdaIndex},'poisson'))
_matlab("if(strcmp(fitObj.fitType{lambdaIndex},'poisson'))")
# MATLAB L487: %                                 lambdaData = exp(newData*b(1:end));
# lambdaData = exp(newData*b(1:end));
# MATLAB L488: %                                 lambdaData = exp(b(1) + newData*b(2:end));
# lambdaData = exp(b(1) + newData*b(2:end));
# MATLAB L489:                             else 
_matlab('else')
# MATLAB L490: %                                 lambdaData = exp(b(1) + newData*b(2:end));
# lambdaData = exp(b(1) + newData*b(2:end));
# MATLAB L491:                                 lambdaData = lambdaData./(1+lambdaData);
_matlab('lambdaData = lambdaData./(1+lambdaData);')
# MATLAB L492:                             end
_matlab('end')
# MATLAB L493: %                         else
# else
# MATLAB L494: %                             if(strcmp(fitObj.fitType{lambdaIndex},'poisson'))
# if(strcmp(fitObj.fitType{lambdaIndex},'poisson'))
# MATLAB L495: %                                 lambdaData = exp(b(1)*baseline);
# lambdaData = exp(b(1)*baseline);
# MATLAB L496: %                                 
#
# MATLAB L497: %                             else
# else
# MATLAB L498: %                                 lambdaData = exp(b(1)*baseline);
# lambdaData = exp(b(1)*baseline);
# MATLAB L499: %                                 lambdaData = lambdaData./(1+lambdaData);
# lambdaData = lambdaData./(1+lambdaData);
# MATLAB L500: %                             end
# end
# MATLAB L501:                         end
_matlab('end')
# MATLAB L502:                         lambdaData = lambdaData*fitObj.neuralSpikeTrain.sampleRate;
_matlab('lambdaData = lambdaData*fitObj.neuralSpikeTrain.sampleRate;')
# MATLAB L503:                     elseif(isa(newData,'cell')) % a cell array, each element is matrix of values for each coeff
_matlab("elseif(isa(newData,'cell')) % a cell array, each element is matrix of values for each coeff")
# MATLAB L504: %                         baseline=ones(size(newData{1})); %design matrix
# baseline=ones(size(newData{1})); %design matrix
# MATLAB L505:                             runSum=0;
runSum = 0
# MATLAB L506:                         for i=1:(length(newData)) %-fitObj.numHist(lambdaIndex))
_matlab('for i=1:(length(newData)) %-fitObj.numHist(lambdaIndex))')
# MATLAB L507: %                             if(i==1)
# if(i==1)
# MATLAB L508: %                                 runSum = b(1)*baseline;
# runSum = b(1)*baseline;
# MATLAB L509: %                             else
# else
# MATLAB L510:                                 if(i<=length(b))
_matlab('if(i<=length(b))')
# MATLAB L511:                                     runSum = runSum+b(i)*newData{i};
_matlab('runSum = runSum+b(i)*newData{i};')
# MATLAB L512:                                 end
_matlab('end')
# MATLAB L513: %                             end
# end
# MATLAB L514:                         end
_matlab('end')
# MATLAB L515:                         if(strcmp(fitObj.fitType{lambdaIndex},'poisson'))
_matlab("if(strcmp(fitObj.fitType{lambdaIndex},'poisson'))")
# MATLAB L516:                             lambdaData = exp(runSum);
_matlab('lambdaData = exp(runSum);')
# MATLAB L517:                             lambdaData = lambdaData*fitObj.neuralSpikeTrain.sampleRate;
_matlab('lambdaData = lambdaData*fitObj.neuralSpikeTrain.sampleRate;')
# MATLAB L518:                         else
_matlab('else')
# MATLAB L519:                             lambdaData = exp(runSum);
_matlab('lambdaData = exp(runSum);')
# MATLAB L520:                             lambdaData = lambdaData./(1+lambdaData);
_matlab('lambdaData = lambdaData./(1+lambdaData);')
# MATLAB L521:                             lambdaData = lambdaData*fitObj.neuralSpikeTrain.sampleRate;
_matlab('lambdaData = lambdaData*fitObj.neuralSpikeTrain.sampleRate;')
# MATLAB L522:                         end
_matlab('end')
# MATLAB L523:                     else
_matlab('else')
# MATLAB L524:                         error('New data must be cell or a matrix');
_matlab("error('New data must be cell or a matrix');")
# MATLAB L525:                     end
_matlab('end')
# MATLAB L526:                     
#
# MATLAB L527:                 end
_matlab('end')
# MATLAB L528:             else
_matlab('else')
# MATLAB L529:                 error('Index into fit params is incorrect');
_matlab("error('Index into fit params is incorrect');")
# MATLAB L530:             end
_matlab('end')
# MATLAB L531:             
#
# MATLAB L532:         end        
_matlab('end')
# MATLAB L533: %         function handle = plotHist(fitObj,fitNum)
# function handle = plotHist(fitObj,fitNum)
# MATLAB L534: %            % handle = plotHist(fitObj,fitNum)
# % handle = plotHist(fitObj,fitNum)
# MATLAB L535: %            % plots the history terms used in this FitResult object
# % plots the history terms used in this FitResult object
# MATLAB L536: %            % if fitNum is not specified then fitNum=1:numResults
# % if fitNum is not specified then fitNum=1:numResults
# MATLAB L537: %            if(nargin<2 || isempty(fitNum))
# if(nargin<2 || isempty(fitNum))
# MATLAB L538: %                fitNum = 1:fitObj.numResults;
# fitNum = 1:fitObj.numResults;
# MATLAB L539: %            end
# end
# MATLAB L540: %            
#
# MATLAB L541: %            for j=fitNum
# for j=fitNum
# MATLAB L542: %                if(j>0 && j <= fitObj.numResults)
# if(j>0 && j <= fitObj.numResults)
# MATLAB L543: %                     b=fitObj.b{j}; %coefficient matrix
# b=fitObj.b{j}; %coefficient matrix
# MATLAB L544: %                     startHistIndex = length(b)-fitObj.numHist(j)+1;
# startHistIndex = length(b)-fitObj.numHist(j)+1;
# MATLAB L545: %                     if(startHistIndex<length(b))
# if(startHistIndex<length(b))
# MATLAB L546: %                         bHist = b(startHistIndex:end);
# bHist = b(startHistIndex:end);
# MATLAB L547: %                         if(~isempty(fitObj.histObjects{j}))
# if(~isempty(fitObj.histObjects{j}))
# MATLAB L548: %                             windowTimes = fitObj.histObjects{j}.windowTimes;
# windowTimes = fitObj.histObjects{j}.windowTimes;
# MATLAB L549: %                             t=linspace(windowTimes(1),windowTimes(end),100)';
# t=linspace(windowTimes(1),windowTimes(end),100)';
# MATLAB L550: %                             histEffect = zeros(length(t),1);
# histEffect = zeros(length(t),1);
# MATLAB L551: %                             for i=1:length(windowTimes)-1
# for i=1:length(windowTimes)-1
# MATLAB L552: %                                 index = and(t>=windowTimes(i),t<=windowTimes(i+1));
# index = and(t>=windowTimes(i),t<=windowTimes(i+1));
# MATLAB L553: %                                 histEffect(index)=exp(-bHist(i))-1; %To offset zero coeffs
# histEffect(index)=exp(-bHist(i))-1; %To offset zero coeffs
# MATLAB L554: %                             end
# end
# MATLAB L555: %                         end
# end
# MATLAB L556: %                     else
# else
# MATLAB L557: %                         t=[0; 0.00001];
# t=[0; 0.00001];
# MATLAB L558: %                         histEffect =[0;0];
# histEffect =[0;0];
# MATLAB L559: %                     end
# end
# MATLAB L560: %                     if(j==fitNum(1))
# if(j==fitNum(1))
# MATLAB L561: %                         hSig = SignalObj(t,histEffect,'History','time','s','',fitObj.lambda.dataLabels{j});
# hSig = SignalObj(t,histEffect,'History','time','s','',fitObj.lambda.dataLabels{j});
# MATLAB L562: %                     else
# else
# MATLAB L563: %                         hSig = hSig.merge(SignalObj(t,histEffect,'History Effect','time','s','',fitObj.lambda.dataLabels{j}));
# hSig = hSig.merge(SignalObj(t,histEffect,'History Effect','time','s','',fitObj.lambda.dataLabels{j}));
# MATLAB L564: %                     end
# end
# MATLAB L565: %                end
# end
# MATLAB L566: %            end
# end
# MATLAB L567: %            N=floor(length(hSig.time)./70); B=ones(1,N)/N; A=1;
# N=floor(length(hSig.time)./70); B=ones(1,N)/N; A=1;
# MATLAB L568: %            handle=hSig.filtfilt(B,A).plot;    
# handle=hSig.filtfilt(B,A).plot;
# MATLAB L569: %         end
# end
# MATLAB L570:         function computePlotParams(fitObj,fitNum)
_matlab('function computePlotParams(fitObj,fitNum)')
# MATLAB L571:              if(nargin<2)
_matlab('if(nargin<2)')
# MATLAB L572:                fitNum = 1:fitObj.numResults;
_matlab('fitNum = 1:fitObj.numResults;')
# MATLAB L573:              end
_matlab('end')
# MATLAB L574:            index=find(sum(fitObj.flatMask,2)>0);%1:length(fitObj.flatMask(:,1));
_matlab('index=find(sum(fitObj.flatMask,2)>0);%1:length(fitObj.flatMask(:,1));')
# MATLAB L575:            %Only use the labels that appear in at least one fit
# Only use the labels that appear in at least one fit
# MATLAB L576:            %Otherwise that parameter was not present for any of the
# Otherwise that parameter was not present for any of the
# MATLAB L577:            %regressions and just takes up plot real-estate
# regressions and just takes up plot real-estate
# MATLAB L578:            
#
# MATLAB L579:            sigIndex=zeros(length(index),length(fitNum));
_matlab('sigIndex=zeros(length(index),length(fitNum));')
# MATLAB L580:            bAct = nan(length(index),length(fitNum));
_matlab('bAct = nan(length(index),length(fitNum));')
# MATLAB L581:            seAct= nan(length(index),length(fitNum));
_matlab('seAct= nan(length(index),length(fitNum));')
# MATLAB L582:            
#
# MATLAB L583:            for i=fitNum
_matlab('for i=fitNum')
# MATLAB L584:                %this indexing is to avoid extremely large se's from
# this indexing is to avoid extremely large se's from
# MATLAB L585:                %affecting plots
# affecting plots
# MATLAB L586:                criteria = find(fitObj.stats{i}.se'<100);
_matlab("criteria = find(fitObj.stats{i}.se'<100);")
# MATLAB L587:                %indicesForFit = find(fitObj.flatMask(index,i)==1);
# indicesForFit = find(fitObj.flatMask(index,i)==1);
# MATLAB L588:                indicesForFit = fitObj.indicesToUniqueLabels{i};
_matlab('indicesForFit = fitObj.indicesToUniqueLabels{i};')
# MATLAB L589:                bVals = fitObj.b{i}(criteria);
_matlab('bVals = fitObj.b{i}(criteria);')
# MATLAB L590:                bAct(indicesForFit(criteria),i) = bVals; %sorted according to uniqueLabels
_matlab('bAct(indicesForFit(criteria),i) = bVals; %sorted according to uniqueLabels')
# MATLAB L591:                seVals = fitObj.stats{i}.se(criteria)';
_matlab("seVals = fitObj.stats{i}.se(criteria)';")
# MATLAB L592:                seAct(indicesForFit(criteria),i)= seVals; %sorted according to uniqueLabels;
_matlab('seAct(indicesForFit(criteria),i)= seVals; %sorted according to uniqueLabels;')
# MATLAB L593:                temp = sign([bAct(:,i)-seAct(:,i) bAct(:,i)+seAct(:,i)]);
_matlab('temp = sign([bAct(:,i)-seAct(:,i) bAct(:,i)+seAct(:,i)]);')
# MATLAB L594:                productOfSigns = temp(:,1).*temp(:,2); %should be positive
_matlab('productOfSigns = temp(:,1).*temp(:,2); %should be positive')
# MATLAB L595:                sIndex=and(productOfSigns>0,seAct(:,i)~=0);
_matlab('sIndex=and(productOfSigns>0,seAct(:,i)~=0);')
# MATLAB L596:                sigIndex(:,i)=sIndex;
_matlab('sigIndex(:,i)=sIndex;')
# MATLAB L597:            end
_matlab('end')
# MATLAB L598:            fitObj.plotParams.bAct = bAct;
_matlab('fitObj.plotParams.bAct = bAct;')
# MATLAB L599:            fitObj.plotParams.seAct= seAct;
_matlab('fitObj.plotParams.seAct= seAct;')
# MATLAB L600:            fitObj.plotParams.sigIndex = sigIndex;
_matlab('fitObj.plotParams.sigIndex = sigIndex;')
# MATLAB L601:            fitObj.plotParams.xLabels  = cell(length(index),1);           
_matlab('fitObj.plotParams.xLabels  = cell(length(index),1);')
# MATLAB L602:            fitObj.plotParams.xLabels = fitObj.uniqueCovLabels;
_matlab('fitObj.plotParams.xLabels = fitObj.uniqueCovLabels;')
# MATLAB L603:                
#
# MATLAB L604: %            for i=1:(length(index))
# for i=1:(length(index))
# MATLAB L605: %                if(i==1)
# if(i==1)
# MATLAB L606: %                    fitObj.plotParams.xLabels{i} = 'baseline';
# fitObj.plotParams.xLabels{i} = 'baseline';
# MATLAB L607: %                    %text(i, 0,'baseline','interpreter','latex');
# %text(i, 0,'baseline','interpreter','latex');
# MATLAB L608: %                else
# else
# MATLAB L609: %                    fitObj.plotParams.xLabels{i} = fitObj.covLabels{index(i)-1};
# fitObj.plotParams.xLabels{i} = fitObj.covLabels{index(i)-1};
# MATLAB L610: %                    %text(i, 0,fitObj.covLabels{index(i)-1},'interpreter','latex');
# %text(i, 0,fitObj.covLabels{index(i)-1},'interpreter','latex');
# MATLAB L611: %                end
# end
# MATLAB L612: %            end
# end
# MATLAB L613:            tempVal =sum(fitObj.flatMask,2);
_matlab('tempVal =sum(fitObj.flatMask,2);')
# MATLAB L614:            fitObj.plotParams.numResultsCoeffPresent =tempVal(index); 
_matlab('fitObj.plotParams.numResultsCoeffPresent =tempVal(index);')
# MATLAB L615:         end
_matlab('end')
# MATLAB L616:         
#
# MATLAB L617:         function [coeffIndex, epochId,numEpochs] = getCoeffIndex(fitObj,fitNum,sortByEpoch)
_matlab('function [coeffIndex, epochId,numEpochs] = getCoeffIndex(fitObj,fitNum,sortByEpoch)')
# MATLAB L618:           if(nargin<3 || isempty(sortByEpoch))
_matlab('if(nargin<3 || isempty(sortByEpoch))')
# MATLAB L619:              sortByEpoch=0; 
sortByEpoch = 0
# MATLAB L620:           end
_matlab('end')
# MATLAB L621:           if(nargin<2 || isempty(fitNum))
_matlab('if(nargin<2 || isempty(fitNum))')
# MATLAB L622:               fitNum = 1:fitObj.numResults;
_matlab('fitNum = 1:fitObj.numResults;')
# MATLAB L623:           end
_matlab('end')
# MATLAB L624:           if(isempty(fitObj.plotParams))
_matlab('if(isempty(fitObj.plotParams))')
# MATLAB L625:                fitObj.computePlotParams;
_matlab('fitObj.computePlotParams;')
# MATLAB L626:           end   
_matlab('end')
# MATLAB L627:           [histIndex, epochId] = fitObj.getHistIndex(fitNum,sortByEpoch);
_matlab('[histIndex, epochId] = fitObj.getHistIndex(fitNum,sortByEpoch);')
# MATLAB L628:           allIndex = 1:length(fitObj.uniqueCovLabels);
_matlab('allIndex = 1:length(fitObj.uniqueCovLabels);')
# MATLAB L629:           
#
# MATLAB L630:           nonHistIndex = setdiff(allIndex,histIndex);
_matlab('nonHistIndex = setdiff(allIndex,histIndex);')
# MATLAB L631: %           nonNANIndex = find(sum(~isnan(fitObj.plotParams.bAct(:,fitNum)),2)>=1);
# nonNANIndex = find(sum(~isnan(fitObj.plotParams.bAct(:,fitNum)),2)>=1);
# MATLAB L632:           nonNANIndex=  allIndex;
_matlab('nonNANIndex=  allIndex;')
# MATLAB L633:           actCoeffIndex = nonHistIndex(ismember(nonHistIndex, nonNANIndex));
_matlab('actCoeffIndex = nonHistIndex(ismember(nonHistIndex, nonNANIndex));')
# MATLAB L634:           allCoeffTerms = fitObj.uniqueCovLabels(actCoeffIndex);
_matlab('allCoeffTerms = fitObj.uniqueCovLabels(actCoeffIndex);')
# MATLAB L635: %           coeffName = cell(size(allCoeffTerms));
# coeffName = cell(size(allCoeffTerms));
# MATLAB L636:           epochStartInd=regexp(allCoeffTerms,'_\{\d*\}','start'); 
_matlab("epochStartInd=regexp(allCoeffTerms,'_\\{\\d*\\}','start');")
# MATLAB L637:           epochEndInd=regexp(allCoeffTerms,'_\{\d*\}','end');
_matlab("epochEndInd=regexp(allCoeffTerms,'_\\{\\d*\\}','end');")
# MATLAB L638:          
#
# MATLAB L639:           allCoeffIndex = [];
_matlab('allCoeffIndex = [];')
# MATLAB L640:           nonEpochIndex=[];
_matlab('nonEpochIndex=[];')
# MATLAB L641: %           nonEmptyCoeffNameInd = [];
# nonEmptyCoeffNameInd = [];
# MATLAB L642:           epochsExist =0;
epochsExist = 0
# MATLAB L643:           for i=1:length(allCoeffTerms)
_matlab('for i=1:length(allCoeffTerms)')
# MATLAB L644:               if(~isempty(allCoeffTerms{i}))
_matlab('if(~isempty(allCoeffTerms{i}))')
# MATLAB L645:                 allCoeffIndex = [allCoeffIndex i];
_matlab('allCoeffIndex = [allCoeffIndex i];')
# MATLAB L646:                 
#
# MATLAB L647:                  if(~isempty(epochStartInd{i}))
_matlab('if(~isempty(epochStartInd{i}))')
# MATLAB L648: %                      nonEmptyCoeffNameInd = [nonEmptyCoeffNameInd i];
# nonEmptyCoeffNameInd = [nonEmptyCoeffNameInd i];
# MATLAB L649:                      epochsExist=1;
epochsExist = 1
# MATLAB L650:                      actStart = epochStartInd{i}+2;
_matlab('actStart = epochStartInd{i}+2;')
# MATLAB L651:                      actEnd   = epochEndInd{i}-1;
_matlab('actEnd   = epochEndInd{i}-1;')
# MATLAB L652:                      numEpoch(i) = str2num(allCoeffTerms{i}(actStart:actEnd));
_matlab('numEpoch(i) = str2num(allCoeffTerms{i}(actStart:actEnd));')
# MATLAB L653: %                      coeffName{i} =  allCoeffTerms{i}(1:actStart-3);
# coeffName{i} =  allCoeffTerms{i}(1:actStart-3);
# MATLAB L654:                      
#
# MATLAB L655:                      
#
# MATLAB L656:                  else
_matlab('else')
# MATLAB L657:                     nonEpochIndex = [nonEpochIndex i];
_matlab('nonEpochIndex = [nonEpochIndex i];')
# MATLAB L658:                     numEpoch(i) = 0; % make terms that only appear once part of epoch 0.
_matlab('numEpoch(i) = 0; % make terms that only appear once part of epoch 0.')
# MATLAB L659:                     
#
# MATLAB L660:                  end
_matlab('end')
# MATLAB L661:               end
_matlab('end')
# MATLAB L662:               
#
# MATLAB L663:           end
_matlab('end')
# MATLAB L664:         
#
# MATLAB L665: %           coeffName = coeffName(nonEmptyCoeffNameInd);
# coeffName = coeffName(nonEmptyCoeffNameInd);
# MATLAB L666:           if(epochsExist && ~sortByEpoch)
_matlab('if(epochsExist && ~sortByEpoch)')
# MATLAB L667:               totalEpochs = unique(numEpoch);
_matlab('totalEpochs = unique(numEpoch);')
# MATLAB L668:               coeffIndex = nonEpochIndex;
_matlab('coeffIndex = nonEpochIndex;')
# MATLAB L669:               if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L670:                   epochId=zeros(size(nonEpochIndex));
_matlab('epochId=zeros(size(nonEpochIndex));')
# MATLAB L671:               end
_matlab('end')
# MATLAB L672:               for i=1:length(totalEpochs)
_matlab('for i=1:length(totalEpochs)')
# MATLAB L673:                   if(totalEpochs(i)~=0)
_matlab('if(totalEpochs(i)~=0)')
# MATLAB L674:                     coeffIndex = [coeffIndex, find(numEpoch==totalEpochs(i))];
_matlab('coeffIndex = [coeffIndex, find(numEpoch==totalEpochs(i))];')
# MATLAB L675:                   
#
# MATLAB L676:                      if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L677:                         epochId = [epochId, totalEpochs(i)*ones(size(find(numEpoch==totalEpochs(i))))];
_matlab('epochId = [epochId, totalEpochs(i)*ones(size(find(numEpoch==totalEpochs(i))))];')
# MATLAB L678:                      end
_matlab('end')
# MATLAB L679:                   end
_matlab('end')
# MATLAB L680:               end
_matlab('end')
# MATLAB L681:               coeffIndex = actCoeffIndex(coeffIndex);
_matlab('coeffIndex = actCoeffIndex(coeffIndex);')
# MATLAB L682:           elseif(epochsExist && sortByEpoch)
_matlab('elseif(epochsExist && sortByEpoch)')
# MATLAB L683:               coeffIndex = actCoeffIndex(allCoeffIndex);
_matlab('coeffIndex = actCoeffIndex(allCoeffIndex);')
# MATLAB L684:               if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L685:                 epochId = numEpoch;
_matlab('epochId = numEpoch;')
# MATLAB L686:               end
_matlab('end')
# MATLAB L687:           else
_matlab('else')
# MATLAB L688:               coeffIndex = actCoeffIndex(allCoeffIndex);
_matlab('coeffIndex = actCoeffIndex(allCoeffIndex);')
# MATLAB L689:               if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L690:                 epochId = zeros(size(allCoeffIndex)); %no epochs exist so just create same index for all;
_matlab('epochId = zeros(size(allCoeffIndex)); %no epochs exist so just create same index for all;')
# MATLAB L691:               end
_matlab('end')
# MATLAB L692:           end
_matlab('end')
# MATLAB L693:           
#
# MATLAB L694: 
#
# MATLAB L695: %           nonNANIndex = find(sum(~isnan(fitObj.plotParams.bAct(:,fitNum)),2)>=1);
# nonNANIndex = find(sum(~isnan(fitObj.plotParams.bAct(:,fitNum)),2)>=1);
# MATLAB L696:           nonNANIndex = allIndex;
_matlab('nonNANIndex = allIndex;')
# MATLAB L697:           coeffIndex = coeffIndex(ismember(coeffIndex, nonNANIndex));
_matlab('coeffIndex = coeffIndex(ismember(coeffIndex, nonNANIndex));')
# MATLAB L698:             
#
# MATLAB L699:           if(nargout>2)
_matlab('if(nargout>2)')
# MATLAB L700:               numEpochs = length(unique(epochId));
_matlab('numEpochs = length(unique(epochId));')
# MATLAB L701:           end
_matlab('end')
# MATLAB L702:           
#
# MATLAB L703:         end
_matlab('end')
# MATLAB L704:         
#
# MATLAB L705:         function h=plotCoeffsWithoutHistory(fitObj,fitNum,sortByEpoch,plotSignificance)
_matlab('function h=plotCoeffsWithoutHistory(fitObj,fitNum,sortByEpoch,plotSignificance)')
# MATLAB L706:            if(nargin<4 || isempty(plotSignificance))
_matlab('if(nargin<4 || isempty(plotSignificance))')
# MATLAB L707:                plotSignificance=1;
plotSignificance = 1
# MATLAB L708:            end
_matlab('end')
# MATLAB L709:            if(nargin<3 || isempty(sortByEpoch))
_matlab('if(nargin<3 || isempty(sortByEpoch))')
# MATLAB L710:               sortByEpoch = 0; 
sortByEpoch = 0
# MATLAB L711:            end
_matlab('end')
# MATLAB L712:            if(nargin<2 || isempty(fitNum))
_matlab('if(nargin<2 || isempty(fitNum))')
# MATLAB L713:                fitNum = 1:fitObj.numResults;
_matlab('fitNum = 1:fitObj.numResults;')
# MATLAB L714:            end
_matlab('end')
# MATLAB L715:            if(isempty(fitObj.plotParams))
_matlab('if(isempty(fitObj.plotParams))')
# MATLAB L716:                fitObj.computePlotParams;
_matlab('fitObj.computePlotParams;')
# MATLAB L717:            end    
_matlab('end')
# MATLAB L718:                
#
# MATLAB L719:             
#
# MATLAB L720:           coeffIndex = fitObj.getCoeffIndex(fitNum,sortByEpoch);
_matlab('coeffIndex = fitObj.getCoeffIndex(fitNum,sortByEpoch);')
# MATLAB L721:           h=fitObj.plotCoeffs([],fitNum,[],plotSignificance,coeffIndex);
_matlab('h=fitObj.plotCoeffs([],fitNum,[],plotSignificance,coeffIndex);')
# MATLAB L722:           
#
# MATLAB L723:           
#
# MATLAB L724:             
#
# MATLAB L725:         end
_matlab('end')
# MATLAB L726:         
#
# MATLAB L727:         function [histIndex, epochId,numEpochs] = getHistIndex(fitObj,fitNum,sortByEpoch)
_matlab('function [histIndex, epochId,numEpochs] = getHistIndex(fitObj,fitNum,sortByEpoch)')
# MATLAB L728:             %if sortByEpoch==1 then we group all regression terms with the
# if sortByEpoch==1 then we group all regression terms with the
# MATLAB L729:             %same name one next to each other by epoch (time interval).
# same name one next to each other by epoch (time interval).
# MATLAB L730:             %Otherwise, we show all epoch one terms, followed by all epoch
# Otherwise, we show all epoch one terms, followed by all epoch
# MATLAB L731:             %2 terms, etc.
# 2 terms, etc.
# MATLAB L732:            if(nargin<3 || isempty(sortByEpoch))
_matlab('if(nargin<3 || isempty(sortByEpoch))')
# MATLAB L733:             sortByEpoch = 0;
sortByEpoch = 0
# MATLAB L734:            end
_matlab('end')
# MATLAB L735:           if(nargin<2 || isempty(fitNum))
_matlab('if(nargin<2 || isempty(fitNum))')
# MATLAB L736:               fitNum = 1:fitObj.numResults;
_matlab('fitNum = 1:fitObj.numResults;')
# MATLAB L737:           end
_matlab('end')
# MATLAB L738:           if(isempty(fitObj.plotParams))
_matlab('if(isempty(fitObj.plotParams))')
# MATLAB L739:                fitObj.computePlotParams;
_matlab('fitObj.computePlotParams;')
# MATLAB L740:           end  
_matlab('end')
# MATLAB L741:           
#
# MATLAB L742:           
#
# MATLAB L743:           allHistTerms = regexp(fitObj.uniqueCovLabels,'^[\w*');
_matlab("allHistTerms = regexp(fitObj.uniqueCovLabels,'^[\\w*');")
# MATLAB L744:           epochStartInd=regexp(fitObj.uniqueCovLabels,'\]_\{\d*\}','start'); 
_matlab("epochStartInd=regexp(fitObj.uniqueCovLabels,'\\]_\\{\\d*\\}','start');")
# MATLAB L745:           epochEndInd=regexp(fitObj.uniqueCovLabels,'\]_\{\d*\}','end');
_matlab("epochEndInd=regexp(fitObj.uniqueCovLabels,'\\]_\\{\\d*\\}','end');")
# MATLAB L746:           allHistIndex = [];
_matlab('allHistIndex = [];')
# MATLAB L747:           epochsExist =0;
epochsExist = 0
# MATLAB L748:           for i=1:length(allHistTerms)
_matlab('for i=1:length(allHistTerms)')
# MATLAB L749:               if(~isempty(allHistTerms{i}))
_matlab('if(~isempty(allHistTerms{i}))')
# MATLAB L750:                 allHistIndex = [allHistIndex i];
_matlab('allHistIndex = [allHistIndex i];')
# MATLAB L751:                  if(~isempty(epochStartInd{i}))
_matlab('if(~isempty(epochStartInd{i}))')
# MATLAB L752:                      epochsExist=1;
epochsExist = 1
# MATLAB L753:                      actStart = epochStartInd{i}+3;
_matlab('actStart = epochStartInd{i}+3;')
# MATLAB L754:                      actEnd   = epochEndInd{i}-1;
_matlab('actEnd   = epochEndInd{i}-1;')
# MATLAB L755:                      numEpoch(i) = str2num(fitObj.uniqueCovLabels{i}(actStart:actEnd));
_matlab('numEpoch(i) = str2num(fitObj.uniqueCovLabels{i}(actStart:actEnd));')
# MATLAB L756:                  end
_matlab('end')
# MATLAB L757:               end
_matlab('end')
# MATLAB L758:               
#
# MATLAB L759:           end
_matlab('end')
# MATLAB L760:           
#
# MATLAB L761:           if(epochsExist && ~sortByEpoch)
_matlab('if(epochsExist && ~sortByEpoch)')
# MATLAB L762:               totalEpochs = unique(numEpoch);
_matlab('totalEpochs = unique(numEpoch);')
# MATLAB L763:               histIndex = [];
_matlab('histIndex = [];')
# MATLAB L764:               if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L765:                   epochId=[];
_matlab('epochId=[];')
# MATLAB L766:               end
_matlab('end')
# MATLAB L767:               for i=1:length(totalEpochs)
_matlab('for i=1:length(totalEpochs)')
# MATLAB L768:                  histIndex = [histIndex, find(numEpoch==totalEpochs(i))]; 
_matlab('histIndex = [histIndex, find(numEpoch==totalEpochs(i))];')
# MATLAB L769:                  if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L770:                     epochId = [epochId, totalEpochs(i)*ones(size(find(numEpoch==totalEpochs(i))))];
_matlab('epochId = [epochId, totalEpochs(i)*ones(size(find(numEpoch==totalEpochs(i))))];')
# MATLAB L771:                  end
_matlab('end')
# MATLAB L772:               end
_matlab('end')
# MATLAB L773:           elseif(epochsExist && sortByEpoch)
_matlab('elseif(epochsExist && sortByEpoch)')
# MATLAB L774:               histIndex = allHistIndex;
_matlab('histIndex = allHistIndex;')
# MATLAB L775:               if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L776:                 epochId = numEpoch;
_matlab('epochId = numEpoch;')
# MATLAB L777:               end
_matlab('end')
# MATLAB L778:           else
_matlab('else')
# MATLAB L779:               histIndex = allHistIndex;
_matlab('histIndex = allHistIndex;')
# MATLAB L780:               if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L781:                 epochId = zeros(size(allHistIndex)); %no epochs exist so just create same index for all;
_matlab('epochId = zeros(size(allHistIndex)); %no epochs exist so just create same index for all;')
# MATLAB L782:               end
_matlab('end')
# MATLAB L783:           end
_matlab('end')
# MATLAB L784:              
#
# MATLAB L785:                    
#
# MATLAB L786: %           nonNANIndex = find(sum(~isnan(fitObj.plotParams.bAct(:,fitNum)),2)>=1);
# nonNANIndex = find(sum(~isnan(fitObj.plotParams.bAct(:,fitNum)),2)>=1);
# MATLAB L787: %           histIndex = histIndex(ismember(histIndex, nonNANIndex));
# histIndex = histIndex(ismember(histIndex, nonNANIndex));
# MATLAB L788: 
#
# MATLAB L789:           if(nargout>2)
_matlab('if(nargout>2)')
# MATLAB L790:               numEpochs = length(unique(epochId));
_matlab('numEpochs = length(unique(epochId));')
# MATLAB L791:           end
_matlab('end')
# MATLAB L792:             
#
# MATLAB L793:         end
_matlab('end')
# MATLAB L794:         
#
# MATLAB L795:         function [coeffMat, labels, SEMat] = getCoeffs(fitObj, fitNum)
_matlab('function [coeffMat, labels, SEMat] = getCoeffs(fitObj, fitNum)')
# MATLAB L796:              if(nargin<2 || isempty(fitNum))
_matlab('if(nargin<2 || isempty(fitNum))')
# MATLAB L797:                 fitNum =1:fitObj.numResults;
_matlab('fitNum =1:fitObj.numResults;')
# MATLAB L798:             end
_matlab('end')
# MATLAB L799:             sortByEpoch = 0; % Make sure we have different time series if the history is divided into epochs;
sortByEpoch = 0
# MATLAB L800:             [coeffIndex, epochId, numEpochs] = fitObj.getCoeffIndex(fitNum,sortByEpoch);
_matlab('[coeffIndex, epochId, numEpochs] = fitObj.getCoeffIndex(fitNum,sortByEpoch);')
# MATLAB L801:             epochNums = unique(epochId);
_matlab('epochNums = unique(epochId);')
# MATLAB L802:             
#
# MATLAB L803:             
#
# MATLAB L804:              coeffStrings = fitObj.uniqueCovLabels(coeffIndex);
_matlab('coeffStrings = fitObj.uniqueCovLabels(coeffIndex);')
# MATLAB L805:             baseStringEndIndex =regexp(coeffStrings,'_\{\d*\}','start');
_matlab("baseStringEndIndex =regexp(coeffStrings,'_\\{\\d*\\}','start');")
# MATLAB L806:             
#
# MATLAB L807:             for i=1:length(baseStringEndIndex)
_matlab('for i=1:length(baseStringEndIndex)')
# MATLAB L808:                 if(~isempty(baseStringEndIndex{i}))
_matlab('if(~isempty(baseStringEndIndex{i}))')
# MATLAB L809:                     baseStrings{i} = coeffStrings{i}(1:baseStringEndIndex{i}-1);
_matlab('baseStrings{i} = coeffStrings{i}(1:baseStringEndIndex{i}-1);')
# MATLAB L810:                 else
_matlab('else')
# MATLAB L811:                     baseStrings{i} = coeffStrings{i};
_matlab('baseStrings{i} = coeffStrings{i};')
# MATLAB L812:                 end
_matlab('end')
# MATLAB L813:             end
_matlab('end')
# MATLAB L814:             uniqueCoeffs = unique(baseStrings);
_matlab('uniqueCoeffs = unique(baseStrings);')
# MATLAB L815:             
#
# MATLAB L816:             for i=1:length(uniqueCoeffs)
_matlab('for i=1:length(uniqueCoeffs)')
# MATLAB L817:                coeffStrIndex{i} = coeffIndex(strcmp(baseStrings,uniqueCoeffs{i})); 
_matlab('coeffStrIndex{i} = coeffIndex(strcmp(baseStrings,uniqueCoeffs{i}));')
# MATLAB L818:                if(min(epochId)==0)
_matlab('if(min(epochId)==0)')
# MATLAB L819:                 epochIndices{i} = epochId(strcmp(baseStrings,uniqueCoeffs{i}))+1;
_matlab('epochIndices{i} = epochId(strcmp(baseStrings,uniqueCoeffs{i}))+1;')
# MATLAB L820:                else 
_matlab('else')
# MATLAB L821:                 epochIndices{i} = epochId(strcmp(baseStrings,uniqueCoeffs{i}));
_matlab('epochIndices{i} = epochId(strcmp(baseStrings,uniqueCoeffs{i}));')
# MATLAB L822:                end
_matlab('end')
# MATLAB L823:             end
_matlab('end')
# MATLAB L824:             
#
# MATLAB L825: %             
#
# MATLAB L826: %             for i=1:numEpochs
# for i=1:numEpochs
# MATLAB L827: %                 epochIndices{i} = find(epochId==epochNums(i));
# epochIndices{i} = find(epochId==epochNums(i));
# MATLAB L828: %                 epochLength(i) = length(epochIndices{i});
# epochLength(i) = length(epochIndices{i});
# MATLAB L829: %             end
# end
# MATLAB L830:             
#
# MATLAB L831:           
#
# MATLAB L832:             
#
# MATLAB L833:             coeffIndMat= nan(length(uniqueCoeffs),numEpochs);
_matlab('coeffIndMat= nan(length(uniqueCoeffs),numEpochs);')
# MATLAB L834:             
#
# MATLAB L835:             labels = cell(size(coeffIndMat));
_matlab('labels = cell(size(coeffIndMat));')
# MATLAB L836:             for i=1:length(uniqueCoeffs)
_matlab('for i=1:length(uniqueCoeffs)')
# MATLAB L837:                coeffIndMat(i,epochIndices{i}) = coeffStrIndex{i};
_matlab('coeffIndMat(i,epochIndices{i}) = coeffStrIndex{i};')
# MATLAB L838:                labels(i,epochIndices{i}) = fitObj.uniqueCovLabels(coeffStrIndex{i});
_matlab('labels(i,epochIndices{i}) = fitObj.uniqueCovLabels(coeffStrIndex{i});')
# MATLAB L839:             end
_matlab('end')
# MATLAB L840:             
#
# MATLAB L841:             
#
# MATLAB L842: %             for i=1:numEpochs
# for i=1:numEpochs
# MATLAB L843: %                coeffIndMat(1:epochLength(i),i) = coeffIndex(epochIndices{i});
# coeffIndMat(1:epochLength(i),i) = coeffIndex(epochIndices{i});
# MATLAB L844: %                labels(1:epochLength(i),i) = fitObj.uniqueCovLabels(coeffIndMat(1:epochLength(i),i));
# labels(1:epochLength(i),i) = fitObj.uniqueCovLabels(coeffIndMat(1:epochLength(i),i));
# MATLAB L845: %             end
# end
# MATLAB L846:             
#
# MATLAB L847:             
#
# MATLAB L848:             
#
# MATLAB L849:             if(length(fitNum)>1)
_matlab('if(length(fitNum)>1)')
# MATLAB L850:                 coeffMat = nan(size(coeffIndMat,1),size(coeffIndMat,2), length(fitNum));
_matlab('coeffMat = nan(size(coeffIndMat,1),size(coeffIndMat,2), length(fitNum));')
# MATLAB L851:                 SEMat    = nan(size(coeffIndMat,1),size(coeffIndMat,2), length(fitNum));
_matlab('SEMat    = nan(size(coeffIndMat,1),size(coeffIndMat,2), length(fitNum));')
# MATLAB L852:                 for i=1:length(fitNum)
_matlab('for i=1:length(fitNum)')
# MATLAB L853:                     for j=1:length(uniqueCoeffs)
_matlab('for j=1:length(uniqueCoeffs)')
# MATLAB L854:                         bTemp=fitObj.plotParams.bAct(coeffStrIndex{j},i);    
_matlab('bTemp=fitObj.plotParams.bAct(coeffStrIndex{j},i);')
# MATLAB L855:                         seTemp=fitObj.plotParams.seAct(coeffStrIndex{j},i);    
_matlab('seTemp=fitObj.plotParams.seAct(coeffStrIndex{j},i);')
# MATLAB L856:                         coeffMat(j,epochIndices{j},i) = bTemp';
_matlab("coeffMat(j,epochIndices{j},i) = bTemp';")
# MATLAB L857:                         SEMat(j,epochIndices{j},i) = seTemp';
_matlab("SEMat(j,epochIndices{j},i) = seTemp';")
# MATLAB L858:                     end
_matlab('end')
# MATLAB L859:                 end
_matlab('end')
# MATLAB L860:             else
_matlab('else')
# MATLAB L861:                 coeffMat = nan(size(coeffIndMat,1),size(coeffIndMat,2));
_matlab('coeffMat = nan(size(coeffIndMat,1),size(coeffIndMat,2));')
# MATLAB L862:                 SEMat    = nan(size(coeffIndMat,1),size(coeffIndMat,2));
_matlab('SEMat    = nan(size(coeffIndMat,1),size(coeffIndMat,2));')
# MATLAB L863:                 for j=1:length(uniqueCoeffs)
_matlab('for j=1:length(uniqueCoeffs)')
# MATLAB L864:                     bTemp=fitObj.plotParams.bAct(coeffStrIndex{j},fitNum); 
_matlab('bTemp=fitObj.plotParams.bAct(coeffStrIndex{j},fitNum);')
# MATLAB L865:                     seTemp = fitObj.plotParams.seAct(coeffStrIndex{j},fitNum); 
_matlab('seTemp = fitObj.plotParams.seAct(coeffStrIndex{j},fitNum);')
# MATLAB L866:                     coeffMat(j,epochIndices{j}) = bTemp';
_matlab("coeffMat(j,epochIndices{j}) = bTemp';")
# MATLAB L867:                     SEMat(j,epochIndices{j}) = seTemp';
_matlab("SEMat(j,epochIndices{j}) = seTemp';")
# MATLAB L868:                 end
_matlab('end')
# MATLAB L869: 
#
# MATLAB L870:             end
_matlab('end')
# MATLAB L871:             
#
# MATLAB L872:         end
_matlab('end')
# MATLAB L873:         
#
# MATLAB L874:         function [histMat, labels, SEMat] = getHistCoeffs(fitObj,fitNum)
_matlab('function [histMat, labels, SEMat] = getHistCoeffs(fitObj,fitNum)')
# MATLAB L875:               if(nargin<2 || isempty(fitNum))
_matlab('if(nargin<2 || isempty(fitNum))')
# MATLAB L876:                 fitNum =1:fitObj.numResults;
_matlab('fitNum =1:fitObj.numResults;')
# MATLAB L877:             end
_matlab('end')
# MATLAB L878:             sortByEpoch = 0; % Make sure we have different time series if the history is divided into epochs;
sortByEpoch = 0
# MATLAB L879:             [histIndex, epochId, numEpochs] = fitObj.getHistIndex(fitNum,sortByEpoch);
_matlab('[histIndex, epochId, numEpochs] = fitObj.getHistIndex(fitNum,sortByEpoch);')
# MATLAB L880:             epochNums = unique(epochId);
_matlab('epochNums = unique(epochId);')
# MATLAB L881:             
#
# MATLAB L882:             
#
# MATLAB L883:             histcoeffStrings = fitObj.uniqueCovLabels(histIndex);
_matlab('histcoeffStrings = fitObj.uniqueCovLabels(histIndex);')
# MATLAB L884:             baseStringEndIndex =regexp(histcoeffStrings,'_\{\d*\}','start');
_matlab("baseStringEndIndex =regexp(histcoeffStrings,'_\\{\\d*\\}','start');")
# MATLAB L885:             baseStrings = cell(length(baseStringEndIndex),1);
_matlab('baseStrings = cell(length(baseStringEndIndex),1);')
# MATLAB L886:             for i=1:length(baseStringEndIndex)
_matlab('for i=1:length(baseStringEndIndex)')
# MATLAB L887:                 if(~isempty(baseStringEndIndex{i}))
_matlab('if(~isempty(baseStringEndIndex{i}))')
# MATLAB L888:                     baseStrings{i} = histcoeffStrings{i}(1:baseStringEndIndex{i}-1);
_matlab('baseStrings{i} = histcoeffStrings{i}(1:baseStringEndIndex{i}-1);')
# MATLAB L889:                 else
_matlab('else')
# MATLAB L890:                     baseStrings{i} = histcoeffStrings{i};
_matlab('baseStrings{i} = histcoeffStrings{i};')
# MATLAB L891:                 end
_matlab('end')
# MATLAB L892:             end
_matlab('end')
# MATLAB L893:             uniqueCoeffs = unique(baseStrings);
_matlab('uniqueCoeffs = unique(baseStrings);')
# MATLAB L894:             
#
# MATLAB L895:             for i=1:length(uniqueCoeffs)
_matlab('for i=1:length(uniqueCoeffs)')
# MATLAB L896:                histcoeffStrIndex{i} = histIndex(strcmp(baseStrings,uniqueCoeffs{i})); 
_matlab('histcoeffStrIndex{i} = histIndex(strcmp(baseStrings,uniqueCoeffs{i}));')
# MATLAB L897:                if(min(epochId)==0)
_matlab('if(min(epochId)==0)')
# MATLAB L898:                 epochIndices{i} = epochId(strcmp(baseStrings,uniqueCoeffs{i}))+1;
_matlab('epochIndices{i} = epochId(strcmp(baseStrings,uniqueCoeffs{i}))+1;')
# MATLAB L899:                else 
_matlab('else')
# MATLAB L900:                 epochIndices{i} = epochId(strcmp(baseStrings,uniqueCoeffs{i}));
_matlab('epochIndices{i} = epochId(strcmp(baseStrings,uniqueCoeffs{i}));')
# MATLAB L901:                end
_matlab('end')
# MATLAB L902:             end
_matlab('end')
# MATLAB L903:             
#
# MATLAB L904: %             
#
# MATLAB L905: %             for i=1:numEpochs
# for i=1:numEpochs
# MATLAB L906: %                 epochIndices{i} = find(epochId==epochNums(i));
# epochIndices{i} = find(epochId==epochNums(i));
# MATLAB L907: %                 epochLength(i) = length(epochIndices{i});
# epochLength(i) = length(epochIndices{i});
# MATLAB L908: %             end
# end
# MATLAB L909:             
#
# MATLAB L910:           
#
# MATLAB L911:             
#
# MATLAB L912:             histcoeffIndMat= nan(length(uniqueCoeffs),numEpochs);
_matlab('histcoeffIndMat= nan(length(uniqueCoeffs),numEpochs);')
# MATLAB L913:             labels = cell(size(histcoeffIndMat));
_matlab('labels = cell(size(histcoeffIndMat));')
# MATLAB L914: %             SEMat = nan(length(uniqueCoeffs),numEpochs);
# SEMat = nan(length(uniqueCoeffs),numEpochs);
# MATLAB L915:             for i=1:length(uniqueCoeffs)
_matlab('for i=1:length(uniqueCoeffs)')
# MATLAB L916:                histcoeffIndMat(i,epochIndices{i}) = histcoeffStrIndex{i};
_matlab('histcoeffIndMat(i,epochIndices{i}) = histcoeffStrIndex{i};')
# MATLAB L917:                labels(i,epochIndices{i}) = fitObj.uniqueCovLabels(histcoeffStrIndex{i});
_matlab('labels(i,epochIndices{i}) = fitObj.uniqueCovLabels(histcoeffStrIndex{i});')
# MATLAB L918: %                SEMat(i,epochIndices{i}) = fitObj.se;
# SEMat(i,epochIndices{i}) = fitObj.se;
# MATLAB L919:             end
_matlab('end')
# MATLAB L920:             
#
# MATLAB L921:             
#
# MATLAB L922: %             for i=1:numEpochs
# for i=1:numEpochs
# MATLAB L923: %                coeffIndMat(1:epochLength(i),i) = coeffIndex(epochIndices{i});
# coeffIndMat(1:epochLength(i),i) = coeffIndex(epochIndices{i});
# MATLAB L924: %                labels(1:epochLength(i),i) = fitObj.uniqueCovLabels(coeffIndMat(1:epochLength(i),i));
# labels(1:epochLength(i),i) = fitObj.uniqueCovLabels(coeffIndMat(1:epochLength(i),i));
# MATLAB L925: %             end
# end
# MATLAB L926:             
#
# MATLAB L927:             
#
# MATLAB L928:             
#
# MATLAB L929:             if(length(fitNum)>1)
_matlab('if(length(fitNum)>1)')
# MATLAB L930:                 histMat = nan(size(histcoeffIndMat,1),size(histcoeffIndMat,2), length(fitNum));
_matlab('histMat = nan(size(histcoeffIndMat,1),size(histcoeffIndMat,2), length(fitNum));')
# MATLAB L931:                 SEMat   = nan(size(histcoeffIndMat,1),size(histcoeffIndMat,2), length(fitNum));
_matlab('SEMat   = nan(size(histcoeffIndMat,1),size(histcoeffIndMat,2), length(fitNum));')
# MATLAB L932:                 for i=fitNum
_matlab('for i=fitNum')
# MATLAB L933:                     for j=1:length(uniqueCoeffs)
_matlab('for j=1:length(uniqueCoeffs)')
# MATLAB L934:                         bTemp=fitObj.plotParams.bAct(histcoeffStrIndex{j},i);    
_matlab('bTemp=fitObj.plotParams.bAct(histcoeffStrIndex{j},i);')
# MATLAB L935:                         seTemp = fitObj.plotParams.seAct(histcoeffStrIndex{j},i);    
_matlab('seTemp = fitObj.plotParams.seAct(histcoeffStrIndex{j},i);')
# MATLAB L936:                         histMat(j,epochIndices{j},i) = bTemp';
_matlab("histMat(j,epochIndices{j},i) = bTemp';")
# MATLAB L937:                         SEMat(j,epochIndices{j},i) = seTemp';
_matlab("SEMat(j,epochIndices{j},i) = seTemp';")
# MATLAB L938:                     end
_matlab('end')
# MATLAB L939:                 end
_matlab('end')
# MATLAB L940:             else
_matlab('else')
# MATLAB L941:                 histMat = nan(size(histcoeffIndMat,1),size(histcoeffIndMat,2));
_matlab('histMat = nan(size(histcoeffIndMat,1),size(histcoeffIndMat,2));')
# MATLAB L942:                 SEMat   = nan(size(histcoeffIndMat,1),size(histcoeffIndMat,2));
_matlab('SEMat   = nan(size(histcoeffIndMat,1),size(histcoeffIndMat,2));')
# MATLAB L943:                 for j=1:length(uniqueCoeffs)
_matlab('for j=1:length(uniqueCoeffs)')
# MATLAB L944:                     bTemp=fitObj.plotParams.bAct(histcoeffStrIndex{j},fitNum);       
_matlab('bTemp=fitObj.plotParams.bAct(histcoeffStrIndex{j},fitNum);')
# MATLAB L945:                     seTemp=fitObj.plotParams.seAct(histcoeffStrIndex{j},fitNum);
_matlab('seTemp=fitObj.plotParams.seAct(histcoeffStrIndex{j},fitNum);')
# MATLAB L946:                     histMat(j,epochIndices{j}) = bTemp';
_matlab("histMat(j,epochIndices{j}) = bTemp';")
# MATLAB L947:                     SEMat(j,epochIndices{j}) = seTemp';
_matlab("SEMat(j,epochIndices{j}) = seTemp';")
# MATLAB L948:                 end
_matlab('end')
# MATLAB L949: 
#
# MATLAB L950:             end
_matlab('end')
# MATLAB L951:             
#
# MATLAB L952:             
#
# MATLAB L953: %             
#
# MATLAB L954: %             if(nargin<2 || isempty(fitNum))
# if(nargin<2 || isempty(fitNum))
# MATLAB L955: %                 fitNum =1:fitObj.numResults;
# fitNum =1:fitObj.numResults;
# MATLAB L956: %             end
# end
# MATLAB L957: %             sortByEpoch = 0; % Make sure we have different time series if the history is divided into epochs;
# sortByEpoch = 0; % Make sure we have different time series if the history is divided into epochs;
# MATLAB L958: %             [histIndex, epochId, numEpochs] = fitObj.getHistIndex(fitNum,sortByEpoch);
# [histIndex, epochId, numEpochs] = fitObj.getHistIndex(fitNum,sortByEpoch);
# MATLAB L959: %             epochNums = unique(epochId);
# epochNums = unique(epochId);
# MATLAB L960: %             for i=1:numEpochs
# for i=1:numEpochs
# MATLAB L961: %                 epochIndices{i} = find(epochId==epochNums(i));
# epochIndices{i} = find(epochId==epochNums(i));
# MATLAB L962: %                 epochLength(i) = length(epochIndices{i});
# epochLength(i) = length(epochIndices{i});
# MATLAB L963: %             end
# end
# MATLAB L964: %             
#
# MATLAB L965: %             histIndMat= nan(max(epochLength),numEpochs);
# histIndMat= nan(max(epochLength),numEpochs);
# MATLAB L966: %             labels = cell(size(histIndMat));
# labels = cell(size(histIndMat));
# MATLAB L967: %             for i=1:numEpochs
# for i=1:numEpochs
# MATLAB L968: %                histIndMat(1:epochLength(i),i) = histIndex(epochIndices{i});
# histIndMat(1:epochLength(i),i) = histIndex(epochIndices{i});
# MATLAB L969: %                labels(1:epochLength(i),i) = fitObj.uniqueCovLabels(histIndMat(1:epochLength(i),i));
# labels(1:epochLength(i),i) = fitObj.uniqueCovLabels(histIndMat(1:epochLength(i),i));
# MATLAB L970: %             end
# end
# MATLAB L971: %             
#
# MATLAB L972: %             
#
# MATLAB L973: %             
#
# MATLAB L974: %             if(length(fitNum)>1)
# if(length(fitNum)>1)
# MATLAB L975: %                 histMat = nan(size(histIndMat,1),size(histIndMat,2), length(fitNum));
# histMat = nan(size(histIndMat,1),size(histIndMat,2), length(fitNum));
# MATLAB L976: %                 for i=1:length(fitNum)
# for i=1:length(fitNum)
# MATLAB L977: %                     for j=1:numEpochs
# for j=1:numEpochs
# MATLAB L978: %                         bTemp=fitObj.plotParams.bAct(epochIndices{j},i);                
# bTemp=fitObj.plotParams.bAct(epochIndices{j},i);
# MATLAB L979: %                         histMat(1:epochLength(j),j,i) = bTemp;
# histMat(1:epochLength(j),j,i) = bTemp;
# MATLAB L980: %                     end
# end
# MATLAB L981: %                 end
# end
# MATLAB L982: %             else
# else
# MATLAB L983: %                 histMat = nan(size(histIndMat,1),size(histIndMat,2));
# histMat = nan(size(histIndMat,1),size(histIndMat,2));
# MATLAB L984: %                 
#
# MATLAB L985: %                 for j=1:numEpochs
# for j=1:numEpochs
# MATLAB L986: %                     bTemp=fitObj.plotParams.bAct(epochIndices{j},fitNum);                
# bTemp=fitObj.plotParams.bAct(epochIndices{j},fitNum);
# MATLAB L987: %                     histMat(1:epochLength(j),j) = bTemp;
# histMat(1:epochLength(j),j) = bTemp;
# MATLAB L988: %                 end
# end
# MATLAB L989: % 
#
# MATLAB L990: %             end
# end
# MATLAB L991:             
#
# MATLAB L992:         end
_matlab('end')
# MATLAB L993:         function h=plotHistCoeffs(fitObj,fitNum,sortByEpoch,plotSignificance)
_matlab('function h=plotHistCoeffs(fitObj,fitNum,sortByEpoch,plotSignificance)')
# MATLAB L994:           if(nargin<4 || isempty(plotSignificance))
_matlab('if(nargin<4 || isempty(plotSignificance))')
# MATLAB L995:             plotSignificance=1;
plotSignificance = 1
# MATLAB L996:           end
_matlab('end')
# MATLAB L997:           if(nargin<3 || isempty(sortByEpoch))
_matlab('if(nargin<3 || isempty(sortByEpoch))')
# MATLAB L998:              sortByEpoch=0; 
sortByEpoch = 0
# MATLAB L999:           end
_matlab('end')
# MATLAB L1000:           if(nargin<2 || isempty(fitNum))
_matlab('if(nargin<2 || isempty(fitNum))')
# MATLAB L1001:               fitNum = 1:fitObj.numResults;
_matlab('fitNum = 1:fitObj.numResults;')
# MATLAB L1002:           end
_matlab('end')
# MATLAB L1003:           if(isempty(fitObj.plotParams))
_matlab('if(isempty(fitObj.plotParams))')
# MATLAB L1004:                fitObj.computePlotParams;
_matlab('fitObj.computePlotParams;')
# MATLAB L1005:           end  
_matlab('end')
# MATLAB L1006:           histIndex = fitObj.getHistIndex(fitNum,sortByEpoch);
_matlab('histIndex = fitObj.getHistIndex(fitNum,sortByEpoch);')
# MATLAB L1007:           h=fitObj.plotCoeffs([],fitNum,[],plotSignificance,histIndex);
_matlab('h=fitObj.plotCoeffs([],fitNum,[],plotSignificance,histIndex);')
# MATLAB L1008:         end
_matlab('end')
# MATLAB L1009:             
#
# MATLAB L1010:             
#
# MATLAB L1011:         function h=plotCoeffs(fitObj,handle,fitNum,plotProps,plotSignificance,subIndex)
_matlab('function h=plotCoeffs(fitObj,handle,fitNum,plotProps,plotSignificance,subIndex)')
# MATLAB L1012:            % h=plotCoeffs(fitObj,handle,fitNum,plotProps,plotSignificance)
# h=plotCoeffs(fitObj,handle,fitNum,plotProps,plotSignificance)
# MATLAB L1013:            % plots the GLM coefficients for each fit along with the
# plots the GLM coefficients for each fit along with the
# MATLAB L1014:            % confidence intervals. 
# confidence intervals.
# MATLAB L1015:            % fitNum: number of the fit to plot. If not specified, all are
# fitNum: number of the fit to plot. If not specified, all are
# MATLAB L1016:            %         plotted.
# plotted.
# MATLAB L1017:            % plotProps: properties to use for the making the plot
# plotProps: properties to use for the making the plot
# MATLAB L1018:            % plotSignificance: If 1 then an asterix (*) is place above
# plotSignificance: If 1 then an asterix (*) is place above
# MATLAB L1019:            %                   parameters that are statistically different
# parameters that are statistically different
# MATLAB L1020:            %                   from zero with alpha=5%.
# from zero with alpha=5%.
# MATLAB L1021:            
#
# MATLAB L1022:            
#
# MATLAB L1023:            if(nargin<5 || isempty(plotSignificance))
_matlab('if(nargin<5 || isempty(plotSignificance))')
# MATLAB L1024:                plotSignificance = 1;
plotSignificance = 1
# MATLAB L1025:            end
_matlab('end')
# MATLAB L1026:            
#
# MATLAB L1027:            if(nargin<4 || isempty(plotProps))
_matlab('if(nargin<4 || isempty(plotProps))')
# MATLAB L1028:                plotProps = [];
_matlab('plotProps = [];')
# MATLAB L1029:            end
_matlab('end')
# MATLAB L1030:            
#
# MATLAB L1031:            if(nargin<3 || isempty(fitNum))
_matlab('if(nargin<3 || isempty(fitNum))')
# MATLAB L1032:                fitNum = 1:fitObj.numResults;
_matlab('fitNum = 1:fitObj.numResults;')
# MATLAB L1033:            end
_matlab('end')
# MATLAB L1034:            
#
# MATLAB L1035:            if(nargin<2 || isempty(handle))
_matlab('if(nargin<2 || isempty(handle))')
# MATLAB L1036:                handle=gca;
_matlab('handle=gca;')
# MATLAB L1037:            end
_matlab('end')
# MATLAB L1038:            
#
# MATLAB L1039:            if(isempty(fitObj.plotParams))
_matlab('if(isempty(fitObj.plotParams))')
# MATLAB L1040:                fitObj.computePlotParams;
_matlab('fitObj.computePlotParams;')
# MATLAB L1041:            end
_matlab('end')
# MATLAB L1042:            
#
# MATLAB L1043:            if(nargin<6 || isempty(subIndex))
_matlab('if(nargin<6 || isempty(subIndex))')
# MATLAB L1044:               subIndex = [fitObj.getHistIndex, fitObj.getCoeffIndex];
_matlab('subIndex = [fitObj.getHistIndex, fitObj.getCoeffIndex];')
# MATLAB L1045:            end
_matlab('end')
# MATLAB L1046:            
#
# MATLAB L1047:            bAct = fitObj.getPlotParams.bAct(subIndex,fitNum);
_matlab('bAct = fitObj.getPlotParams.bAct(subIndex,fitNum);')
# MATLAB L1048:            seAct= fitObj.getPlotParams.seAct(subIndex,fitNum);
_matlab('seAct= fitObj.getPlotParams.seAct(subIndex,fitNum);')
# MATLAB L1049:            sigIndex=fitObj.getPlotParams.sigIndex(subIndex,fitNum);
_matlab('sigIndex=fitObj.getPlotParams.sigIndex(subIndex,fitNum);')
# MATLAB L1050:            
#
# MATLAB L1051:            if(~isempty(plotProps))
_matlab('if(~isempty(plotProps))')
# MATLAB L1052:                for i=1:length(fitNum)
_matlab('for i=1:length(fitNum)')
# MATLAB L1053:                     h(i)=errorbar(handle,1:length(subIndex),bAct(:,i),seAct(:,i),plotProps{i}); hold on;
_matlab('h(i)=errorbar(handle,1:length(subIndex),bAct(:,i),seAct(:,i),plotProps{i}); hold on;')
# MATLAB L1054:                     set(h(i), 'LineStyle', 'none', 'Marker', '.');%,...
_matlab("set(h(i), 'LineStyle', 'none', 'Marker', '.');%,...")
# MATLAB L1055: %                         'Linewidth',1,'Marker','o','MarkerSize',6);
# 'Linewidth',1,'Marker','o','MarkerSize',6);
# MATLAB L1056:                     currColor = get(h(i),'Color');
_matlab("currColor = get(h(i),'Color');")
# MATLAB L1057:                     set(h(i),'MarkerEdgeColor',currColor,'MarkerFaceColor',currColor); 
_matlab("set(h(i),'MarkerEdgeColor',currColor,'MarkerFaceColor',currColor);")
# MATLAB L1058: %                     hE= get(h(i),'Children');
# hE= get(h(i),'Children');
# MATLAB L1059: %                     errorbarXData = get(hE(2),'XData');
# errorbarXData = get(hE(2),'XData');
# MATLAB L1060: %                     errorbarXData(4:9:end) = errorbarXData(1:9:end) - 0.2;
# errorbarXData(4:9:end) = errorbarXData(1:9:end) - 0.2;
# MATLAB L1061: %                     errorbarXData(7:9:end) = errorbarXData(1:9:end) - 0.2;
# errorbarXData(7:9:end) = errorbarXData(1:9:end) - 0.2;
# MATLAB L1062: %                     errorbarXData(5:9:end) = errorbarXData(1:9:end) + 0.2;
# errorbarXData(5:9:end) = errorbarXData(1:9:end) + 0.2;
# MATLAB L1063: %                     errorbarXData(8:9:end) = errorbarXData(1:9:end) + 0.2;
# errorbarXData(8:9:end) = errorbarXData(1:9:end) + 0.2;
# MATLAB L1064: %                     set(hE(2), 'XData', errorbarXData);
# set(hE(2), 'XData', errorbarXData);
# MATLAB L1065:                end
_matlab('end')
# MATLAB L1066:            else
_matlab('else')
# MATLAB L1067:                Xaxis=repmat(1:length(bAct(:,1)),[length(bAct(1,:)) 1]);
_matlab('Xaxis=repmat(1:length(bAct(:,1)),[length(bAct(1,:)) 1]);')
# MATLAB L1068:                h=errorbar(handle,Xaxis',bAct,seAct,'.');%strcat('.',FitResult.colors{mod(i-1,length(FitResult.colors))+1})); 
_matlab("h=errorbar(handle,Xaxis',bAct,seAct,'.');%strcat('.',FitResult.colors{mod(i-1,length(FitResult.colors))+1}));")
# MATLAB L1069:                set(h, 'LineStyle', 'none', 'Marker', '.');%,...
_matlab("set(h, 'LineStyle', 'none', 'Marker', '.');%,...")
# MATLAB L1070:                
#
# MATLAB L1071:                for n=1:length(h)
_matlab('for n=1:length(h)')
# MATLAB L1072:                    currColor = get(h(n),'Color');
_matlab("currColor = get(h(n),'Color');")
# MATLAB L1073:                    set(h(n),'MarkerEdgeColor',currColor,'MarkerFaceColor',currColor); 
_matlab("set(h(n),'MarkerEdgeColor',currColor,'MarkerFaceColor',currColor);")
# MATLAB L1074: 
#
# MATLAB L1075:                end
_matlab('end')
# MATLAB L1076:             end
_matlab('end')
# MATLAB L1077: 
#
# MATLAB L1078:             hold on;
_matlab('hold on;')
# MATLAB L1079:            
#
# MATLAB L1080:             
#
# MATLAB L1081:             if(plotSignificance==1)
_matlab('if(plotSignificance==1)')
# MATLAB L1082:                v=axis;
_matlab('v=axis;')
# MATLAB L1083:                vdiff = .8*v(4);
_matlab('vdiff = .8*v(4);')
# MATLAB L1084: 
#
# MATLAB L1085:                for i=1:length(fitNum)
_matlab('for i=1:length(fitNum)')
# MATLAB L1086:                   plot(handle,find(sigIndex(:,i)==1),vdiff*ones(length(find(sigIndex(:,i)==1)),1)-i*.1,strcat('*',FitResult.colors{mod(i-1,length(FitResult.colors))+1})); hold on;
_matlab("plot(handle,find(sigIndex(:,i)==1),vdiff*ones(length(find(sigIndex(:,i)==1)),1)-i*.1,strcat('*',FitResult.colors{mod(i-1,length(FitResult.colors))+1})); hold on;")
# MATLAB L1087:                end
_matlab('end')
# MATLAB L1088:             end
_matlab('end')
# MATLAB L1089:            ylabel('GLM Fit Coefficients','Interpreter','none');
_matlab("ylabel('GLM Fit Coefficients','Interpreter','none');")
# MATLAB L1090:            xtickLabels = fitObj.getPlotParams.xLabels(subIndex);
_matlab('xtickLabels = fitObj.getPlotParams.xLabels(subIndex);')
# MATLAB L1091:            xticks = 1:(length(xtickLabels));
_matlab('xticks = 1:(length(xtickLabels));')
# MATLAB L1092:            
#
# MATLAB L1093:            set(handle,'xtick',xticks,'xtickLabel',xtickLabels,'FontSize',6);
_matlab("set(handle,'xtick',xticks,'xtickLabel',xtickLabels,'FontSize',6);")
# MATLAB L1094: %            axis tight;
# axis tight;
# MATLAB L1095:            if(max(fitObj.numCoeffs)>=1)
_matlab('if(max(fitObj.numCoeffs)>=1)')
# MATLAB L1096:             xticklabel_rotate([],90,[],'Fontsize',10);
_matlab("xticklabel_rotate([],90,[],'Fontsize',10);")
# MATLAB L1097:            end
_matlab('end')
# MATLAB L1098: %            hT=rotateticklabel(gca,-90);
# hT=rotateticklabel(gca,-90);
# MATLAB L1099:            h_legend=legend(handle,fitObj.lambda.dataLabels(fitNum),'Location','NorthEast');
_matlab("h_legend=legend(handle,fitObj.lambda.dataLabels(fitNum),'Location','NorthEast');")
# MATLAB L1100:            set(h_legend,'FontSize',14)
_matlab("set(h_legend,'FontSize',14)")
# MATLAB L1101:             pos = get(h_legend,'position');
_matlab("pos = get(h_legend,'position');")
# MATLAB L1102:             set(h_legend, 'position',[pos(1)+.05 pos(2) pos(3:4)]);
_matlab("set(h_legend, 'position',[pos(1)+.05 pos(2) pos(3:4)]);")
# MATLAB L1103:             
#
# MATLAB L1104: %            axis tight;
# axis tight;
# MATLAB L1105:             title({'GLM Coefficients with 95% CIs (* p<0.05)'},'FontWeight','bold',...
_matlab("title({'GLM Coefficients with 95% CIs (* p<0.05)'},'FontWeight','bold',...")
# MATLAB L1106:             'FontSize',11,...
_matlab("'FontSize',11,...")
# MATLAB L1107:             'FontName','Arial');
_matlab("'FontName','Arial');")
# MATLAB L1108:             set(gca,'FontName', 'Arial' );
_matlab("set(gca,'FontName', 'Arial' );")
# MATLAB L1109:             set(gca, ...
_matlab('set(gca, ...')
# MATLAB L1110:               'TickLength'  , [.02 .02] , ...
_matlab("'TickLength'  , [.02 .02] , ...")
# MATLAB L1111:               'YGrid'       , 'on'      , ...
_matlab("'YGrid'       , 'on'      , ...")
# MATLAB L1112:               'LineWidth'   , 1         );
_matlab("'LineWidth'   , 1         );")
# MATLAB L1113:             hx=get(gca,'XLabel');  hy=get(gca,'YLabel');
_matlab("hx=get(gca,'XLabel');  hy=get(gca,'YLabel');")
# MATLAB L1114:             set([hx hy],'FontName', 'Arial','FontSize',12,'FontWeight','bold');
_matlab("set([hx hy],'FontName', 'Arial','FontSize',12,'FontWeight','bold');")
# MATLAB L1115:            
#
# MATLAB L1116: 
#
# MATLAB L1117:         end
_matlab('end')
# MATLAB L1118:         function h=plotResults(fitObj)
_matlab('function h=plotResults(fitObj)')
# MATLAB L1119:             % plotResults(fitObj)
# plotResults(fitObj)
# MATLAB L1120:             % Generates KS plot, auto-correlation function of the inverse
# Generates KS plot, auto-correlation function of the inverse
# MATLAB L1121:             % gaussian transformed rescaled ISIs, the sequential
# gaussian transformed rescaled ISIs, the sequential
# MATLAB L1122:             % correlation coefficient between neigboring pairs of the
# correlation coefficient between neigboring pairs of the
# MATLAB L1123:             % rescaled ISIs (zj vs. zj-1), the GLM regression coefficients,
# rescaled ISIs (zj vs. zj-1), the GLM regression coefficients,
# MATLAB L1124:             % and the Point Process Residual.
# and the Point Process Residual.
# MATLAB L1125:                 scrsz = get(0,'ScreenSize');
_matlab("scrsz = get(0,'ScreenSize');")
# MATLAB L1126:                 h=figure('OuterPosition',[scrsz(3)*.01 scrsz(4)*.04 scrsz(3)*.98 scrsz(4)*.95]);
_matlab("h=figure('OuterPosition',[scrsz(3)*.01 scrsz(4)*.04 scrsz(3)*.98 scrsz(4)*.95]);")
# MATLAB L1127:                 
#
# MATLAB L1128:                 subplot(2,4,[1 2]); fitObj.KSPlot; %make the plot
_matlab('subplot(2,4,[1 2]); fitObj.KSPlot; %make the plot')
# MATLAB L1129:                 ht=text(.45, .95,strcat('Neuron:',num2str(fitObj.neuronNumber)));
_matlab("ht=text(.45, .95,strcat('Neuron:',num2str(fitObj.neuronNumber)));")
# MATLAB L1130:                 set(ht,'FontName', 'Arial','FontWeight','bold','FontSize',10);
_matlab("set(ht,'FontName', 'Arial','FontWeight','bold','FontSize',10);")
# MATLAB L1131: 
#
# MATLAB L1132:                 subplot(2,4,3); fitObj.plotInvGausTrans;
_matlab('subplot(2,4,3); fitObj.plotInvGausTrans;')
# MATLAB L1133:                 subplot(2,4,4); fitObj.plotSeqCorr;
_matlab('subplot(2,4,4); fitObj.plotSeqCorr;')
# MATLAB L1134:                 subplot(2,4,[7 8]); fitObj.plotResidual;
_matlab('subplot(2,4,[7 8]); fitObj.plotResidual;')
# MATLAB L1135:                 subplot(2,4,[5 6]); fitObj.plotCoeffs;
_matlab('subplot(2,4,[5 6]); fitObj.plotCoeffs;')
# MATLAB L1136:         end
_matlab('end')
# MATLAB L1137:         function handle = KSPlot(fitObj,fitNum)
_matlab('function handle = KSPlot(fitObj,fitNum)')
# MATLAB L1138:             % handle = KSPlot(fitObj)
# handle = KSPlot(fitObj)
# MATLAB L1139:             % computes the K-S plot for each of the the candidate rate
# computes the K-S plot for each of the the candidate rate
# MATLAB L1140:             % functions in this FitResult object. These candidate rate
# functions in this FitResult object. These candidate rate
# MATLAB L1141:             % functions are numbered according to the order in which they
# functions are numbered according to the order in which they
# MATLAB L1142:             % were added to the FitResult.
# were added to the FitResult.
# MATLAB L1143:             if(nargin<2)
_matlab('if(nargin<2)')
# MATLAB L1144:                 fitNum=1:fitObj.numResults;
_matlab('fitNum=1:fitObj.numResults;')
# MATLAB L1145:             end
_matlab('end')
# MATLAB L1146:             h=gcf; 
_matlab('h=gcf;')
# MATLAB L1147:             %h=[];
# h=[];
# MATLAB L1148:             figure(h); 
_matlab('figure(h);')
# MATLAB L1149:         %     size(xAxis) 
# size(xAxis)
# MATLAB L1150:         %     size(KSSorted)
# size(KSSorted)
# MATLAB L1151:             N = length(fitObj.KSStats.KSSorted);
_matlab('N = length(fitObj.KSStats.KSSorted);')
# MATLAB L1152:             if(~isempty(fitObj.KSStats.xAxis))
_matlab('if(~isempty(fitObj.KSStats.xAxis))')
# MATLAB L1153:                 xaxis = fitObj.KSStats.xAxis(:,1);
_matlab('xaxis = fitObj.KSStats.xAxis(:,1);')
# MATLAB L1154:                 % Plot the CIs
# Plot the CIs
# MATLAB L1155:                 plot(xaxis,xaxis, 'k-.'); hold on;
_matlab("plot(xaxis,xaxis, 'k-.'); hold on;")
# MATLAB L1156:                 plot(xaxis, xaxis+1.36/sqrt(N), 'r','Linewidth',1); 
_matlab("plot(xaxis, xaxis+1.36/sqrt(N), 'r','Linewidth',1);")
# MATLAB L1157:                 plot(xaxis,xaxis-1.36/sqrt(N), 'r','Linewidth',1 );
_matlab("plot(xaxis,xaxis-1.36/sqrt(N), 'r','Linewidth',1 );")
# MATLAB L1158:                 handle=plot(fitObj.KSStats.xAxis(:,fitNum),fitObj.KSStats.KSSorted(:,fitNum),'Linewidth',2);
_matlab("handle=plot(fitObj.KSStats.xAxis(:,fitNum),fitObj.KSStats.KSSorted(:,fitNum),'Linewidth',2);")
# MATLAB L1159:             
#
# MATLAB L1160:                 %set(gca,'xtick',[],'ytick',[],'ztick', [])
# set(gca,'xtick',[],'ytick',[],'ztick', [])
# MATLAB L1161:                 axis( [0 1 0 1] );
_matlab('axis( [0 1 0 1] );')
# MATLAB L1162: %             dataLabels = cell(1,fitObj.lambda.dimension);
# dataLabels = cell(1,fitObj.lambda.dimension);
# MATLAB L1163: %             for i=1:fitObj.lambda.dimension
# for i=1:fitObj.lambda.dimension
# MATLAB L1164:                 dataLabels = fitObj.lambda.dataLabels(fitNum);
_matlab('dataLabels = fitObj.lambda.dataLabels(fitNum);')
# MATLAB L1165: %             end
# end
# MATLAB L1166:                 h_legend=legend(handle,dataLabels,'Location','SouthEast');
_matlab("h_legend=legend(handle,dataLabels,'Location','SouthEast');")
# MATLAB L1167:                 set(h_legend,'FontSize',14)
_matlab("set(h_legend,'FontSize',14)")
# MATLAB L1168:             end
_matlab('end')
# MATLAB L1169:             hx=xlabel('Ideal Uniform CDF');
_matlab("hx=xlabel('Ideal Uniform CDF');")
# MATLAB L1170:             hy=ylabel('Empirical CDF');
_matlab("hy=ylabel('Empirical CDF');")
# MATLAB L1171:             title({'KS Plot of Rescaled ISIs'; 'with 95% Confidence Intervals'},'FontWeight','bold','FontSize',11,'FontName','Arial');
_matlab("title({'KS Plot of Rescaled ISIs'; 'with 95% Confidence Intervals'},'FontWeight','bold','FontSize',11,'FontName','Arial');")
# MATLAB L1172:             set([hx, hy],'FontName', 'Arial','FontWeight','bold','FontSize',12);
_matlab("set([hx, hy],'FontName', 'Arial','FontWeight','bold','FontSize',12);")
# MATLAB L1173: 
#
# MATLAB L1174:             set(gca, ...
_matlab('set(gca, ...')
# MATLAB L1175:               'TickLength'  , [.02 .02] , ...
_matlab("'TickLength'  , [.02 .02] , ...")
# MATLAB L1176:               'YTick'       , 0:.2:1, ...
_matlab("'YTick'       , 0:.2:1, ...")
# MATLAB L1177:               'XTick'       , 0:.2:1, ...
_matlab("'XTick'       , 0:.2:1, ...")
# MATLAB L1178:               'LineWidth'   , 1         );
_matlab("'LineWidth'   , 1         );")
# MATLAB L1179:             end
_matlab('end')
# MATLAB L1180: 
#
# MATLAB L1181:         function structure = toStructure(fitObj)
_matlab('function structure = toStructure(fitObj)')
# MATLAB L1182:             % structure =  toStructure(fitObj)
# structure =  toStructure(fitObj)
# MATLAB L1183:             % Converts FitResult object to a matlab structure than can then
# Converts FitResult object to a matlab structure than can then
# MATLAB L1184:             % be saved. The structure is compatible with the FitResult
# be saved. The structure is compatible with the FitResult
# MATLAB L1185:             % static method FitResult.fromStructure(structure) that returns
# static method FitResult.fromStructure(structure) that returns
# MATLAB L1186:             % the object corresponding structure passed in.
# the object corresponding structure passed in.
# MATLAB L1187:             fnames = fieldnames(fitObj);
_matlab('fnames = fieldnames(fitObj);')
# MATLAB L1188:             
#
# MATLAB L1189:             for i=1:length(fnames)
_matlab('for i=1:length(fnames)')
# MATLAB L1190:                 
#
# MATLAB L1191:                 currObj = fitObj.(fnames{i});
_matlab('currObj = fitObj.(fnames{i});')
# MATLAB L1192:                 if(strcmp(fnames{i},'histObjects')||strcmp(fnames{i},'ensHistObjects'))
_matlab("if(strcmp(fnames{i},'histObjects')||strcmp(fnames{i},'ensHistObjects'))")
# MATLAB L1193:                     for j=1:fitObj.numResults
_matlab('for j=1:fitObj.numResults')
# MATLAB L1194:                         tempObj = fitObj.(fnames{i}){j};
_matlab('tempObj = fitObj.(fnames{i}){j};')
# MATLAB L1195:                         if(~isempty(tempObj))
_matlab('if(~isempty(tempObj))')
# MATLAB L1196:                             structure.(fnames{i}){j} = tempObj.toStructure;
_matlab('structure.(fnames{i}){j} = tempObj.toStructure;')
# MATLAB L1197:                         else
_matlab('else')
# MATLAB L1198:                             structure.(fnames{i}){j} = tempObj;
_matlab('structure.(fnames{i}){j} = tempObj;')
# MATLAB L1199:                         end
_matlab('end')
# MATLAB L1200:                     end
_matlab('end')
# MATLAB L1201:                 elseif(strcmp(fnames{i},'invGausStats'))
_matlab("elseif(strcmp(fnames{i},'invGausStats'))")
# MATLAB L1202:                     tempNames = fieldnames(fitObj.(fnames{i}));
_matlab('tempNames = fieldnames(fitObj.(fnames{i}));')
# MATLAB L1203:                     for j=1:length(tempNames)
_matlab('for j=1:length(tempNames)')
# MATLAB L1204:                        tempObj = currObj.(tempNames{j});
_matlab('tempObj = currObj.(tempNames{j});')
# MATLAB L1205:                        if(~isempty(tempObj))
_matlab('if(~isempty(tempObj))')
# MATLAB L1206:                         structure.(fnames{i}).(tempNames{j})=  tempObj.dataToStructure;
_matlab('structure.(fnames{i}).(tempNames{j})=  tempObj.dataToStructure;')
# MATLAB L1207:                        else
_matlab('else')
# MATLAB L1208:                          structure.(fnames{i}).(tempNames{j})=  tempObj;  
_matlab('structure.(fnames{i}).(tempNames{j})=  tempObj;')
# MATLAB L1209:                        end
_matlab('end')
# MATLAB L1210:                         
#
# MATLAB L1211:                     end
_matlab('end')
# MATLAB L1212:                     
#
# MATLAB L1213:                 else
_matlab('else')
# MATLAB L1214:                 
#
# MATLAB L1215:                     if(isa(currObj,'double')||isa(currObj,'cell'))
_matlab("if(isa(currObj,'double')||isa(currObj,'cell'))")
# MATLAB L1216:                         structure.(fnames{i}) = currObj;
_matlab('structure.(fnames{i}) = currObj;')
# MATLAB L1217:                     elseif(isa(currObj,'Covariate') ||isa(currObj,'ConfigColl')||isa(currObj,'nspikeTrain'))
_matlab("elseif(isa(currObj,'Covariate') ||isa(currObj,'ConfigColl')||isa(currObj,'nspikeTrain'))")
# MATLAB L1218:                         structure.(fnames{i}) = currObj.toStructure;
_matlab('structure.(fnames{i}) = currObj.toStructure;')
# MATLAB L1219:                     elseif(isa(currObj,'SignalObj'))
_matlab("elseif(isa(currObj,'SignalObj'))")
# MATLAB L1220:                         structure.(fnames{i})  = currObj.dataToStructure;
_matlab('structure.(fnames{i})  = currObj.dataToStructure;')
# MATLAB L1221:                     elseif(isa(currObj,'struct'))
_matlab("elseif(isa(currObj,'struct'))")
# MATLAB L1222:                         structure.(fnames{i}) = currObj;
_matlab('structure.(fnames{i}) = currObj;')
# MATLAB L1223:                     end
_matlab('end')
# MATLAB L1224:                 end
_matlab('end')
# MATLAB L1225:             end
_matlab('end')
# MATLAB L1226:             
#
# MATLAB L1227:         end
_matlab('end')
# MATLAB L1228:         
#
# MATLAB L1229: 
#
# MATLAB L1230:         function handle = plotSeqCorr(fitObj)
_matlab('function handle = plotSeqCorr(fitObj)')
# MATLAB L1231:             % handle = plotSeqCorr(fitObj)
# handle = plotSeqCorr(fitObj)
# MATLAB L1232:             % plot zj+1 against zj
# plot zj+1 against zj
# MATLAB L1233:             
#
# MATLAB L1234:             %colors = {'.b','.g','.r','.c','.m','.y','.k'};
# colors = {'.b','.g','.r','.c','.m','.y','.k'};
# MATLAB L1235:             rho=zeros(1,fitObj.numResults);
_matlab('rho=zeros(1,fitObj.numResults);')
# MATLAB L1236:             pval=zeros(1,fitObj.numResults);
_matlab('pval=zeros(1,fitObj.numResults);')
# MATLAB L1237:             dataLabels = fitObj.lambda.dataLabels;
_matlab('dataLabels = fitObj.lambda.dataLabels;')
# MATLAB L1238:             for i=1:fitObj.numResults
_matlab('for i=1:fitObj.numResults')
# MATLAB L1239:                handle = plot(fitObj.U(1:end-1,i),fitObj.U(2:end,i),strcat('.',Analysis.colors{mod(i-1,length(Analysis.colors))+1})); hold on;
_matlab("handle = plot(fitObj.U(1:end-1,i),fitObj.U(2:end,i),strcat('.',Analysis.colors{mod(i-1,length(Analysis.colors))+1})); hold on;")
# MATLAB L1240:                [rhoTemp,p]= corrcoef(fitObj.U(1:end-1,i),fitObj.U(2:end,i));%handle=scatterhist(fitResults.Z(1:end-1,i),fitResults.Z(2:end,i))
_matlab('[rhoTemp,p]= corrcoef(fitObj.U(1:end-1,i),fitObj.U(2:end,i));%handle=scatterhist(fitResults.Z(1:end-1,i),fitResults.Z(2:end,i))')
# MATLAB L1241:                
#
# MATLAB L1242:                [~,columns]=size(rhoTemp);
_matlab('[~,columns]=size(rhoTemp);')
# MATLAB L1243:                 if(columns>1)
_matlab('if(columns>1)')
# MATLAB L1244:                     rho(i) = rhoTemp(1,2);
_matlab('rho(i) = rhoTemp(1,2);')
# MATLAB L1245:                     pval(i)= p(1,2);
_matlab('pval(i)= p(1,2);')
# MATLAB L1246:                 else
_matlab('else')
# MATLAB L1247:                     rho(i) = rhoTemp;
_matlab('rho(i) = rhoTemp;')
# MATLAB L1248:                     pval(i)= p;
_matlab('pval(i)= p;')
# MATLAB L1249:                 end
_matlab('end')
# MATLAB L1250:                dataLabels{i} = strcat(dataLabels{i},', \rho=',num2str(rho(i),'%0.2g'),' (p=',num2str(pval(i),'%0.2g'),')');
_matlab("dataLabels{i} = strcat(dataLabels{i},', \\rho=',num2str(rho(i),'%0.2g'),' (p=',num2str(pval(i),'%0.2g'),')');")
# MATLAB L1251:                 %get(h,'AlphaData');
# get(h,'AlphaData');
# MATLAB L1252:                 %set(h,'FaceAlpha',0.2,'EdgeAlpha',0.8,'EdgeColor',color{i});
# set(h,'FaceAlpha',0.2,'EdgeAlpha',0.8,'EdgeColor',color{i});
# MATLAB L1253:             end
_matlab('end')
# MATLAB L1254:             
#
# MATLAB L1255:            
#
# MATLAB L1256:             h_legend=legend(dataLabels,'Location','NorthEast');     
_matlab("h_legend=legend(dataLabels,'Location','NorthEast');")
# MATLAB L1257:             set(h_legend,'FontSize',14)
_matlab("set(h_legend,'FontSize',14)")
# MATLAB L1258:             pos = get(h_legend,'position');
_matlab("pos = get(h_legend,'position');")
# MATLAB L1259:             if(~isempty(pos))
_matlab('if(~isempty(pos))')
# MATLAB L1260:                  set(h_legend, 'position',[pos(1)+.05 pos(2) pos(3:4)]);
_matlab("set(h_legend, 'position',[pos(1)+.05 pos(2) pos(3:4)]);")
# MATLAB L1261:             end
_matlab('end')
# MATLAB L1262:             
#
# MATLAB L1263:             hy=ylabel('u_{j+1}'); hx=xlabel('u_j');
_matlab("hy=ylabel('u_{j+1}'); hx=xlabel('u_j');")
# MATLAB L1264:             set([hx, hy],'FontName', 'Arial','FontSize',12,'FontWeight','bold');
_matlab("set([hx, hy],'FontName', 'Arial','FontSize',12,'FontWeight','bold');")
# MATLAB L1265: 
#
# MATLAB L1266:             axis([0 1 0 1]);
_matlab('axis([0 1 0 1]);')
# MATLAB L1267:             title({'Sequential Correlation of'; 'Rescaled ISIs'},'FontWeight','bold',...
_matlab("title({'Sequential Correlation of'; 'Rescaled ISIs'},'FontWeight','bold',...")
# MATLAB L1268:             'FontSize',11,...
_matlab("'FontSize',11,...")
# MATLAB L1269:             'FontName','Arial');
_matlab("'FontName','Arial');")
# MATLAB L1270:         
#
# MATLAB L1271:     
#
# MATLAB L1272:             set(gca, ...
_matlab('set(gca, ...')
# MATLAB L1273:               'TickLength'  , [.02 .02] , ...
_matlab("'TickLength'  , [.02 .02] , ...")
# MATLAB L1274:               'YTick'       , 0:.25:1, ...
_matlab("'YTick'       , 0:.25:1, ...")
# MATLAB L1275:               'XTick'       , 0:.25:1, ...
_matlab("'XTick'       , 0:.25:1, ...")
# MATLAB L1276:               'LineWidth'   , 1         );
_matlab("'LineWidth'   , 1         );")
# MATLAB L1277:         
#
# MATLAB L1278: 
#
# MATLAB L1279:             
#
# MATLAB L1280:         end
_matlab('end')
# MATLAB L1281:         function handle = plotInvGausTrans(fitObj)
_matlab('function handle = plotInvGausTrans(fitObj)')
# MATLAB L1282:             % handle = plotInvGausTrans(fitObj)
# handle = plotInvGausTrans(fitObj)
# MATLAB L1283:             % Plots the Auto-correlation function of the X_j's where:
# Plots the Auto-correlation function of the X_j's where:
# MATLAB L1284:             % Z_j: rescaled ISI from the Time Rescaling Theorem. 
# Z_j: rescaled ISI from the Time Rescaling Theorem.
# MATLAB L1285:             %      Exponential Rate 1 under true conditional intensity
# Exponential Rate 1 under true conditional intensity
# MATLAB L1286:             %      function.
# function.
# MATLAB L1287:             % U_j: 1-exp(-Z_j). Uniform on the interval [0,1) if Z_j's
# U_j: 1-exp(-Z_j). Uniform on the interval [0,1) if Z_j's
# MATLAB L1288:             %      are exponential rate 1.
# are exponential rate 1.
# MATLAB L1289:             %
#
# MATLAB L1290:             % X_j: norminv(U_j,0,1). Gaussian mean 0, stdev 1 if U_j's are
# X_j: norminv(U_j,0,1). Gaussian mean 0, stdev 1 if U_j's are
# MATLAB L1291:             %      U([0,1))
# U([0,1))
# MATLAB L1292:             %
#
# MATLAB L1293:             
#
# MATLAB L1294:             %[rows,colm] = size(fitObj.X);
# [rows,colm] = size(fitObj.X);
# MATLAB L1295:             %index=find(fitObj.invGausStats.lags==1);
# index=find(fitObj.invGausStats.lags==1);
# MATLAB L1296:             %lags=fitObj.invGausStats.lags;
# lags=fitObj.invGausStats.lags;
# MATLAB L1297:             [fitObj.X,rhoSig,confBoundSig] = Analysis.computeInvGausTrans(fitObj.Z);
_matlab('[fitObj.X,rhoSig,confBoundSig] = Analysis.computeInvGausTrans(fitObj.Z);')
# MATLAB L1298: %             rhoSig=fitObj.invGausStats.rhoSig;
# rhoSig=fitObj.invGausStats.rhoSig;
# MATLAB L1299:             n=length(fitObj.X);
_matlab('n=length(fitObj.X);')
# MATLAB L1300: %             confBoundSig = fitObj.invGausStats.confBoundSig;
# confBoundSig = fitObj.invGausStats.confBoundSig;
# MATLAB L1301:             handle=[];
_matlab('handle=[];')
# MATLAB L1302: %              for i=1:colm
# for i=1:colm
# MATLAB L1303: %                     %i
# %i
# MATLAB L1304: %                     htemp=plot(lags',rho(:,i),strcat('.',FitResults.colors{mod(i-1,length(Analysis.colors))+1}));
# htemp=plot(lags',rho(:,i),strcat('.',FitResults.colors{mod(i-1,length(Analysis.colors))+1}));
# MATLAB L1305: %                     handle=[handle,htemp];
# handle=[handle,htemp];
# MATLAB L1306: %                     hold on; 
# hold on;
# MATLAB L1307: %                     %labelArray{i} = ['Fit ' num2str(i)];
# %labelArray{i} = ['Fit ' num2str(i)];
# MATLAB L1308: %              end
# end
# MATLAB L1309:             if(~isempty(rhoSig))
_matlab('if(~isempty(rhoSig))')
# MATLAB L1310:                 rhoSig.plot;
_matlab('rhoSig.plot;')
# MATLAB L1311:             end
_matlab('end')
# MATLAB L1312:             h_legend=legend(fitObj.lambda.dataLabels,'Location','NorthEast');            
_matlab("h_legend=legend(fitObj.lambda.dataLabels,'Location','NorthEast');")
# MATLAB L1313:             set(h_legend,'FontSize',14)
_matlab("set(h_legend,'FontSize',14)")
# MATLAB L1314:             pos = get(h_legend,'position');
_matlab("pos = get(h_legend,'position');")
# MATLAB L1315:             if(~isempty(pos))
_matlab('if(~isempty(pos))')
# MATLAB L1316:              set(h_legend, 'position',[pos(1)+.05 pos(2) pos(3:4)]);
_matlab("set(h_legend, 'position',[pos(1)+.05 pos(2) pos(3:4)]);")
# MATLAB L1317:             end
_matlab('end')
# MATLAB L1318:             %legend(h,labelArray); 
# legend(h,labelArray);
# MATLAB L1319:             hold on; 
_matlab('hold on;')
# MATLAB L1320:             if(~isempty(confBoundSig))
_matlab('if(~isempty(confBoundSig))')
# MATLAB L1321:                 confBoundSig.plot;
_matlab('confBoundSig.plot;')
# MATLAB L1322:             end
_matlab('end')
# MATLAB L1323:             title({'Autocorrelation Function';'of Rescaled ISIs'; 'with 95% CIs'},'FontWeight','bold',...
_matlab("title({'Autocorrelation Function';'of Rescaled ISIs'; 'with 95% CIs'},'FontWeight','bold',...")
# MATLAB L1324:             'FontSize',11,...
_matlab("'FontSize',11,...")
# MATLAB L1325:             'FontName','Arial');
_matlab("'FontName','Arial');")
# MATLAB L1326:             hx=get(gca,'XLabel');  hy=get(gca,'YLabel');
_matlab("hx=get(gca,'XLabel');  hy=get(gca,'YLabel');")
# MATLAB L1327:             set([hx, hy],'FontName', 'Arial','FontSize',12,'FontWeight','bold');
_matlab("set([hx, hy],'FontName', 'Arial','FontSize',12,'FontWeight','bold');")
# MATLAB L1328:             set(gca, ...
_matlab('set(gca, ...')
# MATLAB L1329:               'TickLength'  , [.02 .02] , ...
_matlab("'TickLength'  , [.02 .02] , ...")
# MATLAB L1330:               'LineWidth'   , 1         );
_matlab("'LineWidth'   , 1         );")
# MATLAB L1331:             v=axis;
_matlab('v=axis;')
# MATLAB L1332:             maxY = max(abs(v(3:4)))*(1.1); %add 10%
_matlab('maxY = max(abs(v(3:4)))*(1.1); %add 10%')
# MATLAB L1333:             axis([v(1:2) -maxY maxY]);
_matlab('axis([v(1:2) -maxY maxY]);')
# MATLAB L1334:         end
_matlab('end')
# MATLAB L1335:         function handle = plotResidual(fitObj)
_matlab('function handle = plotResidual(fitObj)')
# MATLAB L1336:             % handle = plotResidual(fitObj)
# handle = plotResidual(fitObj)
# MATLAB L1337:             % Plots the Point Process Residual
# Plots the Point Process Residual
# MATLAB L1338:             handle=fitObj.Residual.plot;
_matlab('handle=fitObj.Residual.plot;')
# MATLAB L1339:             legend off;
_matlab('legend off;')
# MATLAB L1340:             h_legend=legend(fitObj.lambda.dataLabels,'Location','NorthEast'); 
_matlab("h_legend=legend(fitObj.lambda.dataLabels,'Location','NorthEast');")
# MATLAB L1341:             set(h_legend,'FontSize',14)
_matlab("set(h_legend,'FontSize',14)")
# MATLAB L1342:             pos = get(h_legend,'position');
_matlab("pos = get(h_legend,'position');")
# MATLAB L1343: %             set(h_legend, 'position',[.91 .41 pos(3:4)]);
# set(h_legend, 'position',[.91 .41 pos(3:4)]);
# MATLAB L1344:             set(h_legend, 'position',[pos(1)+.05 pos(2) pos(3:4)]);
_matlab("set(h_legend, 'position',[pos(1)+.05 pos(2) pos(3:4)]);")
# MATLAB L1345:             title('Point Process Residual','FontWeight','bold',...
_matlab("title('Point Process Residual','FontWeight','bold',...")
# MATLAB L1346:             'FontSize',11,...
_matlab("'FontSize',11,...")
# MATLAB L1347:             'FontName','Arial');
_matlab("'FontName','Arial');")
# MATLAB L1348:             xlabel('time [s]','Interpreter','none');
_matlab("xlabel('time [s]','Interpreter','none');")
# MATLAB L1349:             hx=get(gca,'XLabel');  hy=get(gca,'YLabel');
_matlab("hx=get(gca,'XLabel');  hy=get(gca,'YLabel');")
# MATLAB L1350:             set([hx, hy],'FontName', 'Arial','FontSize',12,'FontWeight','bold');
_matlab("set([hx, hy],'FontName', 'Arial','FontSize',12,'FontWeight','bold');")
# MATLAB L1351:             v=axis;
_matlab('v=axis;')
# MATLAB L1352:             maxY = max(abs(v(3:4)))*(1.1); %add 10%
_matlab('maxY = max(abs(v(3:4)))*(1.1); %add 10%')
# MATLAB L1353:             axis([v(1:2) -maxY maxY]);
_matlab('axis([v(1:2) -maxY maxY]);')
# MATLAB L1354:         end
_matlab('end')
# MATLAB L1355:         
#
# MATLAB L1356:         
#
# MATLAB L1357:         function setKSStats(fitObj, Z, U, xAxis, KSSorted, ks_stat)
_matlab('function setKSStats(fitObj, Z, U, xAxis, KSSorted, ks_stat)')
# MATLAB L1358:             % setKSStats(fitObj, Z, xAxis, KSSorted, ks_stat)
# setKSStats(fitObj, Z, xAxis, KSSorted, ks_stat)
# MATLAB L1359:             % Allows KS statistics to be set after object creation
# Allows KS statistics to be set after object creation
# MATLAB L1360:             % Z: Rescaled ISIs from the Time Rescaling Theorem
# Z: Rescaled ISIs from the Time Rescaling Theorem
# MATLAB L1361:             % xAxis: xAxis of the KS plot
# xAxis: xAxis of the KS plot
# MATLAB L1362:             % KSSorted: the sorted values of Uj=1-exp(-zj)
# KSSorted: the sorted values of Uj=1-exp(-zj)
# MATLAB L1363:             % ks_stat: the maximum deviation from the 45 degree line for
# ks_stat: the maximum deviation from the 45 degree line for
# MATLAB L1364:             % all of the fits.
# all of the fits.
# MATLAB L1365:             % 
#
# MATLAB L1366:             fitObj.Z        =Z;
_matlab('fitObj.Z        =Z;')
# MATLAB L1367:             fitObj.U        =U;
_matlab('fitObj.U        =U;')
# MATLAB L1368:             fitObj.KSStats.xAxis    =xAxis;
_matlab('fitObj.KSStats.xAxis    =xAxis;')
# MATLAB L1369:             fitObj.KSStats.KSSorted =KSSorted;
_matlab('fitObj.KSStats.KSSorted =KSSorted;')
# MATLAB L1370:             
#
# MATLAB L1371:             
#
# MATLAB L1372:             for i=1:size(xAxis,2);
_matlab('for i=1:size(xAxis,2);')
# MATLAB L1373:                 [differentDists(i),pVal(i),ks_stat(i)]=kstest2(fitObj.KSStats.xAxis(:,i) ,fitObj.KSStats.KSSorted(:,i));
_matlab('[differentDists(i),pVal(i),ks_stat(i)]=kstest2(fitObj.KSStats.xAxis(:,i) ,fitObj.KSStats.KSSorted(:,i));')
# MATLAB L1374:             end
_matlab('end')
# MATLAB L1375:             if(~exist('differentDists'))
_matlab("if(~exist('differentDists'))")
# MATLAB L1376:                 differentDists=1;
differentDists = 1
# MATLAB L1377:             end
_matlab('end')
# MATLAB L1378:             if(~exist('pVal'))
_matlab("if(~exist('pVal'))")
# MATLAB L1379:                 pVal=1;
pVal = 1
# MATLAB L1380:             end
_matlab('end')
# MATLAB L1381:             
#
# MATLAB L1382:             fitObj.KSStats.ks_stat  =ks_stat;
_matlab('fitObj.KSStats.ks_stat  =ks_stat;')
# MATLAB L1383: %             N = length(fitObj.KSStats.KSSorted);
# N = length(fitObj.KSStats.KSSorted);
# MATLAB L1384: %             fitObj.KSStats.withinConfInt = ks_stat<1.36/sqrt(N);
# fitObj.KSStats.withinConfInt = ks_stat<1.36/sqrt(N);
# MATLAB L1385:             fitObj.KSStats.withinConfInt = ~differentDists;
_matlab('fitObj.KSStats.withinConfInt = ~differentDists;')
# MATLAB L1386:             fitObj.KSStats.pValue = pVal;
_matlab('fitObj.KSStats.pValue = pVal;')
# MATLAB L1387:         end
_matlab('end')
# MATLAB L1388:         function setInvGausStats(fitObj, X,rhoSig,confBoundSig)
_matlab('function setInvGausStats(fitObj, X,rhoSig,confBoundSig)')
# MATLAB L1389:             % setInvGausStats(fitObj,X,rhoSig,confBoundSig)
# setInvGausStats(fitObj,X,rhoSig,confBoundSig)
# MATLAB L1390:             % Sets the inverse gaussian transformed rescaled ISIs and the
# Sets the inverse gaussian transformed rescaled ISIs and the
# MATLAB L1391:             % confidence bounds after the object has been created.
# confidence bounds after the object has been created.
# MATLAB L1392:             %fitObj.U=U;
# fitObj.U=U;
# MATLAB L1393:             fitObj.X=X;
_matlab('fitObj.X=X;')
# MATLAB L1394:             fitObj.invGausStats.rhoSig=rhoSig;
_matlab('fitObj.invGausStats.rhoSig=rhoSig;')
# MATLAB L1395:             fitObj.invGausStats.confBoundSig=confBoundSig;
_matlab('fitObj.invGausStats.confBoundSig=confBoundSig;')
# MATLAB L1396:         end        
_matlab('end')
# MATLAB L1397:         function setFitResidual(fitObj,M)
_matlab('function setFitResidual(fitObj,M)')
# MATLAB L1398:            % setFitResidual(fitObj,M). 
# setFitResidual(fitObj,M).
# MATLAB L1399:            % Adds the point process residual to the FitResult object
# Adds the point process residual to the FitResult object
# MATLAB L1400:            fitObj.Residual = M; 
_matlab('fitObj.Residual = M;')
# MATLAB L1401:         end
_matlab('end')
# MATLAB L1402:         
#
# MATLAB L1403:         function [paramVals, paramSE, paramSigIndex] = getParam(fitObj,paramNames,fitNum)
_matlab('function [paramVals, paramSE, paramSigIndex] = getParam(fitObj,paramNames,fitNum)')
# MATLAB L1404:            % output is a matrix of length equal to the total number of
# output is a matrix of length equal to the total number of
# MATLAB L1405:            % paramNames
# paramNames
# MATLAB L1406:            % and one column for each fit
# and one column for each fit
# MATLAB L1407:              
#
# MATLAB L1408:             if(nargin<3)
_matlab('if(nargin<3)')
# MATLAB L1409:                 fitNum = 1:fitObj.numResults;
_matlab('fitNum = 1:fitObj.numResults;')
# MATLAB L1410:             end
_matlab('end')
# MATLAB L1411:            if(isempty(fitObj.plotParams))
_matlab('if(isempty(fitObj.plotParams))')
# MATLAB L1412:                fitObj.computePlotParams;
_matlab('fitObj.computePlotParams;')
# MATLAB L1413:            end
_matlab('end')
# MATLAB L1414:            paramVals = zeros(length(paramNames),length(fitNum));
_matlab('paramVals = zeros(length(paramNames),length(fitNum));')
# MATLAB L1415:            
#
# MATLAB L1416:            if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L1417:             paramSE = zeros(length(paramNames),length(fitNum));
_matlab('paramSE = zeros(length(paramNames),length(fitNum));')
# MATLAB L1418:            end
_matlab('end')
# MATLAB L1419:            
#
# MATLAB L1420:            if(nargout>2)
_matlab('if(nargout>2)')
# MATLAB L1421:             paramSigIndex = zeros(length(paramNames),length(fitNum));
_matlab('paramSigIndex = zeros(length(paramNames),length(fitNum));')
# MATLAB L1422:            end
_matlab('end')
# MATLAB L1423:            
#
# MATLAB L1424:            for i=1:length(paramNames)
_matlab('for i=1:length(paramNames)')
# MATLAB L1425:                 paramIndex=find(strcmp(paramNames(i),fitObj.uniqueCovLabels));
_matlab('paramIndex=find(strcmp(paramNames(i),fitObj.uniqueCovLabels));')
# MATLAB L1426:                 paramVals(i,:) = fitObj.plotParams.bAct(paramIndex,fitNum);
_matlab('paramVals(i,:) = fitObj.plotParams.bAct(paramIndex,fitNum);')
# MATLAB L1427:                 if(nargout>1)
_matlab('if(nargout>1)')
# MATLAB L1428:                     paramSE(i,:) = fitObj.plotParams.seAct(paramIndex,fitNum);
_matlab('paramSE(i,:) = fitObj.plotParams.seAct(paramIndex,fitNum);')
# MATLAB L1429:                 end
_matlab('end')
# MATLAB L1430:                 if(nargout>2)
_matlab('if(nargout>2)')
# MATLAB L1431:                     paramSigIndex(i,:) = fitObj.plotParams.sigIndex(paramIndex,fitNum);
_matlab('paramSigIndex(i,:) = fitObj.plotParams.sigIndex(paramIndex,fitNum);')
# MATLAB L1432:                 end
_matlab('end')
# MATLAB L1433:            end
_matlab('end')
# MATLAB L1434:             
#
# MATLAB L1435:         end
_matlab('end')
# MATLAB L1436:         
#
# MATLAB L1437:             
#
# MATLAB L1438:     end
_matlab('end')
# MATLAB L1439:     
#
# MATLAB L1440:     methods (Static)
_matlab('methods (Static)')
# MATLAB L1441:         
#
# MATLAB L1442:         function fitObj = fromStructure(structure)
_matlab('function fitObj = fromStructure(structure)')
# MATLAB L1443:             % fitObj = fromStructure(structure)
# fitObj = fromStructure(structure)
# MATLAB L1444:             % Returns a FitResult object from the input structure.
# Returns a FitResult object from the input structure.
# MATLAB L1445:             % This is used to be able to save and restore FitResult
# This is used to be able to save and restore FitResult
# MATLAB L1446:             if(isa(structure,'struct'))
_matlab("if(isa(structure,'struct'))")
# MATLAB L1447:                 if(isa(structure.neuralSpikeTrain,'cell'))
_matlab("if(isa(structure.neuralSpikeTrain,'cell'))")
# MATLAB L1448:                     spikeObj = cell(1,length(structure.neuralSpikeTrain));
_matlab('spikeObj = cell(1,length(structure.neuralSpikeTrain));')
# MATLAB L1449:                    for k=1:length(structure.neuralSpikeTrain)
_matlab('for k=1:length(structure.neuralSpikeTrain)')
# MATLAB L1450:                        spikeObj{k} = nspikeTrain.fromStructure(structure.neuralSpikeTrain{k}); 
_matlab('spikeObj{k} = nspikeTrain.fromStructure(structure.neuralSpikeTrain{k});')
# MATLAB L1451:                        
#
# MATLAB L1452:                    end
_matlab('end')
# MATLAB L1453:                 else
_matlab('else')
# MATLAB L1454:                     spikeObj=nspikeTrain.fromStructure(structure.neuralSpikeTrain); 
_matlab('spikeObj=nspikeTrain.fromStructure(structure.neuralSpikeTrain);')
# MATLAB L1455:                 end
_matlab('end')
# MATLAB L1456:                 lambda=Covariate.fromStructure(structure.lambda);
_matlab('lambda=Covariate.fromStructure(structure.lambda);')
# MATLAB L1457:                 rhoSig=SignalObj.signalFromStruct(structure.invGausStats.rhoSig);
_matlab('rhoSig=SignalObj.signalFromStruct(structure.invGausStats.rhoSig);')
# MATLAB L1458:                 confBoundSig = SignalObj.signalFromStruct(structure.invGausStats.confBoundSig);
_matlab('confBoundSig = SignalObj.signalFromStruct(structure.invGausStats.confBoundSig);')
# MATLAB L1459:                 M = Covariate.fromStructure(structure.Residual);
_matlab('M = Covariate.fromStructure(structure.Residual);')
# MATLAB L1460:                 for i=1:structure.numResults
_matlab('for i=1:structure.numResults')
# MATLAB L1461:                     histObjects{i} = History.fromStructure(structure.histObjects{i});
_matlab('histObjects{i} = History.fromStructure(structure.histObjects{i});')
# MATLAB L1462:                     ensHistObject{i} = History.fromStructure(structure.ensHistObjects{i});
_matlab('ensHistObject{i} = History.fromStructure(structure.ensHistObjects{i});')
# MATLAB L1463:                 end
_matlab('end')
# MATLAB L1464:                 configColl = ConfigColl.fromStructure(structure.configs);
_matlab('configColl = ConfigColl.fromStructure(structure.configs);')
# MATLAB L1465:                 if(isfield(structure,'logLL'))
_matlab("if(isfield(structure,'logLL'))")
# MATLAB L1466:                     logLL = structure.logLL;
_matlab('logLL = structure.logLL;')
# MATLAB L1467:                 else
_matlab('else')
# MATLAB L1468:                     logLL = zeros(size(structure.AIC));
_matlab('logLL = zeros(size(structure.AIC));')
# MATLAB L1469:                 end
_matlab('end')
# MATLAB L1470:                 fitObj=FitResult(spikeObj,structure.covLabels,structure.numHist,histObjects,ensHistObject,lambda,structure.b, structure.dev, structure.stats,structure.AIC,structure.BIC,logLL,configColl,structure.XvalData,structure.XvalTime,structure.fitType);
_matlab('fitObj=FitResult(spikeObj,structure.covLabels,structure.numHist,histObjects,ensHistObject,lambda,structure.b, structure.dev, structure.stats,structure.AIC,structure.BIC,logLL,configColl,structure.XvalData,structure.XvalTime,structure.fitType);')
# MATLAB L1471:                 fitObj.setKSStats(structure.Z,structure.U, structure.KSStats.xAxis, structure.KSStats.KSSorted, structure.KSStats.ks_stat);
_matlab('fitObj.setKSStats(structure.Z,structure.U, structure.KSStats.xAxis, structure.KSStats.KSSorted, structure.KSStats.ks_stat);')
# MATLAB L1472:                 fitObj.setInvGausStats(structure.X,rhoSig,confBoundSig);
_matlab('fitObj.setInvGausStats(structure.X,rhoSig,confBoundSig);')
# MATLAB L1473:                 fitObj.setFitResidual(M);
_matlab('fitObj.setFitResidual(M);')
# MATLAB L1474:                 fitObj.setNeuronName(structure.neuronNumber);
_matlab('fitObj.setNeuronName(structure.neuronNumber);')
# MATLAB L1475:                 
#
# MATLAB L1476:             elseif(isa(structure,'cell')) %cell array of FitResult objects
_matlab("elseif(isa(structure,'cell')) %cell array of FitResult objects")
# MATLAB L1477:                 fitObj = cell(size(structure));
_matlab('fitObj = cell(size(structure));')
# MATLAB L1478:                for i=1:length(structure)
_matlab('for i=1:length(structure)')
# MATLAB L1479:                   fitObj{i} = FitResult.fromStructure(structure{i}); 
_matlab('fitObj{i} = FitResult.fromStructure(structure{i});')
# MATLAB L1480:                end
_matlab('end')
# MATLAB L1481:             end
_matlab('end')
# MATLAB L1482:             
#
# MATLAB L1483:         end
_matlab('end')
# MATLAB L1484:         
#
# MATLAB L1485:         function structCell = CellArrayToStructure(fitResObjCell)
_matlab('function structCell = CellArrayToStructure(fitResObjCell)')
# MATLAB L1486:             % structCell = CellArrayToStructure(fitResObjCell)
# structCell = CellArrayToStructure(fitResObjCell)
# MATLAB L1487:             % For every FitResult structure in the a cell array, it calls 
# For every FitResult structure in the a cell array, it calls
# MATLAB L1488:             % FitResults.fromStructure
# FitResults.fromStructure
# MATLAB L1489:             
#
# MATLAB L1490:            if(isa(fitResObjCell,'FitResult'))
_matlab("if(isa(fitResObjCell,'FitResult'))")
# MATLAB L1491:                structCell = fitResObjCell.toStructure;
_matlab('structCell = fitResObjCell.toStructure;')
# MATLAB L1492:            elseif(isa(fitResObjCell,'cell')&&~isempty(fitResObjCell))
_matlab("elseif(isa(fitResObjCell,'cell')&&~isempty(fitResObjCell))")
# MATLAB L1493:                if(isa(fitResObjCell{1},'FitResult'))
_matlab("if(isa(fitResObjCell{1},'FitResult'))")
# MATLAB L1494:                    structCell = cell(size(fitResObjCell));
_matlab('structCell = cell(size(fitResObjCell));')
# MATLAB L1495:                   for i=1:length(fitResObjCell)
_matlab('for i=1:length(fitResObjCell)')
# MATLAB L1496:                      structCell{i} = fitResObjCell{i}.toStructure;
_matlab('structCell{i} = fitResObjCell{i}.toStructure;')
# MATLAB L1497:                   end
_matlab('end')
# MATLAB L1498:                end
_matlab('end')
# MATLAB L1499:            else
_matlab('else')
# MATLAB L1500:             structCell={};
_matlab('structCell={};')
# MATLAB L1501:            end
_matlab('end')
# MATLAB L1502:             
#
# MATLAB L1503:         end
_matlab('end')
# MATLAB L1504:         
#
# MATLAB L1505:     end
_matlab('end')
# MATLAB L1506:     
#
# MATLAB L1507: end
_matlab('end')
# MATLAB L1508: 
#
# MATLAB L1509: %Helper functions
# Helper functions
# MATLAB L1510: function hText = xticklabel_rotate(XTick,rot,varargin)
_matlab('function hText = xticklabel_rotate(XTick,rot,varargin)')
# MATLAB L1511:     %hText = xticklabel_rotate(XTick,rot,XTickLabel,varargin)     Rotate XTickLabel
# hText = xticklabel_rotate(XTick,rot,XTickLabel,varargin)     Rotate XTickLabel
# MATLAB L1512:     %
#
# MATLAB L1513:     % Syntax: xticklabel_rotate
# Syntax: xticklabel_rotate
# MATLAB L1514:     %
#
# MATLAB L1515:     % Input:    
# Input:
# MATLAB L1516:     % {opt}     XTick       - vector array of XTick positions & values (numeric) 
# {opt}     XTick       - vector array of XTick positions & values (numeric)
# MATLAB L1517:     %                           uses current XTick values or XTickLabel cell array by
# uses current XTick values or XTickLabel cell array by
# MATLAB L1518:     %                           default (if empty) 
# default (if empty)
# MATLAB L1519:     % {opt}     rot         - angle of rotation in degrees, 90 by default
# {opt}     rot         - angle of rotation in degrees, 90 by default
# MATLAB L1520:     % {opt}     XTickLabel  - cell array of label strings
# {opt}     XTickLabel  - cell array of label strings
# MATLAB L1521:     % {opt}     [var]       - "Property-value" pairs passed to text generator
# {opt}     [var]       - "Property-value" pairs passed to text generator
# MATLAB L1522:     %                           ex: 'interpreter','none'
# ex: 'interpreter','none'
# MATLAB L1523:     %                               'Color','m','Fontweight','bold'
# 'Color','m','Fontweight','bold'
# MATLAB L1524:     %
#
# MATLAB L1525:     % Output:   hText       - handle vector to text labels
# Output:   hText       - handle vector to text labels
# MATLAB L1526:     %
#
# MATLAB L1527:     % Example 1:  Rotate existing XTickLabels at their current position by 90
# Example 1:  Rotate existing XTickLabels at their current position by 90
# MATLAB L1528:     %    xticklabel_rotate
# xticklabel_rotate
# MATLAB L1529:     %
#
# MATLAB L1530:     % Example 2:  Rotate existing XTickLabels at their current position by 45 and change
# Example 2:  Rotate existing XTickLabels at their current position by 45 and change
# MATLAB L1531:     % font size
# font size
# MATLAB L1532:     %    xticklabel_rotate([],45,[],'Fontsize',14)
# xticklabel_rotate([],45,[],'Fontsize',14)
# MATLAB L1533:     %
#
# MATLAB L1534:     % Example 3:  Set the positions of the XTicks and rotate them 90
# Example 3:  Set the positions of the XTicks and rotate them 90
# MATLAB L1535:     %    figure;  plot([1960:2004],randn(45,1)); xlim([1960 2004]);
# figure;  plot([1960:2004],randn(45,1)); xlim([1960 2004]);
# MATLAB L1536:     %    xticklabel_rotate([1960:2:2004]);
# xticklabel_rotate([1960:2:2004]);
# MATLAB L1537:     %
#
# MATLAB L1538:     % Example 4:  Use text labels at XTick positions rotated 45 without tex interpreter
# Example 4:  Use text labels at XTick positions rotated 45 without tex interpreter
# MATLAB L1539:     %    xticklabel_rotate(XTick,45,NameFields,'interpreter','none');
# xticklabel_rotate(XTick,45,NameFields,'interpreter','none');
# MATLAB L1540:     %
#
# MATLAB L1541:     % Example 5:  Use text labels rotated 90 at current positions
# Example 5:  Use text labels rotated 90 at current positions
# MATLAB L1542:     %    xticklabel_rotate([],90,NameFields);
# xticklabel_rotate([],90,NameFields);
# MATLAB L1543:     %
#
# MATLAB L1544:     % Note : you can not re-run xticklabel_rotate on the same graph. 
# Note : you can not re-run xticklabel_rotate on the same graph.
# MATLAB L1545:     %
#
# MATLAB L1546:     % 
#
# MATLAB L1547: 
#
# MATLAB L1548: 
#
# MATLAB L1549:     % This is a modified version of xticklabel_rotate90 by Denis Gilbert
# This is a modified version of xticklabel_rotate90 by Denis Gilbert
# MATLAB L1550:     % Modifications include Text labels (in the form of cell array)
# Modifications include Text labels (in the form of cell array)
# MATLAB L1551:     %                       Arbitrary angle rotation
# Arbitrary angle rotation
# MATLAB L1552:     %                       Output of text handles
# Output of text handles
# MATLAB L1553:     %                       Resizing of axes and title/xlabel/ylabel positions to maintain same overall size 
# Resizing of axes and title/xlabel/ylabel positions to maintain same overall size
# MATLAB L1554:     %                           and keep text on plot
# and keep text on plot
# MATLAB L1555:     %                           (handles small window resizing after, but not well due to proportional placement with 
# (handles small window resizing after, but not well due to proportional placement with
# MATLAB L1556:     %                           fixed font size. To fix this would require a serious resize function)
# fixed font size. To fix this would require a serious resize function)
# MATLAB L1557:     %                       Uses current XTick by default
# Uses current XTick by default
# MATLAB L1558:     %                       Uses current XTickLabel is different from XTick values (meaning has been already defined)
# Uses current XTickLabel is different from XTick values (meaning has been already defined)
# MATLAB L1559: 
#
# MATLAB L1560:     % Brian FG Katz
# Brian FG Katz
# MATLAB L1561:     % bfgkatz@hotmail.com
# bfgkatz@hotmail.com
# MATLAB L1562:     % 23-05-03
# 23-05-03
# MATLAB L1563:     % Modified 03-11-06 after user comment
# Modified 03-11-06 after user comment
# MATLAB L1564:     %	Allow for exisiting XTickLabel cell array
# Allow for exisiting XTickLabel cell array
# MATLAB L1565: 
#
# MATLAB L1566:     % Other m-files required: cell2mat
# Other m-files required: cell2mat
# MATLAB L1567:     % Subfunctions: none
# Subfunctions: none
# MATLAB L1568:     % MAT-files required: none
# MAT-files required: none
# MATLAB L1569:     %
#
# MATLAB L1570:     % See also: xticklabel_rotate90, TEXT,  SET
# See also: xticklabel_rotate90, TEXT,  SET
# MATLAB L1571: 
#
# MATLAB L1572:     % Based on xticklabel_rotate90
# Based on xticklabel_rotate90
# MATLAB L1573:     %   Author: Denis Gilbert, Ph.D., physical oceanography
# Author: Denis Gilbert, Ph.D., physical oceanography
# MATLAB L1574:     %   Maurice Lamontagne Institute, Dept. of Fisheries and Oceans Canada
# Maurice Lamontagne Institute, Dept. of Fisheries and Oceans Canada
# MATLAB L1575:     %   email: gilbertd@dfo-mpo.gc.ca  Web: http://www.qc.dfo-mpo.gc.ca/iml/
# email: gilbertd@dfo-mpo.gc.ca  Web: http://www.qc.dfo-mpo.gc.ca/iml/
# MATLAB L1576:     %   February 1998; Last revision: 24-Mar-2003
# February 1998; Last revision: 24-Mar-2003
# MATLAB L1577: 
#
# MATLAB L1578:     % check to see if xticklabel_rotate has already been here (no other reason for this to happen)
# check to see if xticklabel_rotate has already been here (no other reason for this to happen)
# MATLAB L1579:     if isempty(get(gca,'XTickLabel')),
_matlab("if isempty(get(gca,'XTickLabel')),")
# MATLAB L1580:         error('xticklabel_rotate : can not process, either xticklabel_rotate has already been run or XTickLabel field has been erased')  ;
_matlab("error('xticklabel_rotate : can not process, either xticklabel_rotate has already been run or XTickLabel field has been erased')  ;")
# MATLAB L1581:     end
_matlab('end')
# MATLAB L1582: 
#
# MATLAB L1583:     % if no XTickLabel AND no XTick are defined use the current XTickLabel
# if no XTickLabel AND no XTick are defined use the current XTickLabel
# MATLAB L1584:     %if nargin < 3 & (~exist('XTick') | isempty(XTick)),
# if nargin < 3 & (~exist('XTick') | isempty(XTick)),
# MATLAB L1585:     if (nargin < 3 || isempty(varargin{1})) && (~exist('XTick') || isempty(XTick)),
_matlab("if (nargin < 3 || isempty(varargin{1})) && (~exist('XTick') || isempty(XTick)),")
# MATLAB L1586:         xTickLabels = get(gca,'XTickLabel')  ; % use current XTickLabel
_matlab("xTickLabels = get(gca,'XTickLabel')  ; % use current XTickLabel")
# MATLAB L1587:         if ~iscell(xTickLabels)
_matlab('if ~iscell(xTickLabels)')
# MATLAB L1588:             % remove trailing spaces if exist (typical with auto generated XTickLabel)
# remove trailing spaces if exist (typical with auto generated XTickLabel)
# MATLAB L1589:             temp1 = num2cell(xTickLabels,2)         ;
_matlab('temp1 = num2cell(xTickLabels,2)         ;')
# MATLAB L1590:             for loop = 1:length(temp1),
_matlab('for loop = 1:length(temp1),')
# MATLAB L1591:                 temp1{loop} = deblank(temp1{loop})  ;
_matlab('temp1{loop} = deblank(temp1{loop})  ;')
# MATLAB L1592:             end
_matlab('end')
# MATLAB L1593:             xTickLabels = temp1                     ;
_matlab('xTickLabels = temp1                     ;')
# MATLAB L1594:         end
_matlab('end')
# MATLAB L1595:     varargin = varargin(2:length(varargin));	
_matlab('varargin = varargin(2:length(varargin));')
# MATLAB L1596:     end
_matlab('end')
# MATLAB L1597: 
#
# MATLAB L1598:     % if no XTick is defined use the current XTick
# if no XTick is defined use the current XTick
# MATLAB L1599:     if (~exist('XTick') | isempty(XTick)),
_matlab("if (~exist('XTick') | isempty(XTick)),")
# MATLAB L1600:         XTick = get(gca,'XTick')        ; % use current XTick 
_matlab("XTick = get(gca,'XTick')        ; % use current XTick")
# MATLAB L1601:     end
_matlab('end')
# MATLAB L1602: 
#
# MATLAB L1603:     %Make XTick a column vector
# Make XTick a column vector
# MATLAB L1604:     XTick = XTick(:);
_matlab('XTick = XTick(:);')
# MATLAB L1605: 
#
# MATLAB L1606:     if ~exist('xTickLabels'),
_matlab("if ~exist('xTickLabels'),")
# MATLAB L1607:         % Define the xtickLabels 
# Define the xtickLabels
# MATLAB L1608:         % If XtickLabel is passed as a cell array then use the text
# If XtickLabel is passed as a cell array then use the text
# MATLAB L1609:         if (length(varargin)>0) & (iscell(varargin{1})),
_matlab('if (length(varargin)>0) & (iscell(varargin{1})),')
# MATLAB L1610:             xTickLabels = varargin{1};
_matlab('xTickLabels = varargin{1};')
# MATLAB L1611:             varargin = varargin(2:length(varargin));
_matlab('varargin = varargin(2:length(varargin));')
# MATLAB L1612:         else
_matlab('else')
# MATLAB L1613:             xTickLabels = num2str(XTick);
_matlab('xTickLabels = num2str(XTick);')
# MATLAB L1614:         end
_matlab('end')
# MATLAB L1615:     end    
_matlab('end')
# MATLAB L1616: 
#
# MATLAB L1617:     if length(XTick) ~= length(xTickLabels),
_matlab('if length(XTick) ~= length(xTickLabels),')
# MATLAB L1618:         error('xticklabel_rotate : must have same number of elements in "XTick" and "XTickLabel"')  ;
_matlab('error(\'xticklabel_rotate : must have same number of elements in "XTick" and "XTickLabel"\')  ;')
# MATLAB L1619:     end
_matlab('end')
# MATLAB L1620: 
#
# MATLAB L1621:     %Set the Xtick locations and set XTicklabel to an empty string
# Set the Xtick locations and set XTicklabel to an empty string
# MATLAB L1622:     set(gca,'XTick',XTick,'XTickLabel','')
_matlab("set(gca,'XTick',XTick,'XTickLabel','')")
# MATLAB L1623: 
#
# MATLAB L1624:     if nargin < 2,
_matlab('if nargin < 2,')
# MATLAB L1625:         rot = 90 ;
rot = 90
# MATLAB L1626:     end
_matlab('end')
# MATLAB L1627: 
#
# MATLAB L1628:     % Determine the location of the labels based on the position
# Determine the location of the labels based on the position
# MATLAB L1629:     % of the xlabel
# of the xlabel
# MATLAB L1630:     hxLabel = get(gca,'XLabel');  % Handle to xlabel
_matlab("hxLabel = get(gca,'XLabel');  % Handle to xlabel")
# MATLAB L1631:     xLabelString = get(hxLabel,'String');
_matlab("xLabelString = get(hxLabel,'String');")
# MATLAB L1632: 
#
# MATLAB L1633:     % if ~isempty(xLabelString)
# if ~isempty(xLabelString)
# MATLAB L1634:     %    warning('You may need to manually reset the XLABEL vertical position')
# warning('You may need to manually reset the XLABEL vertical position')
# MATLAB L1635:     % end
# end
# MATLAB L1636: 
#
# MATLAB L1637:     set(hxLabel,'Units','data');
_matlab("set(hxLabel,'Units','data');")
# MATLAB L1638:     xLabelPosition = get(hxLabel,'Position');
_matlab("xLabelPosition = get(hxLabel,'Position');")
# MATLAB L1639:     y = xLabelPosition(2);
_matlab('y = xLabelPosition(2);')
# MATLAB L1640: 
#
# MATLAB L1641:     %CODE below was modified following suggestions from Urs Schwarz
# CODE below was modified following suggestions from Urs Schwarz
# MATLAB L1642:     y=repmat(y,size(XTick,1),1);
_matlab('y=repmat(y,size(XTick,1),1);')
# MATLAB L1643:     % retrieve current axis' fontsize
# retrieve current axis' fontsize
# MATLAB L1644:     fs = get(gca,'fontsize');
_matlab("fs = get(gca,'fontsize');")
# MATLAB L1645: 
#
# MATLAB L1646:     % Place the new xTickLabels by creating TEXT objects
# Place the new xTickLabels by creating TEXT objects
# MATLAB L1647:     hText = text(XTick, y, xTickLabels,'fontsize',fs);
_matlab("hText = text(XTick, y, xTickLabels,'fontsize',fs);")
# MATLAB L1648: 
#
# MATLAB L1649:     % Rotate the text objects by ROT degrees
# Rotate the text objects by ROT degrees
# MATLAB L1650:     set(hText,'Rotation',rot,'HorizontalAlignment','right',varargin{:})
_matlab("set(hText,'Rotation',rot,'HorizontalAlignment','right',varargin{:})")
# MATLAB L1651: 
#
# MATLAB L1652:     % Adjust the size of the axis to accomodate for longest label (like if they are text ones)
# Adjust the size of the axis to accomodate for longest label (like if they are text ones)
# MATLAB L1653:     % This approach keeps the top of the graph at the same place and tries to keep xlabel at the same place
# This approach keeps the top of the graph at the same place and tries to keep xlabel at the same place
# MATLAB L1654:     % This approach keeps the right side of the graph at the same place 
# This approach keeps the right side of the graph at the same place
# MATLAB L1655: 
#
# MATLAB L1656:     set(get(gca,'xlabel'),'units','data')           ;
_matlab("set(get(gca,'xlabel'),'units','data')           ;")
# MATLAB L1657:         labxorigpos_data = get(get(gca,'xlabel'),'position')  ;
_matlab("labxorigpos_data = get(get(gca,'xlabel'),'position')  ;")
# MATLAB L1658:     set(get(gca,'ylabel'),'units','data')           ;
_matlab("set(get(gca,'ylabel'),'units','data')           ;")
# MATLAB L1659:         labyorigpos_data = get(get(gca,'ylabel'),'position')  ;
_matlab("labyorigpos_data = get(get(gca,'ylabel'),'position')  ;")
# MATLAB L1660:     set(get(gca,'title'),'units','data')           ;
_matlab("set(get(gca,'title'),'units','data')           ;")
# MATLAB L1661:         labtorigpos_data = get(get(gca,'title'),'position')  ;
_matlab("labtorigpos_data = get(get(gca,'title'),'position')  ;")
# MATLAB L1662: 
#
# MATLAB L1663:     set(gca,'units','pixel')                        ;
_matlab("set(gca,'units','pixel')                        ;")
# MATLAB L1664:     set(hText,'units','pixel')                      ;
_matlab("set(hText,'units','pixel')                      ;")
# MATLAB L1665:     set(get(gca,'xlabel'),'units','pixel')          ;
_matlab("set(get(gca,'xlabel'),'units','pixel')          ;")
# MATLAB L1666:     set(get(gca,'ylabel'),'units','pixel')          ;
_matlab("set(get(gca,'ylabel'),'units','pixel')          ;")
# MATLAB L1667: 
#
# MATLAB L1668:     origpos = get(gca,'position')                   ;
_matlab("origpos = get(gca,'position')                   ;")
# MATLAB L1669:     
#
# MATLAB L1670:     % Modified by Iahn Cajigas
# Modified by Iahn Cajigas
# MATLAB L1671:     % 3/4/2011 to allow for a single
# 3/4/2011 to allow for a single
# MATLAB L1672:     % xTickLabel to work properly
# xTickLabel to work properly
# MATLAB L1673:     temphText = get(hText,'extent');
_matlab("temphText = get(hText,'extent');")
# MATLAB L1674:     if(isa(temphText,'cell'))
_matlab("if(isa(temphText,'cell'))")
# MATLAB L1675:         textsizes = cell2mat(temphText)       ;
_matlab('textsizes = cell2mat(temphText)       ;')
# MATLAB L1676:     else
_matlab('else')
# MATLAB L1677:         textsizes = temphText;
_matlab('textsizes = temphText;')
# MATLAB L1678:     end
_matlab('end')
# MATLAB L1679:     
#
# MATLAB L1680:     longest =  max(textsizes(:,4))                  ;
_matlab('longest =  max(textsizes(:,4))                  ;')
# MATLAB L1681: 
#
# MATLAB L1682:     laborigext = get(get(gca,'xlabel'),'extent')    ;
_matlab("laborigext = get(get(gca,'xlabel'),'extent')    ;")
# MATLAB L1683:     laborigpos = get(get(gca,'xlabel'),'position')  ;
_matlab("laborigpos = get(get(gca,'xlabel'),'position')  ;")
# MATLAB L1684: 
#
# MATLAB L1685: 
#
# MATLAB L1686:     labyorigext = get(get(gca,'ylabel'),'extent')   ;
_matlab("labyorigext = get(get(gca,'ylabel'),'extent')   ;")
# MATLAB L1687:     labyorigpos = get(get(gca,'ylabel'),'position') ;
_matlab("labyorigpos = get(get(gca,'ylabel'),'position') ;")
# MATLAB L1688:     leftlabdist = labyorigpos(1) + labyorigext(1)   ;
_matlab('leftlabdist = labyorigpos(1) + labyorigext(1)   ;')
# MATLAB L1689: 
#
# MATLAB L1690:     % assume first entry is the farthest left
# assume first entry is the farthest left
# MATLAB L1691:     leftpos = get(hText(1),'position')              ;
_matlab("leftpos = get(hText(1),'position')              ;")
# MATLAB L1692:     leftext = get(hText(1),'extent')                ;
_matlab("leftext = get(hText(1),'extent')                ;")
# MATLAB L1693:     leftdist = leftpos(1) + leftext(1)              ;
_matlab('leftdist = leftpos(1) + leftext(1)              ;')
# MATLAB L1694:     if leftdist > 0,    leftdist = 0 ; end          % only correct for off screen problems
_matlab('if leftdist > 0,    leftdist = 0 ; end          % only correct for off screen problems')
# MATLAB L1695: 
#
# MATLAB L1696:     botdist = origpos(2) + laborigpos(2)            ;
_matlab('botdist = origpos(2) + laborigpos(2)            ;')
# MATLAB L1697:     newpos = [origpos(1)-leftdist longest+botdist origpos(3)+leftdist origpos(4)-longest+origpos(2)-botdist]  ;
_matlab('newpos = [origpos(1)-leftdist longest+botdist origpos(3)+leftdist origpos(4)-longest+origpos(2)-botdist]  ;')
# MATLAB L1698:     set(gca,'position',newpos)                      ;
_matlab("set(gca,'position',newpos)                      ;")
# MATLAB L1699: 
#
# MATLAB L1700:     % readjust position of nex labels after resize of plot
# readjust position of nex labels after resize of plot
# MATLAB L1701:     set(hText,'units','data')                       ;
_matlab("set(hText,'units','data')                       ;")
# MATLAB L1702:     for loop= 1:length(hText),
_matlab('for loop= 1:length(hText),')
# MATLAB L1703:         set(hText(loop),'position',[XTick(loop), y(loop)])  ;
_matlab("set(hText(loop),'position',[XTick(loop), y(loop)])  ;")
# MATLAB L1704:     end
_matlab('end')
# MATLAB L1705: 
#
# MATLAB L1706: 
#
# MATLAB L1707:     % adjust position of xlabel and ylabel
# adjust position of xlabel and ylabel
# MATLAB L1708:     laborigpos = get(get(gca,'xlabel'),'position')  ;
_matlab("laborigpos = get(get(gca,'xlabel'),'position')  ;")
# MATLAB L1709:     set(get(gca,'xlabel'),'position',[laborigpos(1) laborigpos(2)-longest 0])   ;
_matlab("set(get(gca,'xlabel'),'position',[laborigpos(1) laborigpos(2)-longest 0])   ;")
# MATLAB L1710: 
#
# MATLAB L1711:     % switch to data coord and fix it all
# switch to data coord and fix it all
# MATLAB L1712:     set(get(gca,'ylabel'),'units','data')                   ;
_matlab("set(get(gca,'ylabel'),'units','data')                   ;")
# MATLAB L1713:     set(get(gca,'ylabel'),'position',labyorigpos_data)      ;
_matlab("set(get(gca,'ylabel'),'position',labyorigpos_data)      ;")
# MATLAB L1714:     set(get(gca,'title'),'position',labtorigpos_data)       ;
_matlab("set(get(gca,'title'),'position',labtorigpos_data)       ;")
# MATLAB L1715: 
#
# MATLAB L1716:     set(get(gca,'xlabel'),'units','data')                   ;
_matlab("set(get(gca,'xlabel'),'units','data')                   ;")
# MATLAB L1717:         labxorigpos_data_new = get(get(gca,'xlabel'),'position')  ;
_matlab("labxorigpos_data_new = get(get(gca,'xlabel'),'position')  ;")
# MATLAB L1718:     set(get(gca,'xlabel'),'position',[labxorigpos_data(1) labxorigpos_data_new(2)])   ;
_matlab("set(get(gca,'xlabel'),'position',[labxorigpos_data(1) labxorigpos_data_new(2)])   ;")
# MATLAB L1719: 
#
# MATLAB L1720: 
#
# MATLAB L1721:     % Reset all units to normalized to allow future resizing
# Reset all units to normalized to allow future resizing
# MATLAB L1722:     set(get(gca,'xlabel'),'units','normalized')          ;
_matlab("set(get(gca,'xlabel'),'units','normalized')          ;")
# MATLAB L1723:     set(get(gca,'ylabel'),'units','normalized')          ;
_matlab("set(get(gca,'ylabel'),'units','normalized')          ;")
# MATLAB L1724:     set(get(gca,'title'),'units','normalized')          ;
_matlab("set(get(gca,'title'),'units','normalized')          ;")
# MATLAB L1725:     set(hText,'units','normalized')                      ;
_matlab("set(hText,'units','normalized')                      ;")
# MATLAB L1726:     set(gca,'units','normalized')                        ;
_matlab("set(gca,'units','normalized')                        ;")
# MATLAB L1727: 
#
# MATLAB L1728:     if nargout < 1,
_matlab('if nargout < 1,')
# MATLAB L1729:         clear hText
pass
# MATLAB L1730:     end
_matlab('end')
# MATLAB L1731: 
#
# MATLAB L1732: end
_matlab('end')
# MATLAB L1733: function [uniqueLabels, indexIntoOriginal, restoreIndex] = getUniqueLabels(covLabels)
_matlab('function [uniqueLabels, indexIntoOriginal, restoreIndex] = getUniqueLabels(covLabels)')
# MATLAB L1734: % Given a set of covLabels, returns a subset of labels that are unique
# Given a set of covLabels, returns a subset of labels that are unique
# MATLAB L1735:             offset = 0;
offset = 0
# MATLAB L1736:             for i=1:length(covLabels)
_matlab('for i=1:length(covLabels)')
# MATLAB L1737:                 currLabels = covLabels{i};                
_matlab('currLabels = covLabels{i};')
# MATLAB L1738:                 allLabels((1:length(currLabels))+offset) = currLabels;
_matlab('allLabels((1:length(currLabels))+offset) = currLabels;')
# MATLAB L1739:                 offset=length(allLabels);
_matlab('offset=length(allLabels);')
# MATLAB L1740:             end
_matlab('end')
# MATLAB L1741:             [uniqueLabels, indexIntoOriginal, restoreIndex] = unique(allLabels);
_matlab('[uniqueLabels, indexIntoOriginal, restoreIndex] = unique(allLabels);')
# MATLAB L1742: end
_matlab('end')
# MATLAB L1743:         
#
# MATLAB L1744: 
#
# MATLAB L1745:    
#
__tracker.finalize()

# %% [markdown]
# # Using the SignalObj Class
#
# Executable Python notebook generated from source help-topic scripts.
# MATLAB help target: `SignalObjExamples.html`
# Topic module: `examples.help_topics.SignalObjExamples`

# %% [markdown]
# ## What this example demonstrates
# This example shows the standalone Python equivalent of `SignalObjExamples` using the paper's point-process nomenclature (for example CIF, PP-GLM, history dependence, and decoding/network terms when applicable).

# %% [markdown]
# ## Data and assumptions
# The run uses bundled nSTAT datasets or deterministic synthetic fallbacks where needed, with fixed seeds for reproducibility.

# %% [markdown]
# ## Step-by-step workflow
# 1. Resolve repository root and Python path.
# 2. Run `examples.help_topics.SignalObjExamples.run(...)` with figure rendering enabled.
# 3. Print structured output for debugging and parity review.
# 4. Display rendered figure files inline for interpretation and web publication.
# 5. Assert figure-count contract and artifact existence.

# %% [markdown]
# ## Expected figures and interpretation
# This notebook renders 16 figure(s) to illustrate the modeled behavior and analysis pipeline.
# Interpretation should focus on trend consistency, event timing, and qualitative agreement with MATLAB reference outputs rather than pixel-identical rendering.

# %% [markdown]
# ## MATLAB Live Script alignment
# MATLAB Live Script source: `nSTAT_currentRelease_Local/helpfiles/SignalObjExamples.mlx`
# MLX title: **Using the SignalObj Class**
# MLX intent summary: In this file we will give several examples of how the SignalObj can be used. A description of all of the properties of SignalObj can be found at: SignalObj Class Definition
# Key MLX section headings:
# - Example 1: Defining and Plotting Signals
# - Example 2: Changing Signal Properties
# - Example 3: Resampling and Windowing SignalObjs
# - Example 4: SignalObj Mathematical Operations
# - Example 5: Spectra
# - Example 6: View signal variability

# %% [markdown]
# ## Paper terminology and section references
# Reference: **Cajigas et al. (2012), *Journal of Neuroscience Methods***
# Paper URL: https://pmc.ncbi.nlm.nih.gov/articles/PMC3491120/
# Most relevant paper sections for this topic:
# - Section 2.2.1
# - Section 2.3
# nSTAT paper terms used in this notebook:
# - signal
# - covariate
# - visualization
# Section-aligned interpretation: Signal representations used as building blocks for CIF modeling workflows.

# %% [markdown]
# ## Debug tips
# If execution fails, verify dataset availability, run with `MPLBACKEND=Agg` in headless mode, and inspect the JSON payload keys (`topic`, `figure_count`, `figures`) for mismatches.

# %%
from pathlib import Path
import json
import sys

def find_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for p in [cur, *cur.parents]:
        if (p / '.git').exists() and (p / 'nstat').exists() and (p / 'helpfiles').exists():
            return p
    raise RuntimeError('Could not find nSTAT repo root from notebook cwd')

repo_root = find_repo_root(Path.cwd())
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
print('repo_root =', repo_root)
# Out:
# repo_root = /private/tmp/nstat-python-split-bootstrap

# %%
from examples.help_topics.SignalObjExamples import run
expected_figures = 16
figure_dir = repo_root / 'reports' / 'figures' / 'notebooks' / 'SignalObjExamples'
out = run(repo_root=repo_root, figure_dir=figure_dir, render_figures=True)
print(json.dumps(out, indent=2, default=str))
# Out:
# {
#   "topic": "SignalObjExamples",
#   "dimension": 2,
#   "sample_rate": 5000.00000000055,
#   "parity": {
#     "figs": 16.0,
#     "sample_rate_hz": 5000.00000000055
#   },
#   "figure_contract_expected": 16,
#   "figure_count": 16,
#   "figures": [
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_001.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_002.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_003.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_004.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_005.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_006.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_007.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_008.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_009.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_010.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_011.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_012.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_013.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_014.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_015.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/SignalObjExamples/fig_016.png"
#   ]
# }

# %%
from pathlib import Path
from IPython.display import Image, display

for fig_path in out.get('figures', []):
    p = Path(fig_path)
    print(p.name)
    display(Image(filename=str(p)))
# Out:
# fig_001.png
# fig_002.png
# fig_003.png
# fig_004.png
# fig_005.png
# fig_006.png
# fig_007.png
# fig_008.png
# fig_009.png
# fig_010.png
# fig_011.png
# fig_012.png
# fig_013.png
# fig_014.png
# fig_015.png
# fig_016.png

# %%
assert out.get('topic') == 'SignalObjExamples'
assert out.get('figure_contract_expected') == expected_figures
assert out.get('figure_count') == expected_figures, out
for fig_path in out.get('figures', []):
    assert Path(fig_path).exists(), fig_path
print('Notebook execution + figure contract: PASS')
# Out:
# Notebook execution + figure contract: PASS

# %% [markdown]
# # Example Data Analysis - Two Neuron Network Simulation and Estimation of Ensemble Effect
#
# Executable Python notebook generated from source help-topic scripts.
# MATLAB help target: `NetworkTutorial.html`
# Topic module: `examples.help_topics.NetworkTutorial`

# %% [markdown]
# ## What this example demonstrates
# This example shows the standalone Python equivalent of `NetworkTutorial` using the paper's point-process nomenclature (for example CIF, PP-GLM, history dependence, and decoding/network terms when applicable).

# %% [markdown]
# ## Data and assumptions
# The run uses bundled nSTAT datasets or deterministic synthetic fallbacks where needed, with fixed seeds for reproducibility.

# %% [markdown]
# ## Step-by-step workflow
# 1. Resolve repository root and Python path.
# 2. Run `examples.help_topics.NetworkTutorial.run(...)` with figure rendering enabled.
# 3. Print structured output for debugging and parity review.
# 4. Display rendered figure files inline for interpretation and web publication.
# 5. Assert figure-count contract and artifact existence.

# %% [markdown]
# ## Expected figures and interpretation
# This notebook renders 4 figure(s) to illustrate the modeled behavior and analysis pipeline.
# Interpretation should focus on trend consistency, event timing, and qualitative agreement with MATLAB reference outputs rather than pixel-identical rendering.

# %% [markdown]
# ## MATLAB Live Script alignment
# MATLAB Live Script source: `helpfiles/NetworkTutorial.m`
# MLX title: **Example Data Analysis - Two Neuron Network Simulation and Estimation of Ensemble Effect**
# No `.mlx` metadata was found for this topic in the synced MATLAB helpfiles; alignment is based on the MATLAB help script naming convention.

# %% [markdown]
# ## Paper terminology and section references
# Reference: **Cajigas et al. (2012), *Journal of Neuroscience Methods***
# Paper URL: https://pmc.ncbi.nlm.nih.gov/articles/PMC3491120/
# Most relevant paper sections for this topic:
# - Section 2.1.7
# - Section 2.3.5
# - Section 3.5
# nSTAT paper terms used in this notebook:
# - ensemble analysis
# - network coupling
# - connectivity
# Section-aligned interpretation: Two-neuron network simulation illustrating ensemble coupling inference.

# %% [markdown]
# ## Debug tips
# If execution fails, verify dataset availability, run with `MPLBACKEND=Agg` in headless mode, and inspect the JSON payload keys (`topic`, `figure_count`, `figures`) for mismatches.

# %%
from pathlib import Path
import json
import sys

def find_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for p in [cur, *cur.parents]:
        if (p / '.git').exists() and (p / 'nstat').exists() and (p / 'helpfiles').exists():
            return p
    raise RuntimeError('Could not find nSTAT repo root from notebook cwd')

repo_root = find_repo_root(Path.cwd())
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
print('repo_root =', repo_root)
# Out:
# repo_root = /private/tmp/nstat-python-split-bootstrap

# %%
from examples.help_topics.NetworkTutorial import run
expected_figures = 4
figure_dir = repo_root / 'reports' / 'figures' / 'notebooks' / 'NetworkTutorial'
out = run(repo_root=repo_root, figure_dir=figure_dir, render_figures=True)
print(json.dumps(out, indent=2, default=str))
# Out:
# {
#   "topic": "NetworkTutorial",
#   "samples": 2001,
#   "neuron_count": 2,
#   "psth_peak": 40.0,
#   "parity": {
#     "figs": 4.0
#   },
#   "figure_contract_expected": 4,
#   "figure_count": 4,
#   "figures": [
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/NetworkTutorial/fig_001.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/NetworkTutorial/fig_002.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/NetworkTutorial/fig_003.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/NetworkTutorial/fig_004.png"
#   ]
# }

# %%
from pathlib import Path
from IPython.display import Image, display

for fig_path in out.get('figures', []):
    p = Path(fig_path)
    print(p.name)
    display(Image(filename=str(p)))
# Out:
# fig_001.png
# fig_002.png
# fig_003.png
# fig_004.png

# %%
assert out.get('topic') == 'NetworkTutorial'
assert out.get('figure_contract_expected') == expected_figures
assert out.get('figure_count') == expected_figures, out
for fig_path in out.get('figures', []):
    assert Path(fig_path).exists(), fig_path
print('Notebook execution + figure contract: PASS')
# Out:
# Notebook execution + figure contract: PASS

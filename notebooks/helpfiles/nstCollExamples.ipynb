# %% [markdown]
# # Using the nstColl Class
#
# Executable Python notebook generated from source help-topic scripts.
# MATLAB help target: `nstCollExamples.html`
# Topic module: `examples.help_topics.nstCollExamples`

# %% [markdown]
# ## What this example demonstrates
# This example shows the standalone Python equivalent of `nstCollExamples` using the paper's point-process nomenclature (for example CIF, PP-GLM, history dependence, and decoding/network terms when applicable).

# %% [markdown]
# ## Data and assumptions
# The run uses bundled nSTAT datasets or deterministic synthetic fallbacks where needed, with fixed seeds for reproducibility.

# %% [markdown]
# ## Step-by-step workflow
# 1. Resolve repository root and Python path.
# 2. Run `examples.help_topics.nstCollExamples.run(...)` with figure rendering enabled.
# 3. Print structured output for debugging and parity review.
# 4. Display rendered figure files inline for interpretation and web publication.
# 5. Assert figure-count contract and artifact existence.

# %% [markdown]
# ## Expected figures and interpretation
# This notebook renders 3 figure(s) to illustrate the modeled behavior and analysis pipeline.
# Interpretation should focus on trend consistency, event timing, and qualitative agreement with MATLAB reference outputs rather than pixel-identical rendering.

# %% [markdown]
# ## MATLAB Live Script alignment
# MATLAB Live Script source: `nSTAT_currentRelease_Local/helpfiles/nstCollExamples.mlx`
# MLX title: **nstCollExamples**
# MLX intent summary: Create pseudo spike data and create a neural spike collection (nstColl).
# Key MLX section headings:
# - Test the nstColl Class

# %% [markdown]
# ## Paper terminology and section references
# Reference: **Cajigas et al. (2012), *Journal of Neuroscience Methods***
# Paper URL: https://pmc.ncbi.nlm.nih.gov/articles/PMC3491120/
# Most relevant paper sections for this topic:
# - Section 2.2.1
# - Section 2.1.1
# nSTAT paper terms used in this notebook:
# - spike train collection
# - population activity
# Section-aligned interpretation: Population-level spike train handling and PSTH-style summaries.

# %% [markdown]
# ## Debug tips
# If execution fails, verify dataset availability, run with `MPLBACKEND=Agg` in headless mode, and inspect the JSON payload keys (`topic`, `figure_count`, `figures`) for mismatches.

# %%
from pathlib import Path
import json
import sys

def find_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for p in [cur, *cur.parents]:
        if (p / '.git').exists() and (p / 'nstat').exists() and (p / 'helpfiles').exists():
            return p
    raise RuntimeError('Could not find nSTAT repo root from notebook cwd')

repo_root = find_repo_root(Path.cwd())
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
print('repo_root =', repo_root)
# Out:
# repo_root = /private/tmp/nstat-python-split-bootstrap

# %%
from examples.help_topics.nstCollExamples import run
expected_figures = 3
figure_dir = repo_root / 'reports' / 'figures' / 'notebooks' / 'nstCollExamples'
out = run(repo_root=repo_root, figure_dir=figure_dir, render_figures=True)
print(json.dumps(out, indent=2, default=str))
# Out:
# {
#   "topic": "nstCollExamples",
#   "num_trains": 3,
#   "psth_points": 40,
#   "parity": {
#     "figs": 3.0
#   },
#   "figure_contract_expected": 3,
#   "figure_count": 3,
#   "figures": [
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/nstCollExamples/fig_001.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/nstCollExamples/fig_002.png",
#     "/private/tmp/nstat-python-split-bootstrap/reports/figures/notebooks/nstCollExamples/fig_003.png"
#   ]
# }

# %%
from pathlib import Path
from IPython.display import Image, display

for fig_path in out.get('figures', []):
    p = Path(fig_path)
    print(p.name)
    display(Image(filename=str(p)))
# Out:
# fig_001.png
# fig_002.png
# fig_003.png

# %%
assert out.get('topic') == 'nstCollExamples'
assert out.get('figure_contract_expected') == expected_figures
assert out.get('figure_count') == expected_figures, out
for fig_path in out.get('figures', []):
    assert Path(fig_path).exists(), fig_path
print('Notebook execution + figure contract: PASS')
# Out:
# Notebook execution + figure contract: PASS

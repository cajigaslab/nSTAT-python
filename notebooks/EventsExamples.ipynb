# %% [markdown]
# # EventsExamples\n\nEvent-time objects and plotting.\n\nPython port of the MATLAB `EventsExamples` helpfile (`helpfiles/EventsExamples.m`).

# %%
from pathlib import Path
import sys
REPO_ROOT = Path.cwd().resolve().parent
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
import matplotlib; matplotlib.use("Agg")
import matplotlib.pyplot as plt
import numpy as np
from nstat import SignalObj, Covariate, CovColl, Events, nspikeTrain, nstColl
from nstat.notebook_figures import FigureTracker
np.random.seed(0)
OUTPUT_ROOT = REPO_ROOT / "output" / "notebook_images"
__tracker = FigureTracker(topic="EventsExamples", output_root=OUTPUT_ROOT, expected_count=4)

def capture(label, fn):
    """For plot methods that draw on the current axes: discard the tracker
    placeholder, open a FRESH figure so each plot gets its own axes,
    run the plot, then capture the figure it drew on."""
    placeholder = __tracker.new_figure(label)
    plt.close(placeholder)
    fig = plt.figure()
    fn()
    __tracker._active_fig = fig

# %%
# SECTION 1: Events
# Events are simple objects to use and are aimed to facilitate illustration
# of epochs in any type of data.
eTimes = np.sort(np.random.rand(3))
eLabels = ["E_1", "E_2", "E_3"]
eventColor = "b"
e = Events(eTimes, eLabels, eventColor)
capture("e.plot() (blue default)", lambda: e.plot())

# %%
# SECTION 2: (untitled section)
# The color of the event markers can also be specified
capture("e.plot (red)", lambda: e.plot(colorString="r"))
capture("e.plot (green)", lambda: e.plot(colorString="g"))

# Fourth panel: fresh random draw replotted in red (mirrors .mlx live-script extra cell)
eTimes2 = np.sort(np.random.rand(3))
e2 = Events(eTimes2, ["E_1", "E_2", "E_3"], "r")
capture("e2.plot (red, second draw)", lambda: e2.plot())

__tracker.finalize()

# %%
# AUTO-GENERATED FROM MATLAB Examples.mlx -- DO NOT EDIT
from pathlib import Path
import sys

REPO_ROOT = Path.cwd().resolve().parent
SRC_PATH = (REPO_ROOT / "src").resolve()
if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat

from nstat.data_manager import ensure_example_data
from nstat.notebook_figures import FigureTracker

np.random.seed(0)
DATA_DIR = ensure_example_data(download=True)
OUTPUT_ROOT = REPO_ROOT / "output" / "notebook_images"
__tracker = FigureTracker(topic='Examples', output_root=OUTPUT_ROOT, expected_count=0)

def _matlab(line: str) -> None:
    """Placeholder for untranslated MATLAB syntax."""
    _ = line
    return

def _load_matlab_globals(name: str) -> dict[str, object]:
    candidates = [
        Path(name),
        DATA_DIR / name,
        DATA_DIR / "mEPSCs" / name,
        DATA_DIR / "Place Cells" / name,
        DATA_DIR / "Explicit Stimulus" / name,
    ]
    for path in candidates:
        if path.exists():
            data = loadmat(path)
            return {k: v for k, v in data.items() if not k.startswith("__")}
    return {}

def _has_vars(*names: str) -> bool:
    return all(name in globals() for name in names)

# SECTION 0: Section 0
# MATLAB L100: % Examples
# Examples
# MATLAB L200: % Example files are provided for each of the classes defined in the Neural Spike Analysis Toolbox so that the user can understand the functionality of each in more detail.
# Example files are provided for each of the classes defined in the Neural Spike Analysis Toolbox so that the user can understand the functionality of each in more detail.
# MATLAB L300: % Using the SignalObj Class
# Using the SignalObj Class
# MATLAB L400: % Using the Covariate Class
# Using the Covariate Class
# MATLAB L500: % Using the CovColl Class
# Using the CovColl Class
# MATLAB L600: % Using the nSpikeTrain Class
# Using the nSpikeTrain Class
# MATLAB L700: % Using the nstColl Class
# Using the nstColl Class
# MATLAB L800: % Using the Events Class
# Using the Events Class
# MATLAB L900: % Using the History Class
# Using the History Class
# MATLAB L1000: % Using the Trial Class
# Using the Trial Class
# MATLAB L1100: % Using the TrialConfig Class
# Using the TrialConfig Class
# MATLAB L1200: % Using the ConfigColl Class
# Using the ConfigColl Class
# MATLAB L1300: % Using the Analysis Class
# Using the Analysis Class
# MATLAB L1400: % Using the FitResult Class
# Using the FitResult Class
# MATLAB L1500: % Using the FitResSummary Class
# Using the FitResSummary Class
# MATLAB L1600: % Point Process simulation via Thinning
# Point Process simulation via Thinning
# MATLAB L1700: % Example Data Analysis - Simulated Data - Computing a Peri-Stimulus Time Histogram (PSTH)
# Example Data Analysis - Simulated Data - Computing a Peri-Stimulus Time Histogram (PSTH)
# MATLAB L1800: % Example Data Analysis - Simulated Constant (&Piecewise Constant) Rate Poisson
# Example Data Analysis - Simulated Constant (&Piecewise Constant) Rate Poisson
# MATLAB L1900: % Example Data Analysis - Miniature Excitatory Post-Synaptic Currents (mEPSCs)
# Example Data Analysis - Miniature Excitatory Post-Synaptic Currents (mEPSCs)
# MATLAB L2000: % Example Data Analysis - Simulated Explicit Stimulus and History
# Example Data Analysis - Simulated Explicit Stimulus and History
# MATLAB L2100: % Example Data Analysis - Explicit Stimulus
# Example Data Analysis - Explicit Stimulus
# MATLAB L2200: % Example Data Analysis - Hippocampal Place Cell Receptive Field Estimation
# Example Data Analysis - Hippocampal Place Cell Receptive Field Estimation
# MATLAB L2300: % Example Data Analysis - Decoding Univariate Simulated Stimuli (No History Effect)
# Example Data Analysis - Decoding Univariate Simulated Stimuli (No History Effect)
# MATLAB L2400: % Example Data Analysis - Decoding Univariate Simulated Stimuli with and without History Effect
# Example Data Analysis - Decoding Univariate Simulated Stimuli with and without History Effect
# MATLAB L2500: % Example Data Analysis - Decoding Bivariate Simulated Stimuli
# Example Data Analysis - Decoding Bivariate Simulated Stimuli
# MATLAB L2600: % Example Data Analysis - Two Neuron Network Simulation and Estimation of Ensemble Effect
# Example Data Analysis - Two Neuron Network Simulation and Estimation of Ensemble Effect
# MATLAB L2700: % nSTAT J. Neuroscience Methods Examples
# nSTAT J. Neuroscience Methods Examples
__tracker.finalize()
